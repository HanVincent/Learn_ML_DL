# %%
import numpy as np
import os
import tensorflow as tf
from sklearn.metrics import classification_report ## 印出可視覺化的表

###### Do not modify here ###### 

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

reset_graph()

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/")

# training on MNIST but only on digits 0 to 4
X_train1 = mnist.train.images[mnist.train.labels < 5]
y_train1 = mnist.train.labels[mnist.train.labels < 5]
X_valid1 = mnist.validation.images[mnist.validation.labels < 5]
y_valid1 = mnist.validation.labels[mnist.validation.labels < 5]
X_test1 = mnist.test.images[mnist.test.labels < 5]
y_test1 = mnist.test.labels[mnist.test.labels < 5]

###### Do not modify here ######
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
##############################################
#                                            #
#               基礎版本                      #
#                                            #
##############################################

# %%
### 先前設置 
in_units = 784 # 28 * 28 拉直後 = 784維 
h_units = [128, 128, 128, 128, 128] # 題目要求5層hidden layers，及每一層128neurons
n_class = 5 # 題目要求只要辨識 0 ,1 ,2 ,3 及4 ，共5個類別

n_train = len(X_train1) # train資料的長度
batch_size = 50
n_batch = n_train // batch_size

x = tf.placeholder(tf.float32,[None,in_units]) # 初始化x資料型態為[None,784]
y = tf.placeholder(tf.int64, shape=(None), name="y") # 初始化y資料型態[None]

# %%
# [128, 128, 128, 128, 128]
def L_layers_model(x, h_units, n_class, dropout=None):
    # default he_init: factor=2.0, mode='FAN_IN', uniform=False, seed=None, dtype=tf.float32
    he_init = tf.contrib.layers.variance_scaling_initializer()
    
    with tf.name_scope("DNN"):
        h_layers = x
        for i in range(len(h_units)):
            h_layers = tf.layers.dense(h_layers, h_units[i], name="hidden" + str(i+1), 
                                      use_bias=True, kernel_initializer= he_init,
                                      bias_initializer=he_init, activation=tf.nn.elu)
            if dropout is not None:
                h_layers= tf.layers.dropout(h_layers, rate=dropout)
            
        # 結合之後的 tf.nn.sparse_softmax_cross_entropy_with_logits [128 , 5]
        logits = tf.layers.dense(h_layers, n_class, name="outputs")
    
    return logits

def train_op(y, logits):
    with tf.name_scope("loss"):
        entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
        loss = tf.reduce_mean(entropy, name="loss")
    
    ## 此區使用AdamOptimizer 的優化器進行梯度優化
    with tf.name_scope("train"):
        batch = tf.Variable(0)

        learning_rate = tf.train.exponential_decay(
                1e-4,  # Base learning rate.
                batch * batch_size,  # Current index into the dataset.
                n_train,  # Decay step.
                0.95,  # Decay rate.
                staircase=True)
        
        optimizer = tf.train.AdamOptimizer(learning_rate)
        training_op = optimizer.minimize(loss, global_step=batch)

    return (loss, training_op)

def acc_model(y, logits):
    #計算正確率   
    with tf.name_scope('accuracy'):
        correct = tf.equal(tf.argmax(logits, 1), y)
        accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

    #計算precision 因返回會有兩個值，只取後者
    with tf.name_scope("precision"):
        _, precision = tf.metrics.precision(predictions = tf.argmax(logits,1), labels=y)

    #計算recall 因返回會有兩個值，只取後者
    with tf.name_scope('recall'):
        _, recall = tf.metrics.recall(predictions = tf.argmax(logits,1), labels=y)

    return (accuracy, precision, recall)


def shuffle_data(data, labels):
    idx = np.random.permutation(len(data))
    data, label = data[idx], labels[idx]
    return (data, label)

# %%
logits = L_layers_model(x, h_units, n_class, 0.5)
loss, train_op = train_op(y, logits)
accuracy, precision, recall = acc_model(y, logits)

checkpoint_dir = 'save/'  # model儲存位址
saver = tf.train.Saver()  # call save function

config = tf.ConfigProto(device_count = {'GPU': 1}) #指定gpu

# %%
# Params for Train
epochs = 100 # 10 for augmented training data, 20 for training data
val_step = 50 # 當 50 步時去算一次驗證資料的正確率
# display_step = 100  # 你可以用這個去建一個規則去看train的正確率，但本專案先不用

# Training cycle
max_acc = 0. # Save the maximum accuracy value for validation data
early_stop_limit = 0 # 紀錄early_stop的值

init = tf.global_variables_initializer()
init_l = tf.local_variables_initializer()

# %%
def run(sess, X_train1, y_train1, X_valid1, y_valid1):
    early_stop_limit = 0
    max_acc = 0.
        
    sess.run([init, init_l])
    summary_writer = tf.summary.FileWriter('tensorbord/', graph=tf.get_default_graph())
    # 可以自己選擇大概要幾個epoch，因為我們有early stop的方法，所以不怕一直train
    for epoch in range(epochs):
        if early_stop_limit >= 200: 
            print('early_stop...........')
            break

        # Random shuffling
        train_data, train_label = shuffle_data(X_train1, y_train1)

        # 用批次的方式去訓練 model
        for i in range(n_batch):
            # Compute the offset of the current minibatch in the data.
            offset = (i * batch_size) % (n_train)
            batch_xs = train_data[offset:(offset + batch_size), :]
            batch_ys = train_label[offset:(offset + batch_size)]
            sess.run([train_op, loss], feed_dict={x: batch_xs, y: batch_ys})

            # 每 n step時，model去看此時的驗證資料的正確率並印出來
            if i % val_step == 0:
                val_acc = sess.run(accuracy, feed_dict={x: X_valid1, y: y_valid1})
                print("Epoch:", '%04d,' % (epoch + 1), 
                      "batch_index %4d/%4d , validation accuracy %.5f" % (i, n_batch, val_acc))

                # 透過最大驗證正確率大於每一次的驗證正確率的條件來設定 early stop
                if max_acc >= val_acc:
                    early_stop_limit += 1
                    if early_stop_limit == 200: # 自己可以去限制最大驗證正確率不再變n次時，就停止訓練
                        break

                # 如果 val_acc 大於 max_acc，則取代它並儲存一次結果
                else: # validation_accuracy > max_acc
                    early_stop_limit = 0
                    max_acc = val_acc
                    saver.save(sess, checkpoint_dir + 'Team07_HW2.ckpt')                        
                    print('Team07_HW2.ckpt-' + 'complete-%04d-' % (epoch + 1) + 
                          "batch_index-%d" % i)

# %%
with tf.Session(config=config) as sess:
    run(sess, X_train1, y_train1, X_valid1, y_valid1)
    
    sess.run(init_l)
    saver.restore(sess, 'save/Team07_HW2.ckpt') # 開啟剛剛 early_stop 的 model

    print('Acc_test :' , sess.run(accuracy, feed_dict={x: X_test1, y: y_test1}))
    print('Prec_value :' , sess.run(precision, feed_dict={x: X_test1, y: y_test1}))
    print('Recall_value :' , sess.run(recall, feed_dict={x: X_test1, y: y_test1}))

    ## model去測試測試集並將label的結果記錄下來 
    pre = sess.run(tf.argmax(logits, 1), feed_dict={x: X_test1})

    ## 列印出測試資料的報表
    print(classification_report(y_test1.ravel(), pre))
# Out:
# Epoch: 0001, batch_index    0/ 560 , validation accuracy 0.18726
# Team07_HW2.ckpt-complete-0001-batch_index-0
# Epoch: 0001, batch_index   50/ 560 , validation accuracy 0.91243
# Team07_HW2.ckpt-complete-0001-batch_index-50
# Epoch: 0001, batch_index  100/ 560 , validation accuracy 0.94019
# Team07_HW2.ckpt-complete-0001-batch_index-100
# Epoch: 0001, batch_index  150/ 560 , validation accuracy 0.95270
# Team07_HW2.ckpt-complete-0001-batch_index-150
# Epoch: 0001, batch_index  200/ 560 , validation accuracy 0.95661
# Team07_HW2.ckpt-complete-0001-batch_index-200
# Epoch: 0001, batch_index  250/ 560 , validation accuracy 0.96638
# Team07_HW2.ckpt-complete-0001-batch_index-250
# Epoch: 0001, batch_index  300/ 560 , validation accuracy 0.96677
# Team07_HW2.ckpt-complete-0001-batch_index-300
# Epoch: 0001, batch_index  350/ 560 , validation accuracy 0.96755
# Team07_HW2.ckpt-complete-0001-batch_index-350
# Epoch: 0001, batch_index  400/ 560 , validation accuracy 0.96912
# Team07_HW2.ckpt-complete-0001-batch_index-400
# Epoch: 0001, batch_index  450/ 560 , validation accuracy 0.96912
# Epoch: 0001, batch_index  500/ 560 , validation accuracy 0.97146
# Team07_HW2.ckpt-complete-0001-batch_index-500
# Epoch: 0001, batch_index  550/ 560 , validation accuracy 0.97146
# Epoch: 0002, batch_index    0/ 560 , validation accuracy 0.97459
# Team07_HW2.ckpt-complete-0002-batch_index-0
# Epoch: 0002, batch_index   50/ 560 , validation accuracy 0.97459
# Epoch: 0002, batch_index  100/ 560 , validation accuracy 0.97381
# Epoch: 0002, batch_index  150/ 560 , validation accuracy 0.97420
# Epoch: 0002, batch_index  200/ 560 , validation accuracy 0.97498
# Team07_HW2.ckpt-complete-0002-batch_index-200
# Epoch: 0002, batch_index  250/ 560 , validation accuracy 0.97303
# Epoch: 0002, batch_index  300/ 560 , validation accuracy 0.97889
# Team07_HW2.ckpt-complete-0002-batch_index-300
# Epoch: 0002, batch_index  350/ 560 , validation accuracy 0.97850
# Epoch: 0002, batch_index  400/ 560 , validation accuracy 0.97498
# Epoch: 0002, batch_index  450/ 560 , validation accuracy 0.97850
# Epoch: 0002, batch_index  500/ 560 , validation accuracy 0.98163
# Team07_HW2.ckpt-complete-0002-batch_index-500
# Epoch: 0002, batch_index  550/ 560 , validation accuracy 0.97654
# Epoch: 0003, batch_index    0/ 560 , validation accuracy 0.97694
# Epoch: 0003, batch_index   50/ 560 , validation accuracy 0.97889
# Epoch: 0003, batch_index  100/ 560 , validation accuracy 0.97811
# Epoch: 0003, batch_index  150/ 560 , validation accuracy 0.98006
# Epoch: 0003, batch_index  200/ 560 , validation accuracy 0.98084
# Epoch: 0003, batch_index  250/ 560 , validation accuracy 0.97889
# Epoch: 0003, batch_index  300/ 560 , validation accuracy 0.97889
# Epoch: 0003, batch_index  350/ 560 , validation accuracy 0.98124
# Epoch: 0003, batch_index  400/ 560 , validation accuracy 0.98241
# Team07_HW2.ckpt-complete-0003-batch_index-400
# Epoch: 0003, batch_index  450/ 560 , validation accuracy 0.97967
# Epoch: 0003, batch_index  500/ 560 , validation accuracy 0.98319
# Team07_HW2.ckpt-complete-0003-batch_index-500
# Epoch: 0003, batch_index  550/ 560 , validation accuracy 0.98397
# Team07_HW2.ckpt-complete-0003-batch_index-550
# Epoch: 0004, batch_index    0/ 560 , validation accuracy 0.98397
# Team07_HW2.ckpt-complete-0004-batch_index-0
# Epoch: 0004, batch_index   50/ 560 , validation accuracy 0.98397
# Epoch: 0004, batch_index  100/ 560 , validation accuracy 0.98319
# Epoch: 0004, batch_index  150/ 560 , validation accuracy 0.98241
# Epoch: 0004, batch_index  200/ 560 , validation accuracy 0.98436
# Team07_HW2.ckpt-complete-0004-batch_index-200
# Epoch: 0004, batch_index  250/ 560 , validation accuracy 0.98358
# Epoch: 0004, batch_index  300/ 560 , validation accuracy 0.98397
# Epoch: 0004, batch_index  350/ 560 , validation accuracy 0.98436
# Epoch: 0004, batch_index  400/ 560 , validation accuracy 0.98241
# Epoch: 0004, batch_index  450/ 560 , validation accuracy 0.98514
# Team07_HW2.ckpt-complete-0004-batch_index-450
# Epoch: 0004, batch_index  500/ 560 , validation accuracy 0.98280
# Epoch: 0004, batch_index  550/ 560 , validation accuracy 0.98671
# Team07_HW2.ckpt-complete-0004-batch_index-550
# Epoch: 0005, batch_index    0/ 560 , validation accuracy 0.98241
# Epoch: 0005, batch_index   50/ 560 , validation accuracy 0.98593
# Epoch: 0005, batch_index  100/ 560 , validation accuracy 0.98671
# Team07_HW2.ckpt-complete-0005-batch_index-100
# Epoch: 0005, batch_index  150/ 560 , validation accuracy 0.98514
# Epoch: 0005, batch_index  200/ 560 , validation accuracy 0.98280
# Epoch: 0005, batch_index  250/ 560 , validation accuracy 0.98632
# Epoch: 0005, batch_index  300/ 560 , validation accuracy 0.98436
# Epoch: 0005, batch_index  350/ 560 , validation accuracy 0.98475
# Epoch: 0005, batch_index  400/ 560 , validation accuracy 0.98475
# Epoch: 0005, batch_index  450/ 560 , validation accuracy 0.98671
# Epoch: 0005, batch_index  500/ 560 , validation accuracy 0.98593
# Epoch: 0005, batch_index  550/ 560 , validation accuracy 0.98749
# Team07_HW2.ckpt-complete-0005-batch_index-550
# Epoch: 0006, batch_index    0/ 560 , validation accuracy 0.98593
# Epoch: 0006, batch_index   50/ 560 , validation accuracy 0.98554
# Epoch: 0006, batch_index  100/ 560 , validation accuracy 0.98749
# Epoch: 0006, batch_index  150/ 560 , validation accuracy 0.98554
# Epoch: 0006, batch_index  200/ 560 , validation accuracy 0.98632
# Epoch: 0006, batch_index  250/ 560 , validation accuracy 0.98749
# Epoch: 0006, batch_index  300/ 560 , validation accuracy 0.98710
# Epoch: 0006, batch_index  350/ 560 , validation accuracy 0.98710
# Epoch: 0006, batch_index  400/ 560 , validation accuracy 0.98671
# Epoch: 0006, batch_index  450/ 560 , validation accuracy 0.98593
# Epoch: 0006, batch_index  500/ 560 , validation accuracy 0.98710
# Epoch: 0006, batch_index  550/ 560 , validation accuracy 0.98710
# Epoch: 0007, batch_index    0/ 560 , validation accuracy 0.98554
# Epoch: 0007, batch_index   50/ 560 , validation accuracy 0.98671
# Epoch: 0007, batch_index  100/ 560 , validation accuracy 0.98749
# Epoch: 0007, batch_index  150/ 560 , validation accuracy 0.98710
# Epoch: 0007, batch_index  200/ 560 , validation accuracy 0.98710
# Epoch: 0007, batch_index  250/ 560 , validation accuracy 0.98632
# Epoch: 0007, batch_index  300/ 560 , validation accuracy 0.98436
# Epoch: 0007, batch_index  350/ 560 , validation accuracy 0.98554
# Epoch: 0007, batch_index  400/ 560 , validation accuracy 0.98632
# Epoch: 0007, batch_index  450/ 560 , validation accuracy 0.98632
# Epoch: 0007, batch_index  500/ 560 , validation accuracy 0.98866
# Team07_HW2.ckpt-complete-0007-batch_index-500
# Epoch: 0007, batch_index  550/ 560 , validation accuracy 0.98827
# Epoch: 0008, batch_index    0/ 560 , validation accuracy 0.98749
# Epoch: 0008, batch_index   50/ 560 , validation accuracy 0.98593
# Epoch: 0008, batch_index  100/ 560 , validation accuracy 0.98710
# Epoch: 0008, batch_index  150/ 560 , validation accuracy 0.98788
# Epoch: 0008, batch_index  200/ 560 , validation accuracy 0.98905
# Team07_HW2.ckpt-complete-0008-batch_index-200
# Epoch: 0008, batch_index  250/ 560 , validation accuracy 0.98475
# Epoch: 0008, batch_index  300/ 560 , validation accuracy 0.98632
# Epoch: 0008, batch_index  350/ 560 , validation accuracy 0.98749
# Epoch: 0008, batch_index  400/ 560 , validation accuracy 0.98827
# Epoch: 0008, batch_index  450/ 560 , validation accuracy 0.98475
# Epoch: 0008, batch_index  500/ 560 , validation accuracy 0.98671
# Epoch: 0008, batch_index  550/ 560 , validation accuracy 0.98554
# Epoch: 0009, batch_index    0/ 560 , validation accuracy 0.98710
# Epoch: 0009, batch_index   50/ 560 , validation accuracy 0.98866
# Epoch: 0009, batch_index  100/ 560 , validation accuracy 0.98827
# Epoch: 0009, batch_index  150/ 560 , validation accuracy 0.98905
# Epoch: 0009, batch_index  200/ 560 , validation accuracy 0.98788
# Epoch: 0009, batch_index  250/ 560 , validation accuracy 0.98866
# Epoch: 0009, batch_index  300/ 560 , validation accuracy 0.98671
# Epoch: 0009, batch_index  350/ 560 , validation accuracy 0.98944
# Team07_HW2.ckpt-complete-0009-batch_index-350
# Epoch: 0009, batch_index  400/ 560 , validation accuracy 0.98671
# Epoch: 0009, batch_index  450/ 560 , validation accuracy 0.98514
# Epoch: 0009, batch_index  500/ 560 , validation accuracy 0.98788
# Epoch: 0009, batch_index  550/ 560 , validation accuracy 0.98788
# Epoch: 0010, batch_index    0/ 560 , validation accuracy 0.98788
# Epoch: 0010, batch_index   50/ 560 , validation accuracy 0.98827
# Epoch: 0010, batch_index  100/ 560 , validation accuracy 0.98749
# Epoch: 0010, batch_index  150/ 560 , validation accuracy 0.98788
# Epoch: 0010, batch_index  200/ 560 , validation accuracy 0.98866
# Epoch: 0010, batch_index  250/ 560 , validation accuracy 0.98905
# Epoch: 0010, batch_index  300/ 560 , validation accuracy 0.98788
# Epoch: 0010, batch_index  350/ 560 , validation accuracy 0.98905
# Epoch: 0010, batch_index  400/ 560 , validation accuracy 0.98710
# Epoch: 0010, batch_index  450/ 560 , validation accuracy 0.98827
# Epoch: 0010, batch_index  500/ 560 , validation accuracy 0.98905
# Epoch: 0010, batch_index  550/ 560 , validation accuracy 0.98827
# Epoch: 0011, batch_index    0/ 560 , validation accuracy 0.98632
# Epoch: 0011, batch_index   50/ 560 , validation accuracy 0.98866
# Epoch: 0011, batch_index  100/ 560 , validation accuracy 0.98632
# Epoch: 0011, batch_index  150/ 560 , validation accuracy 0.98905
# Epoch: 0011, batch_index  200/ 560 , validation accuracy 0.98905
# Epoch: 0011, batch_index  250/ 560 , validation accuracy 0.98827
# Epoch: 0011, batch_index  300/ 560 , validation accuracy 0.98671
# Epoch: 0011, batch_index  350/ 560 , validation accuracy 0.98788
# Epoch: 0011, batch_index  400/ 560 , validation accuracy 0.98749
# Epoch: 0011, batch_index  450/ 560 , validation accuracy 0.98788
# Epoch: 0011, batch_index  500/ 560 , validation accuracy 0.98827
# Epoch: 0011, batch_index  550/ 560 , validation accuracy 0.98827
# Epoch: 0012, batch_index    0/ 560 , validation accuracy 0.98944
# Epoch: 0012, batch_index   50/ 560 , validation accuracy 0.98827
# Epoch: 0012, batch_index  100/ 560 , validation accuracy 0.98671
# Epoch: 0012, batch_index  150/ 560 , validation accuracy 0.98788
# Epoch: 0012, batch_index  200/ 560 , validation accuracy 0.98710
# Epoch: 0012, batch_index  250/ 560 , validation accuracy 0.98593
# Epoch: 0012, batch_index  300/ 560 , validation accuracy 0.98788
# Epoch: 0012, batch_index  350/ 560 , validation accuracy 0.98827
# Epoch: 0012, batch_index  400/ 560 , validation accuracy 0.98827
# Epoch: 0012, batch_index  450/ 560 , validation accuracy 0.99023
# Team07_HW2.ckpt-complete-0012-batch_index-450
# Epoch: 0012, batch_index  500/ 560 , validation accuracy 0.98944
# Epoch: 0012, batch_index  550/ 560 , validation accuracy 0.99023
# Epoch: 0013, batch_index    0/ 560 , validation accuracy 0.98944
# Epoch: 0013, batch_index   50/ 560 , validation accuracy 0.99023
# Epoch: 0013, batch_index  100/ 560 , validation accuracy 0.99023
# Epoch: 0013, batch_index  150/ 560 , validation accuracy 0.98984
# Epoch: 0013, batch_index  200/ 560 , validation accuracy 0.98788
# Epoch: 0013, batch_index  250/ 560 , validation accuracy 0.98749
# Epoch: 0013, batch_index  300/ 560 , validation accuracy 0.98866
# Epoch: 0013, batch_index  350/ 560 , validation accuracy 0.98866
# Epoch: 0013, batch_index  400/ 560 , validation accuracy 0.98866
# Epoch: 0013, batch_index  450/ 560 , validation accuracy 0.98788
# Epoch: 0013, batch_index  500/ 560 , validation accuracy 0.98984
# Epoch: 0013, batch_index  550/ 560 , validation accuracy 0.98866
# Epoch: 0014, batch_index    0/ 560 , validation accuracy 0.98671
# Epoch: 0014, batch_index   50/ 560 , validation accuracy 0.99101
# Team07_HW2.ckpt-complete-0014-batch_index-50
# Epoch: 0014, batch_index  100/ 560 , validation accuracy 0.98984
# Epoch: 0014, batch_index  150/ 560 , validation accuracy 0.98866
# Epoch: 0014, batch_index  200/ 560 , validation accuracy 0.98827
# Epoch: 0014, batch_index  250/ 560 , validation accuracy 0.98905
# Epoch: 0014, batch_index  300/ 560 , validation accuracy 0.98984
# Epoch: 0014, batch_index  350/ 560 , validation accuracy 0.98866
# Epoch: 0014, batch_index  400/ 560 , validation accuracy 0.98866
# Epoch: 0014, batch_index  450/ 560 , validation accuracy 0.98984
# Epoch: 0014, batch_index  500/ 560 , validation accuracy 0.98827
# Epoch: 0014, batch_index  550/ 560 , validation accuracy 0.98710
# Epoch: 0015, batch_index    0/ 560 , validation accuracy 0.98905
# Epoch: 0015, batch_index   50/ 560 , validation accuracy 0.98866
# Epoch: 0015, batch_index  100/ 560 , validation accuracy 0.98827
# Epoch: 0015, batch_index  150/ 560 , validation accuracy 0.98866
# Epoch: 0015, batch_index  200/ 560 , validation accuracy 0.98944
# Epoch: 0015, batch_index  250/ 560 , validation accuracy 0.99101
# Epoch: 0015, batch_index  300/ 560 , validation accuracy 0.99023
# Epoch: 0015, batch_index  350/ 560 , validation accuracy 0.99062
# Epoch: 0015, batch_index  400/ 560 , validation accuracy 0.98749
# Epoch: 0015, batch_index  450/ 560 , validation accuracy 0.98632
# Epoch: 0015, batch_index  500/ 560 , validation accuracy 0.98944
# Epoch: 0015, batch_index  550/ 560 , validation accuracy 0.98905
# Epoch: 0016, batch_index    0/ 560 , validation accuracy 0.98827
# Epoch: 0016, batch_index   50/ 560 , validation accuracy 0.98827
# Epoch: 0016, batch_index  100/ 560 , validation accuracy 0.98905
# Epoch: 0016, batch_index  150/ 560 , validation accuracy 0.98788
# Epoch: 0016, batch_index  200/ 560 , validation accuracy 0.98905
# Epoch: 0016, batch_index  250/ 560 , validation accuracy 0.98944
# Epoch: 0016, batch_index  300/ 560 , validation accuracy 0.98827
# Epoch: 0016, batch_index  350/ 560 , validation accuracy 0.98944
# Epoch: 0016, batch_index  400/ 560 , validation accuracy 0.98866
# Epoch: 0016, batch_index  450/ 560 , validation accuracy 0.99062
# Epoch: 0016, batch_index  500/ 560 , validation accuracy 0.98827
# Epoch: 0016, batch_index  550/ 560 , validation accuracy 0.98788
# Epoch: 0017, batch_index    0/ 560 , validation accuracy 0.98788
# Epoch: 0017, batch_index   50/ 560 , validation accuracy 0.98905
# Epoch: 0017, batch_index  100/ 560 , validation accuracy 0.98944
# Epoch: 0017, batch_index  150/ 560 , validation accuracy 0.98905
# Epoch: 0017, batch_index  200/ 560 , validation accuracy 0.98944
# Epoch: 0017, batch_index  250/ 560 , validation accuracy 0.98671
# Epoch: 0017, batch_index  300/ 560 , validation accuracy 0.98944
# Epoch: 0017, batch_index  350/ 560 , validation accuracy 0.98866
# Epoch: 0017, batch_index  400/ 560 , validation accuracy 0.98944
# Epoch: 0017, batch_index  450/ 560 , validation accuracy 0.98905
# Epoch: 0017, batch_index  500/ 560 , validation accuracy 0.98749
# Epoch: 0017, batch_index  550/ 560 , validation accuracy 0.98749
# Epoch: 0018, batch_index    0/ 560 , validation accuracy 0.98749
# Epoch: 0018, batch_index   50/ 560 , validation accuracy 0.98749
# Epoch: 0018, batch_index  100/ 560 , validation accuracy 0.98827
# Epoch: 0018, batch_index  150/ 560 , validation accuracy 0.98944
# Epoch: 0018, batch_index  200/ 560 , validation accuracy 0.98944
# Epoch: 0018, batch_index  250/ 560 , validation accuracy 0.98944
# Epoch: 0018, batch_index  300/ 560 , validation accuracy 0.98944
# Epoch: 0018, batch_index  350/ 560 , validation accuracy 0.99023
# Epoch: 0018, batch_index  400/ 560 , validation accuracy 0.98866
# Epoch: 0018, batch_index  450/ 560 , validation accuracy 0.98944
# Epoch: 0018, batch_index  500/ 560 , validation accuracy 0.98905
# Epoch: 0018, batch_index  550/ 560 , validation accuracy 0.99062
# Epoch: 0019, batch_index    0/ 560 , validation accuracy 0.98905
# Epoch: 0019, batch_index   50/ 560 , validation accuracy 0.99023
# Epoch: 0019, batch_index  100/ 560 , validation accuracy 0.98944
# Epoch: 0019, batch_index  150/ 560 , validation accuracy 0.99023
# Epoch: 0019, batch_index  200/ 560 , validation accuracy 0.98866
# Epoch: 0019, batch_index  250/ 560 , validation accuracy 0.99023
# Epoch: 0019, batch_index  300/ 560 , validation accuracy 0.98944
# Epoch: 0019, batch_index  350/ 560 , validation accuracy 0.98984
# Epoch: 0019, batch_index  400/ 560 , validation accuracy 0.98944
# Epoch: 0019, batch_index  450/ 560 , validation accuracy 0.99023
# Epoch: 0019, batch_index  500/ 560 , validation accuracy 0.98905
# Epoch: 0019, batch_index  550/ 560 , validation accuracy 0.98905
# Epoch: 0020, batch_index    0/ 560 , validation accuracy 0.99023
# Epoch: 0020, batch_index   50/ 560 , validation accuracy 0.98944
# Epoch: 0020, batch_index  100/ 560 , validation accuracy 0.98866
# Epoch: 0020, batch_index  150/ 560 , validation accuracy 0.98984
# Epoch: 0020, batch_index  200/ 560 , validation accuracy 0.98671
# Epoch: 0020, batch_index  250/ 560 , validation accuracy 0.98944
# Epoch: 0020, batch_index  300/ 560 , validation accuracy 0.98905
# Epoch: 0020, batch_index  350/ 560 , validation accuracy 0.98984
# Epoch: 0020, batch_index  400/ 560 , validation accuracy 0.98944
# Epoch: 0020, batch_index  450/ 560 , validation accuracy 0.98944
# Epoch: 0020, batch_index  500/ 560 , validation accuracy 0.99023
# Epoch: 0020, batch_index  550/ 560 , validation accuracy 0.98944
# Epoch: 0021, batch_index    0/ 560 , validation accuracy 0.98749
# Epoch: 0021, batch_index   50/ 560 , validation accuracy 0.98944
# Epoch: 0021, batch_index  100/ 560 , validation accuracy 0.98944
# Epoch: 0021, batch_index  150/ 560 , validation accuracy 0.98905
# Epoch: 0021, batch_index  200/ 560 , validation accuracy 0.99062
# Epoch: 0021, batch_index  250/ 560 , validation accuracy 0.98905
# Epoch: 0021, batch_index  300/ 560 , validation accuracy 0.98866
# Epoch: 0021, batch_index  350/ 560 , validation accuracy 0.98944
# Epoch: 0021, batch_index  400/ 560 , validation accuracy 0.99023
# Epoch: 0021, batch_index  450/ 560 , validation accuracy 0.98905
# Epoch: 0021, batch_index  500/ 560 , validation accuracy 0.99062
# Epoch: 0021, batch_index  550/ 560 , validation accuracy 0.98788
# Epoch: 0022, batch_index    0/ 560 , validation accuracy 0.98827
# Epoch: 0022, batch_index   50/ 560 , validation accuracy 0.98866
# Epoch: 0022, batch_index  100/ 560 , validation accuracy 0.98984
# Epoch: 0022, batch_index  150/ 560 , validation accuracy 0.98944
# Epoch: 0022, batch_index  200/ 560 , validation accuracy 0.98827
# Epoch: 0022, batch_index  250/ 560 , validation accuracy 0.98905
# Epoch: 0022, batch_index  300/ 560 , validation accuracy 0.99023
# Epoch: 0022, batch_index  350/ 560 , validation accuracy 0.99101
# Epoch: 0022, batch_index  400/ 560 , validation accuracy 0.99101
# Team07_HW2.ckpt-complete-0022-batch_index-400
# Epoch: 0022, batch_index  450/ 560 , validation accuracy 0.99023
# Epoch: 0022, batch_index  500/ 560 , validation accuracy 0.98905
# Epoch: 0022, batch_index  550/ 560 , validation accuracy 0.98905
# Epoch: 0023, batch_index    0/ 560 , validation accuracy 0.99023
# Epoch: 0023, batch_index   50/ 560 , validation accuracy 0.98984
# Epoch: 0023, batch_index  100/ 560 , validation accuracy 0.98905
# Epoch: 0023, batch_index  150/ 560 , validation accuracy 0.98866
# Epoch: 0023, batch_index  200/ 560 , validation accuracy 0.98944
# Epoch: 0023, batch_index  250/ 560 , validation accuracy 0.98866
# Epoch: 0023, batch_index  300/ 560 , validation accuracy 0.98788
# Epoch: 0023, batch_index  350/ 560 , validation accuracy 0.98905
# Epoch: 0023, batch_index  400/ 560 , validation accuracy 0.98944
# Epoch: 0023, batch_index  450/ 560 , validation accuracy 0.98944
# Epoch: 0023, batch_index  500/ 560 , validation accuracy 0.99023
# Epoch: 0023, batch_index  550/ 560 , validation accuracy 0.99140
# Team07_HW2.ckpt-complete-0023-batch_index-550
# Epoch: 0024, batch_index    0/ 560 , validation accuracy 0.99062
# Epoch: 0024, batch_index   50/ 560 , validation accuracy 0.98984
# Epoch: 0024, batch_index  100/ 560 , validation accuracy 0.98984
# Epoch: 0024, batch_index  150/ 560 , validation accuracy 0.98984
# Epoch: 0024, batch_index  200/ 560 , validation accuracy 0.98905
# Epoch: 0024, batch_index  250/ 560 , validation accuracy 0.98944
# Epoch: 0024, batch_index  300/ 560 , validation accuracy 0.98905
# Epoch: 0024, batch_index  350/ 560 , validation accuracy 0.98905
# Epoch: 0024, batch_index  400/ 560 , validation accuracy 0.98944
# Epoch: 0024, batch_index  450/ 560 , validation accuracy 0.98827
# Epoch: 0024, batch_index  500/ 560 , validation accuracy 0.99101
# Epoch: 0024, batch_index  550/ 560 , validation accuracy 0.99023
# Epoch: 0025, batch_index    0/ 560 , validation accuracy 0.99023
# Epoch: 0025, batch_index   50/ 560 , validation accuracy 0.99062
# Epoch: 0025, batch_index  100/ 560 , validation accuracy 0.99101
# Epoch: 0025, batch_index  150/ 560 , validation accuracy 0.99023
# Epoch: 0025, batch_index  200/ 560 , validation accuracy 0.99023
# Epoch: 0025, batch_index  250/ 560 , validation accuracy 0.99023
# Epoch: 0025, batch_index  300/ 560 , validation accuracy 0.99023
# Epoch: 0025, batch_index  350/ 560 , validation accuracy 0.99023
# Epoch: 0025, batch_index  400/ 560 , validation accuracy 0.98944
# Epoch: 0025, batch_index  450/ 560 , validation accuracy 0.99023
# Epoch: 0025, batch_index  500/ 560 , validation accuracy 0.99023
# Epoch: 0025, batch_index  550/ 560 , validation accuracy 0.99023
# Epoch: 0026, batch_index    0/ 560 , validation accuracy 0.99062
# Epoch: 0026, batch_index   50/ 560 , validation accuracy 0.98866
# Epoch: 0026, batch_index  100/ 560 , validation accuracy 0.99023
# Epoch: 0026, batch_index  150/ 560 , validation accuracy 0.99023
# Epoch: 0026, batch_index  200/ 560 , validation accuracy 0.98944
# Epoch: 0026, batch_index  250/ 560 , validation accuracy 0.98984
# Epoch: 0026, batch_index  300/ 560 , validation accuracy 0.99062
# Epoch: 0026, batch_index  350/ 560 , validation accuracy 0.99062
# Epoch: 0026, batch_index  400/ 560 , validation accuracy 0.99062
# Epoch: 0026, batch_index  450/ 560 , validation accuracy 0.99062
# Epoch: 0026, batch_index  500/ 560 , validation accuracy 0.99023
# Epoch: 0026, batch_index  550/ 560 , validation accuracy 0.99062
# Epoch: 0027, batch_index    0/ 560 , validation accuracy 0.99062
# Epoch: 0027, batch_index   50/ 560 , validation accuracy 0.98984
# Epoch: 0027, batch_index  100/ 560 , validation accuracy 0.98944
# Epoch: 0027, batch_index  150/ 560 , validation accuracy 0.98984
# Epoch: 0027, batch_index  200/ 560 , validation accuracy 0.98944
# Epoch: 0027, batch_index  250/ 560 , validation accuracy 0.98944
# Epoch: 0027, batch_index  300/ 560 , validation accuracy 0.98905
# Epoch: 0027, batch_index  350/ 560 , validation accuracy 0.98944
# Epoch: 0027, batch_index  400/ 560 , validation accuracy 0.98984
# Epoch: 0027, batch_index  450/ 560 , validation accuracy 0.98984
# Epoch: 0027, batch_index  500/ 560 , validation accuracy 0.98866
# Epoch: 0027, batch_index  550/ 560 , validation accuracy 0.98984
# Epoch: 0028, batch_index    0/ 560 , validation accuracy 0.98944
# Epoch: 0028, batch_index   50/ 560 , validation accuracy 0.99023
# Epoch: 0028, batch_index  100/ 560 , validation accuracy 0.99140
# Epoch: 0028, batch_index  150/ 560 , validation accuracy 0.99062
# Epoch: 0028, batch_index  200/ 560 , validation accuracy 0.98944
# Epoch: 0028, batch_index  250/ 560 , validation accuracy 0.98905
# Epoch: 0028, batch_index  300/ 560 , validation accuracy 0.98866
# Epoch: 0028, batch_index  350/ 560 , validation accuracy 0.99062
# Epoch: 0028, batch_index  400/ 560 , validation accuracy 0.99023
# Epoch: 0028, batch_index  450/ 560 , validation accuracy 0.98905
# Epoch: 0028, batch_index  500/ 560 , validation accuracy 0.98827
# Epoch: 0028, batch_index  550/ 560 , validation accuracy 0.98905
# Epoch: 0029, batch_index    0/ 560 , validation accuracy 0.98749
# Epoch: 0029, batch_index   50/ 560 , validation accuracy 0.98905
# Epoch: 0029, batch_index  100/ 560 , validation accuracy 0.98944
# Epoch: 0029, batch_index  150/ 560 , validation accuracy 0.98984
# Epoch: 0029, batch_index  200/ 560 , validation accuracy 0.98984
# Epoch: 0029, batch_index  250/ 560 , validation accuracy 0.98866
# Epoch: 0029, batch_index  300/ 560 , validation accuracy 0.99101
# Epoch: 0029, batch_index  350/ 560 , validation accuracy 0.99023
# Epoch: 0029, batch_index  400/ 560 , validation accuracy 0.99140
# Epoch: 0029, batch_index  450/ 560 , validation accuracy 0.98984
# Epoch: 0029, batch_index  500/ 560 , validation accuracy 0.98905
# Epoch: 0029, batch_index  550/ 560 , validation accuracy 0.98984
# Epoch: 0030, batch_index    0/ 560 , validation accuracy 0.98905
# Epoch: 0030, batch_index   50/ 560 , validation accuracy 0.98905
# Epoch: 0030, batch_index  100/ 560 , validation accuracy 0.99140
# Epoch: 0030, batch_index  150/ 560 , validation accuracy 0.99062
# Epoch: 0030, batch_index  200/ 560 , validation accuracy 0.98905
# Epoch: 0030, batch_index  250/ 560 , validation accuracy 0.99101
# Epoch: 0030, batch_index  300/ 560 , validation accuracy 0.98944
# Epoch: 0030, batch_index  350/ 560 , validation accuracy 0.98984
# Epoch: 0030, batch_index  400/ 560 , validation accuracy 0.98984
# Epoch: 0030, batch_index  450/ 560 , validation accuracy 0.98944
# Epoch: 0030, batch_index  500/ 560 , validation accuracy 0.99101
# Epoch: 0030, batch_index  550/ 560 , validation accuracy 0.99062
# Epoch: 0031, batch_index    0/ 560 , validation accuracy 0.99062
# Epoch: 0031, batch_index   50/ 560 , validation accuracy 0.99101
# Epoch: 0031, batch_index  100/ 560 , validation accuracy 0.99062
# Epoch: 0031, batch_index  150/ 560 , validation accuracy 0.98944
# Epoch: 0031, batch_index  200/ 560 , validation accuracy 0.99062
# Epoch: 0031, batch_index  250/ 560 , validation accuracy 0.98984
# Epoch: 0031, batch_index  300/ 560 , validation accuracy 0.98905
# Epoch: 0031, batch_index  350/ 560 , validation accuracy 0.98944
# Epoch: 0031, batch_index  400/ 560 , validation accuracy 0.98866
# Epoch: 0031, batch_index  450/ 560 , validation accuracy 0.99062
# Epoch: 0031, batch_index  500/ 560 , validation accuracy 0.99023
# Epoch: 0031, batch_index  550/ 560 , validation accuracy 0.98905
# Epoch: 0032, batch_index    0/ 560 , validation accuracy 0.98944
# Epoch: 0032, batch_index   50/ 560 , validation accuracy 0.98905
# Epoch: 0032, batch_index  100/ 560 , validation accuracy 0.99023
# Epoch: 0032, batch_index  150/ 560 , validation accuracy 0.98944
# Epoch: 0032, batch_index  200/ 560 , validation accuracy 0.98944
# Epoch: 0032, batch_index  250/ 560 , validation accuracy 0.98984
# Epoch: 0032, batch_index  300/ 560 , validation accuracy 0.98984
# Epoch: 0032, batch_index  350/ 560 , validation accuracy 0.98984
# Epoch: 0032, batch_index  400/ 560 , validation accuracy 0.98984
# Epoch: 0032, batch_index  450/ 560 , validation accuracy 0.99023
# Epoch: 0032, batch_index  500/ 560 , validation accuracy 0.98944
# Epoch: 0032, batch_index  550/ 560 , validation accuracy 0.98984
# Epoch: 0033, batch_index    0/ 560 , validation accuracy 0.98944
# Epoch: 0033, batch_index   50/ 560 , validation accuracy 0.98984
# Epoch: 0033, batch_index  100/ 560 , validation accuracy 0.98788
# Epoch: 0033, batch_index  150/ 560 , validation accuracy 0.98984
# Epoch: 0033, batch_index  200/ 560 , validation accuracy 0.98905
# Epoch: 0033, batch_index  250/ 560 , validation accuracy 0.98984
# Epoch: 0033, batch_index  300/ 560 , validation accuracy 0.98905
# Epoch: 0033, batch_index  350/ 560 , validation accuracy 0.98905
# Epoch: 0033, batch_index  400/ 560 , validation accuracy 0.98905
# Epoch: 0033, batch_index  450/ 560 , validation accuracy 0.99062
# Epoch: 0033, batch_index  500/ 560 , validation accuracy 0.98984
# Epoch: 0033, batch_index  550/ 560 , validation accuracy 0.99101
# Epoch: 0034, batch_index    0/ 560 , validation accuracy 0.99101
# Epoch: 0034, batch_index   50/ 560 , validation accuracy 0.98984
# Epoch: 0034, batch_index  100/ 560 , validation accuracy 0.99023
# Epoch: 0034, batch_index  150/ 560 , validation accuracy 0.98944
# Epoch: 0034, batch_index  200/ 560 , validation accuracy 0.98944
# Epoch: 0034, batch_index  250/ 560 , validation accuracy 0.98984
# Epoch: 0034, batch_index  300/ 560 , validation accuracy 0.98984
# Epoch: 0034, batch_index  350/ 560 , validation accuracy 0.98984
# Epoch: 0034, batch_index  400/ 560 , validation accuracy 0.98984
# Epoch: 0034, batch_index  450/ 560 , validation accuracy 0.99023
# Epoch: 0034, batch_index  500/ 560 , validation accuracy 0.98984
# Epoch: 0034, batch_index  550/ 560 , validation accuracy 0.98866
# Epoch: 0035, batch_index    0/ 560 , validation accuracy 0.98827
# Epoch: 0035, batch_index   50/ 560 , validation accuracy 0.98984
# Epoch: 0035, batch_index  100/ 560 , validation accuracy 0.98905
# Epoch: 0035, batch_index  150/ 560 , validation accuracy 0.99023
# Epoch: 0035, batch_index  200/ 560 , validation accuracy 0.99023
# Epoch: 0035, batch_index  250/ 560 , validation accuracy 0.98905
# Epoch: 0035, batch_index  300/ 560 , validation accuracy 0.99023
# Epoch: 0035, batch_index  350/ 560 , validation accuracy 0.99023
# Epoch: 0035, batch_index  400/ 560 , validation accuracy 0.99062
# Epoch: 0035, batch_index  450/ 560 , validation accuracy 0.98866
# Epoch: 0035, batch_index  500/ 560 , validation accuracy 0.98944
# Epoch: 0035, batch_index  550/ 560 , validation accuracy 0.98866
# Epoch: 0036, batch_index    0/ 560 , validation accuracy 0.98905
# Epoch: 0036, batch_index   50/ 560 , validation accuracy 0.98866
# Epoch: 0036, batch_index  100/ 560 , validation accuracy 0.98944
# Epoch: 0036, batch_index  150/ 560 , validation accuracy 0.98984
# Epoch: 0036, batch_index  200/ 560 , validation accuracy 0.98984
# Epoch: 0036, batch_index  250/ 560 , validation accuracy 0.98984
# Epoch: 0036, batch_index  300/ 560 , validation accuracy 0.99023
# Epoch: 0036, batch_index  350/ 560 , validation accuracy 0.98984
# Epoch: 0036, batch_index  400/ 560 , validation accuracy 0.98905
# Epoch: 0036, batch_index  450/ 560 , validation accuracy 0.98905
# Epoch: 0036, batch_index  500/ 560 , validation accuracy 0.98984
# Epoch: 0036, batch_index  550/ 560 , validation accuracy 0.99101
# Epoch: 0037, batch_index    0/ 560 , validation accuracy 0.99101
# Epoch: 0037, batch_index   50/ 560 , validation accuracy 0.99062
# Epoch: 0037, batch_index  100/ 560 , validation accuracy 0.98944
# Epoch: 0037, batch_index  150/ 560 , validation accuracy 0.99023
# Epoch: 0037, batch_index  200/ 560 , validation accuracy 0.98984
# Epoch: 0037, batch_index  250/ 560 , validation accuracy 0.99101
# Epoch: 0037, batch_index  300/ 560 , validation accuracy 0.99062
# Epoch: 0037, batch_index  350/ 560 , validation accuracy 0.99062
# Epoch: 0037, batch_index  400/ 560 , validation accuracy 0.99101
# Epoch: 0037, batch_index  450/ 560 , validation accuracy 0.99062
# Epoch: 0037, batch_index  500/ 560 , validation accuracy 0.98984
# Epoch: 0037, batch_index  550/ 560 , validation accuracy 0.98944
# Epoch: 0038, batch_index    0/ 560 , validation accuracy 0.98905
# Epoch: 0038, batch_index   50/ 560 , validation accuracy 0.98905
# Epoch: 0038, batch_index  100/ 560 , validation accuracy 0.98905
# Epoch: 0038, batch_index  150/ 560 , validation accuracy 0.98984
# Epoch: 0038, batch_index  200/ 560 , validation accuracy 0.99062
# Epoch: 0038, batch_index  250/ 560 , validation accuracy 0.99023
# Epoch: 0038, batch_index  300/ 560 , validation accuracy 0.98984
# Epoch: 0038, batch_index  350/ 560 , validation accuracy 0.98944
# Epoch: 0038, batch_index  400/ 560 , validation accuracy 0.98984
# Epoch: 0038, batch_index  450/ 560 , validation accuracy 0.98984
# Epoch: 0038, batch_index  500/ 560 , validation accuracy 0.98984
# Epoch: 0038, batch_index  550/ 560 , validation accuracy 0.98944
# Epoch: 0039, batch_index    0/ 560 , validation accuracy 0.98944
# Epoch: 0039, batch_index   50/ 560 , validation accuracy 0.99023
# Epoch: 0039, batch_index  100/ 560 , validation accuracy 0.99023
# Epoch: 0039, batch_index  150/ 560 , validation accuracy 0.98984
# Epoch: 0039, batch_index  200/ 560 , validation accuracy 0.98984
# Epoch: 0039, batch_index  250/ 560 , validation accuracy 0.98984
# Epoch: 0039, batch_index  300/ 560 , validation accuracy 0.99023
# Epoch: 0039, batch_index  350/ 560 , validation accuracy 0.98905
# Epoch: 0039, batch_index  400/ 560 , validation accuracy 0.98984
# Epoch: 0039, batch_index  450/ 560 , validation accuracy 0.98944
# Epoch: 0039, batch_index  500/ 560 , validation accuracy 0.98984
# Epoch: 0039, batch_index  550/ 560 , validation accuracy 0.99023
# Epoch: 0040, batch_index    0/ 560 , validation accuracy 0.99023
# Epoch: 0040, batch_index   50/ 560 , validation accuracy 0.99062
# Epoch: 0040, batch_index  100/ 560 , validation accuracy 0.98984
# Epoch: 0040, batch_index  150/ 560 , validation accuracy 0.98984
# Epoch: 0040, batch_index  200/ 560 , validation accuracy 0.99023
# Epoch: 0040, batch_index  250/ 560 , validation accuracy 0.99023
# Epoch: 0040, batch_index  300/ 560 , validation accuracy 0.99023
# Epoch: 0040, batch_index  350/ 560 , validation accuracy 0.99023
# early_stop...........
# INFO:tensorflow:Restoring parameters from save/Team07_HW2.ckpt
# Acc_test : 0.991243
# Prec_value : 0.999038
# Recall_value : 0.998317
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99       980
#           1       1.00      0.99      0.99      1135
#           2       0.98      0.98      0.98      1032
#           3       0.99      0.99      0.99      1010
#           4       0.99      0.99      0.99       982
#
# avg / total       0.99      0.99      0.99      5139

# %%
###################################
#                                 #
#     K-FOLD cross validation     #
#                                 #
###################################

# %%
### 額外程式，主要去打亂合併的資料，並做k-fold 的取資料
class CrossValidationFolds(object):
    
    def __init__(self, data, labels, num_folds, shuffle=True):
        self.data = data
        self.labels = labels
        self.num_folds = num_folds
        self.current_fold = 0
        
        # Shuffle Dataset
        if shuffle:
            perm = np.random.permutation(self.data.shape[0]) ##隨機打亂資料
            data = data[perm]
            labels = labels[perm]
    
    def split(self):
        current = self.current_fold
        size = int(self.data.shape[0]/self.num_folds) # 30596 / 5 一塊k的size大小
        
        index = np.arange(self.data.shape[0]) 

        # 利用 True/False 抓出 validation 區塊
        lower_bound = index >= current*size # validation 下界
        upper_bound = index < (current + 1)*size # 上界

        cv_region = lower_bound*upper_bound

        cv_data = self.data[cv_region] # 利用 True/False 抓出 True 的資料
        train_data = self.data[~cv_region]
        
        cv_labels = self.labels[cv_region]
        train_labels = self.labels[~cv_region]
        
        self.current_fold += 1 ## 丟回下一的fold
        return (train_data, train_labels), (cv_data, cv_labels)

# %%
FOLDS = 5 # k = 5

X_train = np.concatenate((X_train1,X_valid1), axis=0)
Y_label = np.concatenate((y_train1,y_valid1), axis=0)
data = CrossValidationFolds(X_train, Y_label, FOLDS)

recall_test = [] # 放每個第n-fold 時的recall值
prec_test = []   # 放每個第n-fold 時的精確值
acc_test = []    # 放每個第n-fold 時的正確率值

# %%
with tf.Session(config=config) as sess:
    for i in range(FOLDS):
        print("Fold: ", '%d,' % (i+1))
        (X_train1, y_train1), (X_valid1, y_valid1) = data.split()
        run(sess, X_train1, y_train1, X_valid1, y_valid1)
                        
        recall_test.append(sess.run(accuracy, feed_dict={x: X_test1, y: y_test1}))
        prec_test.append(sess.run(precision, feed_dict={x: X_test1, y: y_test1}))
        acc_test.append(sess.run(recall, feed_dict={x: X_test1, y: y_test1}))
    
    print(acc_test)
    print(recall_test)
    print(prec_test)
    print('1. 5-Fold平均正確率 : ',np.array(acc_test).mean() , 
          '2. 5-Fold平均精確率 : ',np.array(prec_test).mean() ,
          '3. 5-Fold平均Recall : ',np.array(recall_test).mean())
# Out:
# Fold:  1,
# Epoch: 0001, batch_index    0/ 560 , validation accuracy 0.20853
# Team07_HW2.ckpt-complete-0001-batch_index-0
# Epoch: 0001, batch_index   50/ 560 , validation accuracy 0.90031
# Team07_HW2.ckpt-complete-0001-batch_index-50
# Epoch: 0001, batch_index  100/ 560 , validation accuracy 0.93904
# Team07_HW2.ckpt-complete-0001-batch_index-100
# Epoch: 0001, batch_index  150/ 560 , validation accuracy 0.94950
# Team07_HW2.ckpt-complete-0001-batch_index-150
# Epoch: 0001, batch_index  200/ 560 , validation accuracy 0.95620
# Team07_HW2.ckpt-complete-0001-batch_index-200
# Epoch: 0001, batch_index  250/ 560 , validation accuracy 0.95686
# Team07_HW2.ckpt-complete-0001-batch_index-250
# Epoch: 0001, batch_index  300/ 560 , validation accuracy 0.96372
# Team07_HW2.ckpt-complete-0001-batch_index-300
# Epoch: 0001, batch_index  350/ 560 , validation accuracy 0.96552
# Team07_HW2.ckpt-complete-0001-batch_index-350
# Epoch: 0001, batch_index  400/ 560 , validation accuracy 0.96764
# Team07_HW2.ckpt-complete-0001-batch_index-400
# Epoch: 0001, batch_index  450/ 560 , validation accuracy 0.96846
# Team07_HW2.ckpt-complete-0001-batch_index-450
# Epoch: 0001, batch_index  500/ 560 , validation accuracy 0.96977
# Team07_HW2.ckpt-complete-0001-batch_index-500
# Epoch: 0001, batch_index  550/ 560 , validation accuracy 0.96993
# Team07_HW2.ckpt-complete-0001-batch_index-550
# Epoch: 0002, batch_index    0/ 560 , validation accuracy 0.97042
# Team07_HW2.ckpt-complete-0002-batch_index-0
# Epoch: 0002, batch_index   50/ 560 , validation accuracy 0.97042
# Epoch: 0002, batch_index  100/ 560 , validation accuracy 0.97140
# Team07_HW2.ckpt-complete-0002-batch_index-100
# Epoch: 0002, batch_index  150/ 560 , validation accuracy 0.97075
# Epoch: 0002, batch_index  200/ 560 , validation accuracy 0.97238
# Team07_HW2.ckpt-complete-0002-batch_index-200
# Epoch: 0002, batch_index  250/ 560 , validation accuracy 0.97353
# Team07_HW2.ckpt-complete-0002-batch_index-250
# Epoch: 0002, batch_index  300/ 560 , validation accuracy 0.97516
# Team07_HW2.ckpt-complete-0002-batch_index-300
# Epoch: 0002, batch_index  350/ 560 , validation accuracy 0.97549
# Team07_HW2.ckpt-complete-0002-batch_index-350
# Epoch: 0002, batch_index  400/ 560 , validation accuracy 0.97696
# Team07_HW2.ckpt-complete-0002-batch_index-400
# Epoch: 0002, batch_index  450/ 560 , validation accuracy 0.97696
# Epoch: 0002, batch_index  500/ 560 , validation accuracy 0.97696
# Epoch: 0002, batch_index  550/ 560 , validation accuracy 0.97679
# Epoch: 0003, batch_index    0/ 560 , validation accuracy 0.97679
# Epoch: 0003, batch_index   50/ 560 , validation accuracy 0.97500
# Epoch: 0003, batch_index  100/ 560 , validation accuracy 0.97794
# Team07_HW2.ckpt-complete-0003-batch_index-100
# Epoch: 0003, batch_index  150/ 560 , validation accuracy 0.97663
# Epoch: 0003, batch_index  200/ 560 , validation accuracy 0.97647
# Epoch: 0003, batch_index  250/ 560 , validation accuracy 0.97712
# Epoch: 0003, batch_index  300/ 560 , validation accuracy 0.97745
# Epoch: 0003, batch_index  350/ 560 , validation accuracy 0.97875
# Team07_HW2.ckpt-complete-0003-batch_index-350
# Epoch: 0003, batch_index  400/ 560 , validation accuracy 0.97925
# Team07_HW2.ckpt-complete-0003-batch_index-400
# Epoch: 0003, batch_index  450/ 560 , validation accuracy 0.98055
# Team07_HW2.ckpt-complete-0003-batch_index-450
# Epoch: 0003, batch_index  500/ 560 , validation accuracy 0.98006
# Epoch: 0003, batch_index  550/ 560 , validation accuracy 0.97990
# Epoch: 0004, batch_index    0/ 560 , validation accuracy 0.97974
# Epoch: 0004, batch_index   50/ 560 , validation accuracy 0.97843
# Epoch: 0004, batch_index  100/ 560 , validation accuracy 0.97990
# Epoch: 0004, batch_index  150/ 560 , validation accuracy 0.98023
# Epoch: 0004, batch_index  200/ 560 , validation accuracy 0.97974
# Epoch: 0004, batch_index  250/ 560 , validation accuracy 0.97957
# Epoch: 0004, batch_index  300/ 560 , validation accuracy 0.98104
# Team07_HW2.ckpt-complete-0004-batch_index-300
# Epoch: 0004, batch_index  350/ 560 , validation accuracy 0.98186
# Team07_HW2.ckpt-complete-0004-batch_index-350
# Epoch: 0004, batch_index  400/ 560 , validation accuracy 0.98121
# Epoch: 0004, batch_index  450/ 560 , validation accuracy 0.98104
# Epoch: 0004, batch_index  500/ 560 , validation accuracy 0.98268
# Team07_HW2.ckpt-complete-0004-batch_index-500
# Epoch: 0004, batch_index  550/ 560 , validation accuracy 0.98186
# Epoch: 0005, batch_index    0/ 560 , validation accuracy 0.98202
# Epoch: 0005, batch_index   50/ 560 , validation accuracy 0.98137
# Epoch: 0005, batch_index  100/ 560 , validation accuracy 0.98121
# Epoch: 0005, batch_index  150/ 560 , validation accuracy 0.98104
# Epoch: 0005, batch_index  200/ 560 , validation accuracy 0.98202
# Epoch: 0005, batch_index  250/ 560 , validation accuracy 0.98415
# Team07_HW2.ckpt-complete-0005-batch_index-250
# Epoch: 0005, batch_index  300/ 560 , validation accuracy 0.98268
# Epoch: 0005, batch_index  350/ 560 , validation accuracy 0.98186
# Epoch: 0005, batch_index  400/ 560 , validation accuracy 0.98268
# Epoch: 0005, batch_index  450/ 560 , validation accuracy 0.98219
# Epoch: 0005, batch_index  500/ 560 , validation accuracy 0.98398
# Epoch: 0005, batch_index  550/ 560 , validation accuracy 0.98447
# Team07_HW2.ckpt-complete-0005-batch_index-550
# Epoch: 0006, batch_index    0/ 560 , validation accuracy 0.98447
# Team07_HW2.ckpt-complete-0006-batch_index-0
# Epoch: 0006, batch_index   50/ 560 , validation accuracy 0.98300
# Epoch: 0006, batch_index  100/ 560 , validation accuracy 0.98186
# Epoch: 0006, batch_index  150/ 560 , validation accuracy 0.98186
# Epoch: 0006, batch_index  200/ 560 , validation accuracy 0.98284
# Epoch: 0006, batch_index  250/ 560 , validation accuracy 0.98431
# Epoch: 0006, batch_index  300/ 560 , validation accuracy 0.98366
# Epoch: 0006, batch_index  350/ 560 , validation accuracy 0.98382
# Epoch: 0006, batch_index  400/ 560 , validation accuracy 0.98382
# Epoch: 0006, batch_index  450/ 560 , validation accuracy 0.98170
# Epoch: 0006, batch_index  500/ 560 , validation accuracy 0.98333
# Epoch: 0006, batch_index  550/ 560 , validation accuracy 0.98333
# Epoch: 0007, batch_index    0/ 560 , validation accuracy 0.98333
# Epoch: 0007, batch_index   50/ 560 , validation accuracy 0.98366
# Epoch: 0007, batch_index  100/ 560 , validation accuracy 0.98464
# Team07_HW2.ckpt-complete-0007-batch_index-100
# Epoch: 0007, batch_index  150/ 560 , validation accuracy 0.98382
# Epoch: 0007, batch_index  200/ 560 , validation accuracy 0.98529
# Team07_HW2.ckpt-complete-0007-batch_index-200
# Epoch: 0007, batch_index  250/ 560 , validation accuracy 0.98415
# Epoch: 0007, batch_index  300/ 560 , validation accuracy 0.98415
# Epoch: 0007, batch_index  350/ 560 , validation accuracy 0.98366
# Epoch: 0007, batch_index  400/ 560 , validation accuracy 0.98349
# Epoch: 0007, batch_index  450/ 560 , validation accuracy 0.98366
# Epoch: 0007, batch_index  500/ 560 , validation accuracy 0.98415
# Epoch: 0007, batch_index  550/ 560 , validation accuracy 0.98349
# Epoch: 0008, batch_index    0/ 560 , validation accuracy 0.98366
# Epoch: 0008, batch_index   50/ 560 , validation accuracy 0.98333
# Epoch: 0008, batch_index  100/ 560 , validation accuracy 0.98562
# Team07_HW2.ckpt-complete-0008-batch_index-100
# Epoch: 0008, batch_index  150/ 560 , validation accuracy 0.98268
# Epoch: 0008, batch_index  200/ 560 , validation accuracy 0.98431
# Epoch: 0008, batch_index  250/ 560 , validation accuracy 0.98513
# Epoch: 0008, batch_index  300/ 560 , validation accuracy 0.98480
# Epoch: 0008, batch_index  350/ 560 , validation accuracy 0.98447
# Epoch: 0008, batch_index  400/ 560 , validation accuracy 0.98447
# Epoch: 0008, batch_index  450/ 560 , validation accuracy 0.98431
# Epoch: 0008, batch_index  500/ 560 , validation accuracy 0.98382
# Epoch: 0008, batch_index  550/ 560 , validation accuracy 0.98300
# Epoch: 0009, batch_index    0/ 560 , validation accuracy 0.98300
# Epoch: 0009, batch_index   50/ 560 , validation accuracy 0.98660
# Team07_HW2.ckpt-complete-0009-batch_index-50
# Epoch: 0009, batch_index  100/ 560 , validation accuracy 0.98595
# Epoch: 0009, batch_index  150/ 560 , validation accuracy 0.98513
# Epoch: 0009, batch_index  200/ 560 , validation accuracy 0.98431
# Epoch: 0009, batch_index  250/ 560 , validation accuracy 0.98398
# Epoch: 0009, batch_index  300/ 560 , validation accuracy 0.98546
# Epoch: 0009, batch_index  350/ 560 , validation accuracy 0.98562
# Epoch: 0009, batch_index  400/ 560 , validation accuracy 0.98447
# Epoch: 0009, batch_index  450/ 560 , validation accuracy 0.98480
# Epoch: 0009, batch_index  500/ 560 , validation accuracy 0.98513
# Epoch: 0009, batch_index  550/ 560 , validation accuracy 0.98513
# Epoch: 0010, batch_index    0/ 560 , validation accuracy 0.98529
# Epoch: 0010, batch_index   50/ 560 , validation accuracy 0.98595
# Epoch: 0010, batch_index  100/ 560 , validation accuracy 0.98627
# Epoch: 0010, batch_index  150/ 560 , validation accuracy 0.98627
# Epoch: 0010, batch_index  200/ 560 , validation accuracy 0.98562
# Epoch: 0010, batch_index  250/ 560 , validation accuracy 0.98546
# Epoch: 0010, batch_index  300/ 560 , validation accuracy 0.98660
# Epoch: 0010, batch_index  350/ 560 , validation accuracy 0.98497
# Epoch: 0010, batch_index  400/ 560 , validation accuracy 0.98578
# Epoch: 0010, batch_index  450/ 560 , validation accuracy 0.98513
# Epoch: 0010, batch_index  500/ 560 , validation accuracy 0.98431
# Epoch: 0010, batch_index  550/ 560 , validation accuracy 0.97974
# Epoch: 0011, batch_index    0/ 560 , validation accuracy 0.98039
# Epoch: 0011, batch_index   50/ 560 , validation accuracy 0.98464
# Epoch: 0011, batch_index  100/ 560 , validation accuracy 0.98676
# Team07_HW2.ckpt-complete-0011-batch_index-100
# Epoch: 0011, batch_index  150/ 560 , validation accuracy 0.98578
# Epoch: 0011, batch_index  200/ 560 , validation accuracy 0.98644
# Epoch: 0011, batch_index  250/ 560 , validation accuracy 0.98497
# Epoch: 0011, batch_index  300/ 560 , validation accuracy 0.98562
# Epoch: 0011, batch_index  350/ 560 , validation accuracy 0.98595
# Epoch: 0011, batch_index  400/ 560 , validation accuracy 0.98497
# Epoch: 0011, batch_index  450/ 560 , validation accuracy 0.98627
# Epoch: 0011, batch_index  500/ 560 , validation accuracy 0.98497
# Epoch: 0011, batch_index  550/ 560 , validation accuracy 0.98447
# Epoch: 0012, batch_index    0/ 560 , validation accuracy 0.98447
# Epoch: 0012, batch_index   50/ 560 , validation accuracy 0.98660
# Epoch: 0012, batch_index  100/ 560 , validation accuracy 0.98644
# Epoch: 0012, batch_index  150/ 560 , validation accuracy 0.98595
# Epoch: 0012, batch_index  200/ 560 , validation accuracy 0.98644
# Epoch: 0012, batch_index  250/ 560 , validation accuracy 0.98562
# Epoch: 0012, batch_index  300/ 560 , validation accuracy 0.98595
# Epoch: 0012, batch_index  350/ 560 , validation accuracy 0.98774
# Team07_HW2.ckpt-complete-0012-batch_index-350
# Epoch: 0012, batch_index  400/ 560 , validation accuracy 0.98529
# Epoch: 0012, batch_index  450/ 560 , validation accuracy 0.98676
# Epoch: 0012, batch_index  500/ 560 , validation accuracy 0.98595
# Epoch: 0012, batch_index  550/ 560 , validation accuracy 0.98595
# Epoch: 0013, batch_index    0/ 560 , validation accuracy 0.98595
# Epoch: 0013, batch_index   50/ 560 , validation accuracy 0.98644
# Epoch: 0013, batch_index  100/ 560 , validation accuracy 0.98693
# Epoch: 0013, batch_index  150/ 560 , validation accuracy 0.98693
# Epoch: 0013, batch_index  200/ 560 , validation accuracy 0.98742
# Epoch: 0013, batch_index  250/ 560 , validation accuracy 0.98644
# Epoch: 0013, batch_index  300/ 560 , validation accuracy 0.98709
# Epoch: 0013, batch_index  350/ 560 , validation accuracy 0.98644
# Epoch: 0013, batch_index  400/ 560 , validation accuracy 0.98611
# Epoch: 0013, batch_index  450/ 560 , validation accuracy 0.98546
# Epoch: 0013, batch_index  500/ 560 , validation accuracy 0.98693
# Epoch: 0013, batch_index  550/ 560 , validation accuracy 0.98693
# Epoch: 0014, batch_index    0/ 560 , validation accuracy 0.98693
# Epoch: 0014, batch_index   50/ 560 , validation accuracy 0.98595
# Epoch: 0014, batch_index  100/ 560 , validation accuracy 0.98644
# Epoch: 0014, batch_index  150/ 560 , validation accuracy 0.98660
# Epoch: 0014, batch_index  200/ 560 , validation accuracy 0.98660
# Epoch: 0014, batch_index  250/ 560 , validation accuracy 0.98644
# Epoch: 0014, batch_index  300/ 560 , validation accuracy 0.98693
# Epoch: 0014, batch_index  350/ 560 , validation accuracy 0.98627
# Epoch: 0014, batch_index  400/ 560 , validation accuracy 0.98660
# Epoch: 0014, batch_index  450/ 560 , validation accuracy 0.98693
# Epoch: 0014, batch_index  500/ 560 , validation accuracy 0.98693
# Epoch: 0014, batch_index  550/ 560 , validation accuracy 0.98676
# Epoch: 0015, batch_index    0/ 560 , validation accuracy 0.98676
# Epoch: 0015, batch_index   50/ 560 , validation accuracy 0.98693
# Epoch: 0015, batch_index  100/ 560 , validation accuracy 0.98725
# Epoch: 0015, batch_index  150/ 560 , validation accuracy 0.98693
# Epoch: 0015, batch_index  200/ 560 , validation accuracy 0.98725
# Epoch: 0015, batch_index  250/ 560 , validation accuracy 0.98660
# Epoch: 0015, batch_index  300/ 560 , validation accuracy 0.98709
# Epoch: 0015, batch_index  350/ 560 , validation accuracy 0.98758
# Epoch: 0015, batch_index  400/ 560 , validation accuracy 0.98693
# Epoch: 0015, batch_index  450/ 560 , validation accuracy 0.98660
# Epoch: 0015, batch_index  500/ 560 , validation accuracy 0.98676
# Epoch: 0015, batch_index  550/ 560 , validation accuracy 0.98660
# Epoch: 0016, batch_index    0/ 560 , validation accuracy 0.98660
# Epoch: 0016, batch_index   50/ 560 , validation accuracy 0.98676
# Epoch: 0016, batch_index  100/ 560 , validation accuracy 0.98676
# Epoch: 0016, batch_index  150/ 560 , validation accuracy 0.98742
# Epoch: 0016, batch_index  200/ 560 , validation accuracy 0.98774
# Epoch: 0016, batch_index  250/ 560 , validation accuracy 0.98742
# Epoch: 0016, batch_index  300/ 560 , validation accuracy 0.98774
# Epoch: 0016, batch_index  350/ 560 , validation accuracy 0.98742
# Epoch: 0016, batch_index  400/ 560 , validation accuracy 0.98660
# Epoch: 0016, batch_index  450/ 560 , validation accuracy 0.98676
# Epoch: 0016, batch_index  500/ 560 , validation accuracy 0.98660
# Epoch: 0016, batch_index  550/ 560 , validation accuracy 0.98676
# Epoch: 0017, batch_index    0/ 560 , validation accuracy 0.98676
# Epoch: 0017, batch_index   50/ 560 , validation accuracy 0.98807
# Team07_HW2.ckpt-complete-0017-batch_index-50
# Epoch: 0017, batch_index  100/ 560 , validation accuracy 0.98709
# Epoch: 0017, batch_index  150/ 560 , validation accuracy 0.98742
# Epoch: 0017, batch_index  200/ 560 , validation accuracy 0.98644
# Epoch: 0017, batch_index  250/ 560 , validation accuracy 0.98807
# Epoch: 0017, batch_index  300/ 560 , validation accuracy 0.98725
# Epoch: 0017, batch_index  350/ 560 , validation accuracy 0.98725
# Epoch: 0017, batch_index  400/ 560 , validation accuracy 0.98693
# Epoch: 0017, batch_index  450/ 560 , validation accuracy 0.98693
# Epoch: 0017, batch_index  500/ 560 , validation accuracy 0.98758
# Epoch: 0017, batch_index  550/ 560 , validation accuracy 0.98774
# Epoch: 0018, batch_index    0/ 560 , validation accuracy 0.98758
# Epoch: 0018, batch_index   50/ 560 , validation accuracy 0.98742
# Epoch: 0018, batch_index  100/ 560 , validation accuracy 0.98660
# Epoch: 0018, batch_index  150/ 560 , validation accuracy 0.98823
# Team07_HW2.ckpt-complete-0018-batch_index-150
# Epoch: 0018, batch_index  200/ 560 , validation accuracy 0.98791
# Epoch: 0018, batch_index  250/ 560 , validation accuracy 0.98807
# Epoch: 0018, batch_index  300/ 560 , validation accuracy 0.98889
# Team07_HW2.ckpt-complete-0018-batch_index-300
# Epoch: 0018, batch_index  350/ 560 , validation accuracy 0.98693
# Epoch: 0018, batch_index  400/ 560 , validation accuracy 0.98823
# Epoch: 0018, batch_index  450/ 560 , validation accuracy 0.98774
# Epoch: 0018, batch_index  500/ 560 , validation accuracy 0.98709
# Epoch: 0018, batch_index  550/ 560 , validation accuracy 0.98758
# Epoch: 0019, batch_index    0/ 560 , validation accuracy 0.98758
# Epoch: 0019, batch_index   50/ 560 , validation accuracy 0.98758
# Epoch: 0019, batch_index  100/ 560 , validation accuracy 0.98774
# Epoch: 0019, batch_index  150/ 560 , validation accuracy 0.98807
# Epoch: 0019, batch_index  200/ 560 , validation accuracy 0.98725
# Epoch: 0019, batch_index  250/ 560 , validation accuracy 0.98709
# Epoch: 0019, batch_index  300/ 560 , validation accuracy 0.98758
# Epoch: 0019, batch_index  350/ 560 , validation accuracy 0.98774
# Epoch: 0019, batch_index  400/ 560 , validation accuracy 0.98742
# Epoch: 0019, batch_index  450/ 560 , validation accuracy 0.98725
# Epoch: 0019, batch_index  500/ 560 , validation accuracy 0.98742
# Epoch: 0019, batch_index  550/ 560 , validation accuracy 0.98725
# Epoch: 0020, batch_index    0/ 560 , validation accuracy 0.98725
# Epoch: 0020, batch_index   50/ 560 , validation accuracy 0.98725
# Epoch: 0020, batch_index  100/ 560 , validation accuracy 0.98823
# Epoch: 0020, batch_index  150/ 560 , validation accuracy 0.98758
# Epoch: 0020, batch_index  200/ 560 , validation accuracy 0.98758
# Epoch: 0020, batch_index  250/ 560 , validation accuracy 0.98807
# Epoch: 0020, batch_index  300/ 560 , validation accuracy 0.98856
# Epoch: 0020, batch_index  350/ 560 , validation accuracy 0.98709
# Epoch: 0020, batch_index  400/ 560 , validation accuracy 0.98807
# Epoch: 0020, batch_index  450/ 560 , validation accuracy 0.98742
# Epoch: 0020, batch_index  500/ 560 , validation accuracy 0.98774
# Epoch: 0020, batch_index  550/ 560 , validation accuracy 0.98742
# Epoch: 0021, batch_index    0/ 560 , validation accuracy 0.98742
# Epoch: 0021, batch_index   50/ 560 , validation accuracy 0.98693
# Epoch: 0021, batch_index  100/ 560 , validation accuracy 0.98742
# Epoch: 0021, batch_index  150/ 560 , validation accuracy 0.98774
# Epoch: 0021, batch_index  200/ 560 , validation accuracy 0.98791
# Epoch: 0021, batch_index  250/ 560 , validation accuracy 0.98807
# Epoch: 0021, batch_index  300/ 560 , validation accuracy 0.98823
# Epoch: 0021, batch_index  350/ 560 , validation accuracy 0.98742
# Epoch: 0021, batch_index  400/ 560 , validation accuracy 0.98676
# Epoch: 0021, batch_index  450/ 560 , validation accuracy 0.98872
# Epoch: 0021, batch_index  500/ 560 , validation accuracy 0.98807
# Epoch: 0021, batch_index  550/ 560 , validation accuracy 0.98807
# Epoch: 0022, batch_index    0/ 560 , validation accuracy 0.98807
# Epoch: 0022, batch_index   50/ 560 , validation accuracy 0.98725
# Epoch: 0022, batch_index  100/ 560 , validation accuracy 0.98709
# Epoch: 0022, batch_index  150/ 560 , validation accuracy 0.98758
# Epoch: 0022, batch_index  200/ 560 , validation accuracy 0.98742
# Epoch: 0022, batch_index  250/ 560 , validation accuracy 0.98774
# Epoch: 0022, batch_index  300/ 560 , validation accuracy 0.98791
# Epoch: 0022, batch_index  350/ 560 , validation accuracy 0.98840
# Epoch: 0022, batch_index  400/ 560 , validation accuracy 0.98758
# Epoch: 0022, batch_index  450/ 560 , validation accuracy 0.98807
# Epoch: 0022, batch_index  500/ 560 , validation accuracy 0.98758
# Epoch: 0022, batch_index  550/ 560 , validation accuracy 0.98758
# Epoch: 0023, batch_index    0/ 560 , validation accuracy 0.98758
# Epoch: 0023, batch_index   50/ 560 , validation accuracy 0.98791
# Epoch: 0023, batch_index  100/ 560 , validation accuracy 0.98774
# Epoch: 0023, batch_index  150/ 560 , validation accuracy 0.98758
# Epoch: 0023, batch_index  200/ 560 , validation accuracy 0.98856
# Epoch: 0023, batch_index  250/ 560 , validation accuracy 0.98856
# Epoch: 0023, batch_index  300/ 560 , validation accuracy 0.98791
# Epoch: 0023, batch_index  350/ 560 , validation accuracy 0.98774
# Epoch: 0023, batch_index  400/ 560 , validation accuracy 0.98693
# Epoch: 0023, batch_index  450/ 560 , validation accuracy 0.98791
# Epoch: 0023, batch_index  500/ 560 , validation accuracy 0.98742
# Epoch: 0023, batch_index  550/ 560 , validation accuracy 0.98725
# Epoch: 0024, batch_index    0/ 560 , validation accuracy 0.98725
# Epoch: 0024, batch_index   50/ 560 , validation accuracy 0.98774
# Epoch: 0024, batch_index  100/ 560 , validation accuracy 0.98758
# Epoch: 0024, batch_index  150/ 560 , validation accuracy 0.98725
# Epoch: 0024, batch_index  200/ 560 , validation accuracy 0.98774
# Epoch: 0024, batch_index  250/ 560 , validation accuracy 0.98758
# Epoch: 0024, batch_index  300/ 560 , validation accuracy 0.98774
# Epoch: 0024, batch_index  350/ 560 , validation accuracy 0.98840
# Epoch: 0024, batch_index  400/ 560 , validation accuracy 0.98823
# Epoch: 0024, batch_index  450/ 560 , validation accuracy 0.98709
# Epoch: 0024, batch_index  500/ 560 , validation accuracy 0.98823
# Epoch: 0024, batch_index  550/ 560 , validation accuracy 0.98823
# Epoch: 0025, batch_index    0/ 560 , validation accuracy 0.98823
# Epoch: 0025, batch_index   50/ 560 , validation accuracy 0.98807
# Epoch: 0025, batch_index  100/ 560 , validation accuracy 0.98725
# Epoch: 0025, batch_index  150/ 560 , validation accuracy 0.98807
# Epoch: 0025, batch_index  200/ 560 , validation accuracy 0.98725
# Epoch: 0025, batch_index  250/ 560 , validation accuracy 0.98774
# Epoch: 0025, batch_index  300/ 560 , validation accuracy 0.98774
# Epoch: 0025, batch_index  350/ 560 , validation accuracy 0.98823
# Epoch: 0025, batch_index  400/ 560 , validation accuracy 0.98807
# Epoch: 0025, batch_index  450/ 560 , validation accuracy 0.98758
# Epoch: 0025, batch_index  500/ 560 , validation accuracy 0.98823
# Epoch: 0025, batch_index  550/ 560 , validation accuracy 0.98840
# Epoch: 0026, batch_index    0/ 560 , validation accuracy 0.98840
# Epoch: 0026, batch_index   50/ 560 , validation accuracy 0.98774
# Epoch: 0026, batch_index  100/ 560 , validation accuracy 0.98774
# Epoch: 0026, batch_index  150/ 560 , validation accuracy 0.98758
# Epoch: 0026, batch_index  200/ 560 , validation accuracy 0.98725
# Epoch: 0026, batch_index  250/ 560 , validation accuracy 0.98791
# Epoch: 0026, batch_index  300/ 560 , validation accuracy 0.98758
# Epoch: 0026, batch_index  350/ 560 , validation accuracy 0.98758
# Epoch: 0026, batch_index  400/ 560 , validation accuracy 0.98725
# Epoch: 0026, batch_index  450/ 560 , validation accuracy 0.98791
# Epoch: 0026, batch_index  500/ 560 , validation accuracy 0.98872
# Epoch: 0026, batch_index  550/ 560 , validation accuracy 0.98856
# Epoch: 0027, batch_index    0/ 560 , validation accuracy 0.98856
# Epoch: 0027, batch_index   50/ 560 , validation accuracy 0.98742
# Epoch: 0027, batch_index  100/ 560 , validation accuracy 0.98774
# Epoch: 0027, batch_index  150/ 560 , validation accuracy 0.98725
# Epoch: 0027, batch_index  200/ 560 , validation accuracy 0.98774
# Epoch: 0027, batch_index  250/ 560 , validation accuracy 0.98774
# Epoch: 0027, batch_index  300/ 560 , validation accuracy 0.98872
# Epoch: 0027, batch_index  350/ 560 , validation accuracy 0.98856
# Epoch: 0027, batch_index  400/ 560 , validation accuracy 0.98840
# Epoch: 0027, batch_index  450/ 560 , validation accuracy 0.98774
# Epoch: 0027, batch_index  500/ 560 , validation accuracy 0.98791
# Epoch: 0027, batch_index  550/ 560 , validation accuracy 0.98774
# Epoch: 0028, batch_index    0/ 560 , validation accuracy 0.98774
# Epoch: 0028, batch_index   50/ 560 , validation accuracy 0.98758
# Epoch: 0028, batch_index  100/ 560 , validation accuracy 0.98742
# Epoch: 0028, batch_index  150/ 560 , validation accuracy 0.98823
# Epoch: 0028, batch_index  200/ 560 , validation accuracy 0.98823
# Epoch: 0028, batch_index  250/ 560 , validation accuracy 0.98774
# Epoch: 0028, batch_index  300/ 560 , validation accuracy 0.98742
# Epoch: 0028, batch_index  350/ 560 , validation accuracy 0.98742
# Epoch: 0028, batch_index  400/ 560 , validation accuracy 0.98791
# Epoch: 0028, batch_index  450/ 560 , validation accuracy 0.98758
# Epoch: 0028, batch_index  500/ 560 , validation accuracy 0.98791
# Epoch: 0028, batch_index  550/ 560 , validation accuracy 0.98774
# Epoch: 0029, batch_index    0/ 560 , validation accuracy 0.98774
# Epoch: 0029, batch_index   50/ 560 , validation accuracy 0.98758
# Epoch: 0029, batch_index  100/ 560 , validation accuracy 0.98823
# Epoch: 0029, batch_index  150/ 560 , validation accuracy 0.98791
# Epoch: 0029, batch_index  200/ 560 , validation accuracy 0.98791
# Epoch: 0029, batch_index  250/ 560 , validation accuracy 0.98758
# Epoch: 0029, batch_index  300/ 560 , validation accuracy 0.98774
# Epoch: 0029, batch_index  350/ 560 , validation accuracy 0.98774
# Epoch: 0029, batch_index  400/ 560 , validation accuracy 0.98791
# Epoch: 0029, batch_index  450/ 560 , validation accuracy 0.98791
# Epoch: 0029, batch_index  500/ 560 , validation accuracy 0.98758
# Epoch: 0029, batch_index  550/ 560 , validation accuracy 0.98774
# Epoch: 0030, batch_index    0/ 560 , validation accuracy 0.98774
# Epoch: 0030, batch_index   50/ 560 , validation accuracy 0.98791
# Epoch: 0030, batch_index  100/ 560 , validation accuracy 0.98840
# Epoch: 0030, batch_index  150/ 560 , validation accuracy 0.98823
# Epoch: 0030, batch_index  200/ 560 , validation accuracy 0.98774
# Epoch: 0030, batch_index  250/ 560 , validation accuracy 0.98758
# Epoch: 0030, batch_index  300/ 560 , validation accuracy 0.98823
# Epoch: 0030, batch_index  350/ 560 , validation accuracy 0.98774
# Epoch: 0030, batch_index  400/ 560 , validation accuracy 0.98774
# Epoch: 0030, batch_index  450/ 560 , validation accuracy 0.98693
# Epoch: 0030, batch_index  500/ 560 , validation accuracy 0.98823
# Epoch: 0030, batch_index  550/ 560 , validation accuracy 0.98840
# Epoch: 0031, batch_index    0/ 560 , validation accuracy 0.98840
# Epoch: 0031, batch_index   50/ 560 , validation accuracy 0.98823
# Epoch: 0031, batch_index  100/ 560 , validation accuracy 0.98791
# Epoch: 0031, batch_index  150/ 560 , validation accuracy 0.98742
# Epoch: 0031, batch_index  200/ 560 , validation accuracy 0.98725
# Epoch: 0031, batch_index  250/ 560 , validation accuracy 0.98725
# Epoch: 0031, batch_index  300/ 560 , validation accuracy 0.98758
# Epoch: 0031, batch_index  350/ 560 , validation accuracy 0.98840
# Epoch: 0031, batch_index  400/ 560 , validation accuracy 0.98774
# Epoch: 0031, batch_index  450/ 560 , validation accuracy 0.98774
# Epoch: 0031, batch_index  500/ 560 , validation accuracy 0.98791
# Epoch: 0031, batch_index  550/ 560 , validation accuracy 0.98791
# Epoch: 0032, batch_index    0/ 560 , validation accuracy 0.98791
# Epoch: 0032, batch_index   50/ 560 , validation accuracy 0.98791
# Epoch: 0032, batch_index  100/ 560 , validation accuracy 0.98758
# Epoch: 0032, batch_index  150/ 560 , validation accuracy 0.98791
# Epoch: 0032, batch_index  200/ 560 , validation accuracy 0.98807
# Epoch: 0032, batch_index  250/ 560 , validation accuracy 0.98742
# Epoch: 0032, batch_index  300/ 560 , validation accuracy 0.98791
# Epoch: 0032, batch_index  350/ 560 , validation accuracy 0.98791
# Epoch: 0032, batch_index  400/ 560 , validation accuracy 0.98758
# Epoch: 0032, batch_index  450/ 560 , validation accuracy 0.98807
# Epoch: 0032, batch_index  500/ 560 , validation accuracy 0.98791
# Epoch: 0032, batch_index  550/ 560 , validation accuracy 0.98791
# Epoch: 0033, batch_index    0/ 560 , validation accuracy 0.98791
# Epoch: 0033, batch_index   50/ 560 , validation accuracy 0.98791
# Epoch: 0033, batch_index  100/ 560 , validation accuracy 0.98758
# Epoch: 0033, batch_index  150/ 560 , validation accuracy 0.98791
# Epoch: 0033, batch_index  200/ 560 , validation accuracy 0.98807
# Epoch: 0033, batch_index  250/ 560 , validation accuracy 0.98774
# Epoch: 0033, batch_index  300/ 560 , validation accuracy 0.98823
# Epoch: 0033, batch_index  350/ 560 , validation accuracy 0.98758
# Epoch: 0033, batch_index  400/ 560 , validation accuracy 0.98807
# Epoch: 0033, batch_index  450/ 560 , validation accuracy 0.98840
# Epoch: 0033, batch_index  500/ 560 , validation accuracy 0.98823
# Epoch: 0033, batch_index  550/ 560 , validation accuracy 0.98856
# Epoch: 0034, batch_index    0/ 560 , validation accuracy 0.98840
# Epoch: 0034, batch_index   50/ 560 , validation accuracy 0.98840
# Epoch: 0034, batch_index  100/ 560 , validation accuracy 0.98823
# Epoch: 0034, batch_index  150/ 560 , validation accuracy 0.98807
# Epoch: 0034, batch_index  200/ 560 , validation accuracy 0.98791
# Epoch: 0034, batch_index  250/ 560 , validation accuracy 0.98791
# Epoch: 0034, batch_index  300/ 560 , validation accuracy 0.98709
# Epoch: 0034, batch_index  350/ 560 , validation accuracy 0.98758
# Epoch: 0034, batch_index  400/ 560 , validation accuracy 0.98709
# Epoch: 0034, batch_index  450/ 560 , validation accuracy 0.98725
# Epoch: 0034, batch_index  500/ 560 , validation accuracy 0.98791
# Epoch: 0034, batch_index  550/ 560 , validation accuracy 0.98807
# Epoch: 0035, batch_index    0/ 560 , validation accuracy 0.98807
# Epoch: 0035, batch_index   50/ 560 , validation accuracy 0.98742
# Epoch: 0035, batch_index  100/ 560 , validation accuracy 0.98774
# early_stop...........
# Fold:  2,
# Epoch: 0001, batch_index    0/ 560 , validation accuracy 0.21981
# Team07_HW2.ckpt-complete-0001-batch_index-0
# Epoch: 0001, batch_index   50/ 560 , validation accuracy 0.90309
# Team07_HW2.ckpt-complete-0001-batch_index-50
# Epoch: 0001, batch_index  100/ 560 , validation accuracy 0.93855
# Team07_HW2.ckpt-complete-0001-batch_index-100
# Epoch: 0001, batch_index  150/ 560 , validation accuracy 0.94901
# Team07_HW2.ckpt-complete-0001-batch_index-150
# Epoch: 0001, batch_index  200/ 560 , validation accuracy 0.95261
# Team07_HW2.ckpt-complete-0001-batch_index-200
# Epoch: 0001, batch_index  250/ 560 , validation accuracy 0.95702
# Team07_HW2.ckpt-complete-0001-batch_index-250
# Epoch: 0001, batch_index  300/ 560 , validation accuracy 0.96143
# Team07_HW2.ckpt-complete-0001-batch_index-300
# Epoch: 0001, batch_index  350/ 560 , validation accuracy 0.96061
# Epoch: 0001, batch_index  400/ 560 , validation accuracy 0.96486
# Team07_HW2.ckpt-complete-0001-batch_index-400
# Epoch: 0001, batch_index  450/ 560 , validation accuracy 0.96732
# Team07_HW2.ckpt-complete-0001-batch_index-450
# Epoch: 0001, batch_index  500/ 560 , validation accuracy 0.96748
# Team07_HW2.ckpt-complete-0001-batch_index-500
# Epoch: 0001, batch_index  550/ 560 , validation accuracy 0.96617
# Epoch: 0002, batch_index    0/ 560 , validation accuracy 0.96650
# Epoch: 0002, batch_index   50/ 560 , validation accuracy 0.96960
# Team07_HW2.ckpt-complete-0002-batch_index-50
# Epoch: 0002, batch_index  100/ 560 , validation accuracy 0.97107
# Team07_HW2.ckpt-complete-0002-batch_index-100
# Epoch: 0002, batch_index  150/ 560 , validation accuracy 0.96977
# Epoch: 0002, batch_index  200/ 560 , validation accuracy 0.97336
# Team07_HW2.ckpt-complete-0002-batch_index-200
# Epoch: 0002, batch_index  250/ 560 , validation accuracy 0.97254
# Epoch: 0002, batch_index  300/ 560 , validation accuracy 0.97353
# Team07_HW2.ckpt-complete-0002-batch_index-300
# Epoch: 0002, batch_index  350/ 560 , validation accuracy 0.97581
# Team07_HW2.ckpt-complete-0002-batch_index-350
# Epoch: 0002, batch_index  400/ 560 , validation accuracy 0.97500
# Epoch: 0002, batch_index  450/ 560 , validation accuracy 0.97467
# Epoch: 0002, batch_index  500/ 560 , validation accuracy 0.97434
# Epoch: 0002, batch_index  550/ 560 , validation accuracy 0.97320
# Epoch: 0003, batch_index    0/ 560 , validation accuracy 0.97304
# Epoch: 0003, batch_index   50/ 560 , validation accuracy 0.97728
# Team07_HW2.ckpt-complete-0003-batch_index-50
# Epoch: 0003, batch_index  100/ 560 , validation accuracy 0.97647
# Epoch: 0003, batch_index  150/ 560 , validation accuracy 0.97794
# Team07_HW2.ckpt-complete-0003-batch_index-150
# Epoch: 0003, batch_index  200/ 560 , validation accuracy 0.97630
# Epoch: 0003, batch_index  250/ 560 , validation accuracy 0.97777
# Epoch: 0003, batch_index  300/ 560 , validation accuracy 0.97794
# Epoch: 0003, batch_index  350/ 560 , validation accuracy 0.97859
# Team07_HW2.ckpt-complete-0003-batch_index-350
# Epoch: 0003, batch_index  400/ 560 , validation accuracy 0.97892
# Team07_HW2.ckpt-complete-0003-batch_index-400
# Epoch: 0003, batch_index  450/ 560 , validation accuracy 0.97859
# Epoch: 0003, batch_index  500/ 560 , validation accuracy 0.97794
# Epoch: 0003, batch_index  550/ 560 , validation accuracy 0.97581
# Epoch: 0004, batch_index    0/ 560 , validation accuracy 0.97598
# Epoch: 0004, batch_index   50/ 560 , validation accuracy 0.98006
# Team07_HW2.ckpt-complete-0004-batch_index-50
# Epoch: 0004, batch_index  100/ 560 , validation accuracy 0.98104
# Team07_HW2.ckpt-complete-0004-batch_index-100
# Epoch: 0004, batch_index  150/ 560 , validation accuracy 0.98055
# Epoch: 0004, batch_index  200/ 560 , validation accuracy 0.98088
# Epoch: 0004, batch_index  250/ 560 , validation accuracy 0.98006
# Epoch: 0004, batch_index  300/ 560 , validation accuracy 0.98137
# Team07_HW2.ckpt-complete-0004-batch_index-300
# Epoch: 0004, batch_index  350/ 560 , validation accuracy 0.98121
# Epoch: 0004, batch_index  400/ 560 , validation accuracy 0.98055
# Epoch: 0004, batch_index  450/ 560 , validation accuracy 0.98072
# Epoch: 0004, batch_index  500/ 560 , validation accuracy 0.98039
# Epoch: 0004, batch_index  550/ 560 , validation accuracy 0.97974
# Epoch: 0005, batch_index    0/ 560 , validation accuracy 0.97974
# Epoch: 0005, batch_index   50/ 560 , validation accuracy 0.98006
# Epoch: 0005, batch_index  100/ 560 , validation accuracy 0.98153
# Team07_HW2.ckpt-complete-0005-batch_index-100
# Epoch: 0005, batch_index  150/ 560 , validation accuracy 0.98300
# Team07_HW2.ckpt-complete-0005-batch_index-150
# Epoch: 0005, batch_index  200/ 560 , validation accuracy 0.98121
# Epoch: 0005, batch_index  250/ 560 , validation accuracy 0.98137
# Epoch: 0005, batch_index  300/ 560 , validation accuracy 0.98202
# Epoch: 0005, batch_index  350/ 560 , validation accuracy 0.98186
# Epoch: 0005, batch_index  400/ 560 , validation accuracy 0.98251
# Epoch: 0005, batch_index  450/ 560 , validation accuracy 0.98170
# Epoch: 0005, batch_index  500/ 560 , validation accuracy 0.98333
# Team07_HW2.ckpt-complete-0005-batch_index-500
# Epoch: 0005, batch_index  550/ 560 , validation accuracy 0.98235
# Epoch: 0006, batch_index    0/ 560 , validation accuracy 0.98235
# Epoch: 0006, batch_index   50/ 560 , validation accuracy 0.98202
# Epoch: 0006, batch_index  100/ 560 , validation accuracy 0.98382
# Team07_HW2.ckpt-complete-0006-batch_index-100
# Epoch: 0006, batch_index  150/ 560 , validation accuracy 0.98317
# Epoch: 0006, batch_index  200/ 560 , validation accuracy 0.98398
# Team07_HW2.ckpt-complete-0006-batch_index-200
# Epoch: 0006, batch_index  250/ 560 , validation accuracy 0.98464
# Team07_HW2.ckpt-complete-0006-batch_index-250
# Epoch: 0006, batch_index  300/ 560 , validation accuracy 0.98349
# Epoch: 0006, batch_index  350/ 560 , validation accuracy 0.98398
# Epoch: 0006, batch_index  400/ 560 , validation accuracy 0.98415
# Epoch: 0006, batch_index  450/ 560 , validation accuracy 0.98415
# Epoch: 0006, batch_index  500/ 560 , validation accuracy 0.98415
# Epoch: 0006, batch_index  550/ 560 , validation accuracy 0.98333
# Epoch: 0007, batch_index    0/ 560 , validation accuracy 0.98333
# Epoch: 0007, batch_index   50/ 560 , validation accuracy 0.98349
# Epoch: 0007, batch_index  100/ 560 , validation accuracy 0.98382
# Epoch: 0007, batch_index  150/ 560 , validation accuracy 0.98447
# Epoch: 0007, batch_index  200/ 560 , validation accuracy 0.98415
# Epoch: 0007, batch_index  250/ 560 , validation accuracy 0.98398
# Epoch: 0007, batch_index  300/ 560 , validation accuracy 0.98284
# Epoch: 0007, batch_index  350/ 560 , validation accuracy 0.98398
# Epoch: 0007, batch_index  400/ 560 , validation accuracy 0.98529
# Team07_HW2.ckpt-complete-0007-batch_index-400
# Epoch: 0007, batch_index  450/ 560 , validation accuracy 0.98464
# Epoch: 0007, batch_index  500/ 560 , validation accuracy 0.98447
# Epoch: 0007, batch_index  550/ 560 , validation accuracy 0.98366
# Epoch: 0008, batch_index    0/ 560 , validation accuracy 0.98382
# Epoch: 0008, batch_index   50/ 560 , validation accuracy 0.98366
# Epoch: 0008, batch_index  100/ 560 , validation accuracy 0.98398
# Epoch: 0008, batch_index  150/ 560 , validation accuracy 0.98546
# Team07_HW2.ckpt-complete-0008-batch_index-150
# Epoch: 0008, batch_index  200/ 560 , validation accuracy 0.98513
# Epoch: 0008, batch_index  250/ 560 , validation accuracy 0.98382
# Epoch: 0008, batch_index  300/ 560 , validation accuracy 0.98546
# Epoch: 0008, batch_index  350/ 560 , validation accuracy 0.98513
# Epoch: 0008, batch_index  400/ 560 , validation accuracy 0.98447
# Epoch: 0008, batch_index  450/ 560 , validation accuracy 0.98497
# Epoch: 0008, batch_index  500/ 560 , validation accuracy 0.98251
# Epoch: 0008, batch_index  550/ 560 , validation accuracy 0.98170
# Epoch: 0009, batch_index    0/ 560 , validation accuracy 0.98170
# Epoch: 0009, batch_index   50/ 560 , validation accuracy 0.98398
# Epoch: 0009, batch_index  100/ 560 , validation accuracy 0.98546
# Epoch: 0009, batch_index  150/ 560 , validation accuracy 0.98513
# Epoch: 0009, batch_index  200/ 560 , validation accuracy 0.98447
# Epoch: 0009, batch_index  250/ 560 , validation accuracy 0.98546
# Epoch: 0009, batch_index  300/ 560 , validation accuracy 0.98447
# Epoch: 0009, batch_index  350/ 560 , validation accuracy 0.98447
# Epoch: 0009, batch_index  400/ 560 , validation accuracy 0.98398
# Epoch: 0009, batch_index  450/ 560 , validation accuracy 0.98497
# Epoch: 0009, batch_index  500/ 560 , validation accuracy 0.98398
# Epoch: 0009, batch_index  550/ 560 , validation accuracy 0.98300
# Epoch: 0010, batch_index    0/ 560 , validation accuracy 0.98317
# Epoch: 0010, batch_index   50/ 560 , validation accuracy 0.98497
# Epoch: 0010, batch_index  100/ 560 , validation accuracy 0.98578
# Team07_HW2.ckpt-complete-0010-batch_index-100
# Epoch: 0010, batch_index  150/ 560 , validation accuracy 0.98464
# Epoch: 0010, batch_index  200/ 560 , validation accuracy 0.98366
# Epoch: 0010, batch_index  250/ 560 , validation accuracy 0.98529
# Epoch: 0010, batch_index  300/ 560 , validation accuracy 0.98480
# Epoch: 0010, batch_index  350/ 560 , validation accuracy 0.98497
# Epoch: 0010, batch_index  400/ 560 , validation accuracy 0.98578
# Epoch: 0010, batch_index  450/ 560 , validation accuracy 0.98431
# Epoch: 0010, batch_index  500/ 560 , validation accuracy 0.98497
# Epoch: 0010, batch_index  550/ 560 , validation accuracy 0.98464
# Epoch: 0011, batch_index    0/ 560 , validation accuracy 0.98464
# Epoch: 0011, batch_index   50/ 560 , validation accuracy 0.98644
# Team07_HW2.ckpt-complete-0011-batch_index-50
# Epoch: 0011, batch_index  100/ 560 , validation accuracy 0.98513
# Epoch: 0011, batch_index  150/ 560 , validation accuracy 0.98611
# Epoch: 0011, batch_index  200/ 560 , validation accuracy 0.98595
# Epoch: 0011, batch_index  250/ 560 , validation accuracy 0.98529
# Epoch: 0011, batch_index  300/ 560 , validation accuracy 0.98497
# Epoch: 0011, batch_index  350/ 560 , validation accuracy 0.98382
# Epoch: 0011, batch_index  400/ 560 , validation accuracy 0.98497
# Epoch: 0011, batch_index  450/ 560 , validation accuracy 0.98562
# Epoch: 0011, batch_index  500/ 560 , validation accuracy 0.98627
# Epoch: 0011, batch_index  550/ 560 , validation accuracy 0.98611
# Epoch: 0012, batch_index    0/ 560 , validation accuracy 0.98611
# Epoch: 0012, batch_index   50/ 560 , validation accuracy 0.98627
# Epoch: 0012, batch_index  100/ 560 , validation accuracy 0.98513
# Epoch: 0012, batch_index  150/ 560 , validation accuracy 0.98546
# Epoch: 0012, batch_index  200/ 560 , validation accuracy 0.98431
# Epoch: 0012, batch_index  250/ 560 , validation accuracy 0.98513
# Epoch: 0012, batch_index  300/ 560 , validation accuracy 0.98595
# Epoch: 0012, batch_index  350/ 560 , validation accuracy 0.98611
# Epoch: 0012, batch_index  400/ 560 , validation accuracy 0.98497
# Epoch: 0012, batch_index  450/ 560 , validation accuracy 0.98644
# Team07_HW2.ckpt-complete-0012-batch_index-450
# Epoch: 0012, batch_index  500/ 560 , validation accuracy 0.98513
# Epoch: 0012, batch_index  550/ 560 , validation accuracy 0.98497
# Epoch: 0013, batch_index    0/ 560 , validation accuracy 0.98497
# Epoch: 0013, batch_index   50/ 560 , validation accuracy 0.98513
# Epoch: 0013, batch_index  100/ 560 , validation accuracy 0.98611
# Epoch: 0013, batch_index  150/ 560 , validation accuracy 0.98627
# Epoch: 0013, batch_index  200/ 560 , validation accuracy 0.98627
# Epoch: 0013, batch_index  250/ 560 , validation accuracy 0.98529
# Epoch: 0013, batch_index  300/ 560 , validation accuracy 0.98644
# Epoch: 0013, batch_index  350/ 560 , validation accuracy 0.98546
# Epoch: 0013, batch_index  400/ 560 , validation accuracy 0.98529
# Epoch: 0013, batch_index  450/ 560 , validation accuracy 0.98611
# Epoch: 0013, batch_index  500/ 560 , validation accuracy 0.98595
# Epoch: 0013, batch_index  550/ 560 , validation accuracy 0.98595
# Epoch: 0014, batch_index    0/ 560 , validation accuracy 0.98595
# Epoch: 0014, batch_index   50/ 560 , validation accuracy 0.98627
# Epoch: 0014, batch_index  100/ 560 , validation accuracy 0.98611
# Epoch: 0014, batch_index  150/ 560 , validation accuracy 0.98676
# Team07_HW2.ckpt-complete-0014-batch_index-150
# Epoch: 0014, batch_index  200/ 560 , validation accuracy 0.98578
# Epoch: 0014, batch_index  250/ 560 , validation accuracy 0.98562
# Epoch: 0014, batch_index  300/ 560 , validation accuracy 0.98447
# Epoch: 0014, batch_index  350/ 560 , validation accuracy 0.98578
# Epoch: 0014, batch_index  400/ 560 , validation accuracy 0.98627
# Epoch: 0014, batch_index  450/ 560 , validation accuracy 0.98709
# Team07_HW2.ckpt-complete-0014-batch_index-450
# Epoch: 0014, batch_index  500/ 560 , validation accuracy 0.98578
# Epoch: 0014, batch_index  550/ 560 , validation accuracy 0.98627
# Epoch: 0015, batch_index    0/ 560 , validation accuracy 0.98627
# Epoch: 0015, batch_index   50/ 560 , validation accuracy 0.98709
# Epoch: 0015, batch_index  100/ 560 , validation accuracy 0.98578
# Epoch: 0015, batch_index  150/ 560 , validation accuracy 0.98578
# Epoch: 0015, batch_index  200/ 560 , validation accuracy 0.98595
# Epoch: 0015, batch_index  250/ 560 , validation accuracy 0.98480
# Epoch: 0015, batch_index  300/ 560 , validation accuracy 0.98562
# Epoch: 0015, batch_index  350/ 560 , validation accuracy 0.98562
# Epoch: 0015, batch_index  400/ 560 , validation accuracy 0.98611
# Epoch: 0015, batch_index  450/ 560 , validation accuracy 0.98676
# Epoch: 0015, batch_index  500/ 560 , validation accuracy 0.98595
# Epoch: 0015, batch_index  550/ 560 , validation accuracy 0.98595
# Epoch: 0016, batch_index    0/ 560 , validation accuracy 0.98595
# Epoch: 0016, batch_index   50/ 560 , validation accuracy 0.98644
# Epoch: 0016, batch_index  100/ 560 , validation accuracy 0.98578
# Epoch: 0016, batch_index  150/ 560 , validation accuracy 0.98611
# Epoch: 0016, batch_index  200/ 560 , validation accuracy 0.98611
# Epoch: 0016, batch_index  250/ 560 , validation accuracy 0.98611
# Epoch: 0016, batch_index  300/ 560 , validation accuracy 0.98693
# Epoch: 0016, batch_index  350/ 560 , validation accuracy 0.98546
# Epoch: 0016, batch_index  400/ 560 , validation accuracy 0.98676
# Epoch: 0016, batch_index  450/ 560 , validation accuracy 0.98513
# Epoch: 0016, batch_index  500/ 560 , validation accuracy 0.98546
# Epoch: 0016, batch_index  550/ 560 , validation accuracy 0.98578
# Epoch: 0017, batch_index    0/ 560 , validation accuracy 0.98578
# Epoch: 0017, batch_index   50/ 560 , validation accuracy 0.98627
# Epoch: 0017, batch_index  100/ 560 , validation accuracy 0.98627
# Epoch: 0017, batch_index  150/ 560 , validation accuracy 0.98562
# Epoch: 0017, batch_index  200/ 560 , validation accuracy 0.98578
# Epoch: 0017, batch_index  250/ 560 , validation accuracy 0.98578
# Epoch: 0017, batch_index  300/ 560 , validation accuracy 0.98644
# Epoch: 0017, batch_index  350/ 560 , validation accuracy 0.98595
# Epoch: 0017, batch_index  400/ 560 , validation accuracy 0.98562
# Epoch: 0017, batch_index  450/ 560 , validation accuracy 0.98660
# Epoch: 0017, batch_index  500/ 560 , validation accuracy 0.98611
# Epoch: 0017, batch_index  550/ 560 , validation accuracy 0.98546
# Epoch: 0018, batch_index    0/ 560 , validation accuracy 0.98546
# Epoch: 0018, batch_index   50/ 560 , validation accuracy 0.98660
# Epoch: 0018, batch_index  100/ 560 , validation accuracy 0.98611
# Epoch: 0018, batch_index  150/ 560 , validation accuracy 0.98529
# Epoch: 0018, batch_index  200/ 560 , validation accuracy 0.98611
# Epoch: 0018, batch_index  250/ 560 , validation accuracy 0.98578
# Epoch: 0018, batch_index  300/ 560 , validation accuracy 0.98644
# Epoch: 0018, batch_index  350/ 560 , validation accuracy 0.98627
# Epoch: 0018, batch_index  400/ 560 , validation accuracy 0.98660
# Epoch: 0018, batch_index  450/ 560 , validation accuracy 0.98644
# Epoch: 0018, batch_index  500/ 560 , validation accuracy 0.98595
# Epoch: 0018, batch_index  550/ 560 , validation accuracy 0.98562
# Epoch: 0019, batch_index    0/ 560 , validation accuracy 0.98578
# Epoch: 0019, batch_index   50/ 560 , validation accuracy 0.98546
# Epoch: 0019, batch_index  100/ 560 , validation accuracy 0.98627
# Epoch: 0019, batch_index  150/ 560 , validation accuracy 0.98644
# Epoch: 0019, batch_index  200/ 560 , validation accuracy 0.98660
# Epoch: 0019, batch_index  250/ 560 , validation accuracy 0.98529
# Epoch: 0019, batch_index  300/ 560 , validation accuracy 0.98627
# Epoch: 0019, batch_index  350/ 560 , validation accuracy 0.98578
# Epoch: 0019, batch_index  400/ 560 , validation accuracy 0.98595
# Epoch: 0019, batch_index  450/ 560 , validation accuracy 0.98611
# Epoch: 0019, batch_index  500/ 560 , validation accuracy 0.98513
# Epoch: 0019, batch_index  550/ 560 , validation accuracy 0.98513
# Epoch: 0020, batch_index    0/ 560 , validation accuracy 0.98513
# Epoch: 0020, batch_index   50/ 560 , validation accuracy 0.98562
# Epoch: 0020, batch_index  100/ 560 , validation accuracy 0.98611
# Epoch: 0020, batch_index  150/ 560 , validation accuracy 0.98562
# Epoch: 0020, batch_index  200/ 560 , validation accuracy 0.98611
# Epoch: 0020, batch_index  250/ 560 , validation accuracy 0.98595
# Epoch: 0020, batch_index  300/ 560 , validation accuracy 0.98725
# Team07_HW2.ckpt-complete-0020-batch_index-300
# Epoch: 0020, batch_index  350/ 560 , validation accuracy 0.98709
# Epoch: 0020, batch_index  400/ 560 , validation accuracy 0.98578
# Epoch: 0020, batch_index  450/ 560 , validation accuracy 0.98627
# Epoch: 0020, batch_index  500/ 560 , validation accuracy 0.98644
# Epoch: 0020, batch_index  550/ 560 , validation accuracy 0.98644
# Epoch: 0021, batch_index    0/ 560 , validation accuracy 0.98644
# Epoch: 0021, batch_index   50/ 560 , validation accuracy 0.98611
# Epoch: 0021, batch_index  100/ 560 , validation accuracy 0.98660
# Epoch: 0021, batch_index  150/ 560 , validation accuracy 0.98725
# Team07_HW2.ckpt-complete-0021-batch_index-150
# Epoch: 0021, batch_index  200/ 560 , validation accuracy 0.98627
# Epoch: 0021, batch_index  250/ 560 , validation accuracy 0.98742
# Team07_HW2.ckpt-complete-0021-batch_index-250
# Epoch: 0021, batch_index  300/ 560 , validation accuracy 0.98578
# Epoch: 0021, batch_index  350/ 560 , validation accuracy 0.98611
# Epoch: 0021, batch_index  400/ 560 , validation accuracy 0.98611
# Epoch: 0021, batch_index  450/ 560 , validation accuracy 0.98546
# Epoch: 0021, batch_index  500/ 560 , validation accuracy 0.98644
# Epoch: 0021, batch_index  550/ 560 , validation accuracy 0.98644
# Epoch: 0022, batch_index    0/ 560 , validation accuracy 0.98660
# Epoch: 0022, batch_index   50/ 560 , validation accuracy 0.98644
# Epoch: 0022, batch_index  100/ 560 , validation accuracy 0.98595
# Epoch: 0022, batch_index  150/ 560 , validation accuracy 0.98562
# Epoch: 0022, batch_index  200/ 560 , validation accuracy 0.98627
# Epoch: 0022, batch_index  250/ 560 , validation accuracy 0.98627
# Epoch: 0022, batch_index  300/ 560 , validation accuracy 0.98758
# Team07_HW2.ckpt-complete-0022-batch_index-300
# Epoch: 0022, batch_index  350/ 560 , validation accuracy 0.98595
# Epoch: 0022, batch_index  400/ 560 , validation accuracy 0.98644
# Epoch: 0022, batch_index  450/ 560 , validation accuracy 0.98725
# Epoch: 0022, batch_index  500/ 560 , validation accuracy 0.98676
# Epoch: 0022, batch_index  550/ 560 , validation accuracy 0.98644
# Epoch: 0023, batch_index    0/ 560 , validation accuracy 0.98644
# Epoch: 0023, batch_index   50/ 560 , validation accuracy 0.98627
# Epoch: 0023, batch_index  100/ 560 , validation accuracy 0.98578
# Epoch: 0023, batch_index  150/ 560 , validation accuracy 0.98578
# Epoch: 0023, batch_index  200/ 560 , validation accuracy 0.98676
# Epoch: 0023, batch_index  250/ 560 , validation accuracy 0.98562
# Epoch: 0023, batch_index  300/ 560 , validation accuracy 0.98627
# Epoch: 0023, batch_index  350/ 560 , validation accuracy 0.98611
# ...
# Epoch: 0053, batch_index  300/ 560 , validation accuracy 0.99101
# Epoch: 0053, batch_index  350/ 560 , validation accuracy 0.99085
# Epoch: 0053, batch_index  400/ 560 , validation accuracy 0.99118
# Epoch: 0053, batch_index  450/ 560 , validation accuracy 0.99118
# Epoch: 0053, batch_index  500/ 560 , validation accuracy 0.99118
# Epoch: 0053, batch_index  550/ 560 , validation accuracy 0.99118
# Epoch: 0054, batch_index    0/ 560 , validation accuracy 0.99118
# Epoch: 0054, batch_index   50/ 560 , validation accuracy 0.99118
# Epoch: 0054, batch_index  100/ 560 , validation accuracy 0.99101
# Epoch: 0054, batch_index  150/ 560 , validation accuracy 0.99101
# Epoch: 0054, batch_index  200/ 560 , validation accuracy 0.99118
# Epoch: 0054, batch_index  250/ 560 , validation accuracy 0.99134
# Epoch: 0054, batch_index  300/ 560 , validation accuracy 0.99118
# Epoch: 0054, batch_index  350/ 560 , validation accuracy 0.99118
# Epoch: 0054, batch_index  400/ 560 , validation accuracy 0.99101
# Epoch: 0054, batch_index  450/ 560 , validation accuracy 0.99134
# Epoch: 0054, batch_index  500/ 560 , validation accuracy 0.99101
# Epoch: 0054, batch_index  550/ 560 , validation accuracy 0.99101
# Epoch: 0055, batch_index    0/ 560 , validation accuracy 0.99101
# Epoch: 0055, batch_index   50/ 560 , validation accuracy 0.99118
# Epoch: 0055, batch_index  100/ 560 , validation accuracy 0.99101
# Epoch: 0055, batch_index  150/ 560 , validation accuracy 0.99101
# Epoch: 0055, batch_index  200/ 560 , validation accuracy 0.99101
# Epoch: 0055, batch_index  250/ 560 , validation accuracy 0.99101
# Epoch: 0055, batch_index  300/ 560 , validation accuracy 0.99118
# Epoch: 0055, batch_index  350/ 560 , validation accuracy 0.99118
# Epoch: 0055, batch_index  400/ 560 , validation accuracy 0.99085
# Epoch: 0055, batch_index  450/ 560 , validation accuracy 0.99101
# Epoch: 0055, batch_index  500/ 560 , validation accuracy 0.99101
# Epoch: 0055, batch_index  550/ 560 , validation accuracy 0.99118
# Epoch: 0056, batch_index    0/ 560 , validation accuracy 0.99118
# Epoch: 0056, batch_index   50/ 560 , validation accuracy 0.99118
# Epoch: 0056, batch_index  100/ 560 , validation accuracy 0.99118
# Epoch: 0056, batch_index  150/ 560 , validation accuracy 0.99118
# Epoch: 0056, batch_index  200/ 560 , validation accuracy 0.99134
# Epoch: 0056, batch_index  250/ 560 , validation accuracy 0.99118
# Epoch: 0056, batch_index  300/ 560 , validation accuracy 0.99101
# early_stop...........
# Fold:  5,
# Epoch: 0001, batch_index    0/ 560 , validation accuracy 0.00000
# Epoch: 0001, batch_index   50/ 560 , validation accuracy 0.00000
# Epoch: 0001, batch_index  100/ 560 , validation accuracy 1.00000
# Team07_HW2.ckpt-complete-0001-batch_index-100
# Epoch: 0001, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0001, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0001, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0001, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0001, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0001, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0001, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0001, batch_index  500/ 560 , validation accuracy 1.00000
# Epoch: 0001, batch_index  550/ 560 , validation accuracy 1.00000
# Epoch: 0002, batch_index    0/ 560 , validation accuracy 1.00000
# Epoch: 0002, batch_index   50/ 560 , validation accuracy 1.00000
# Epoch: 0002, batch_index  100/ 560 , validation accuracy 1.00000
# Epoch: 0002, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0002, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0002, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0002, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0002, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0002, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0002, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0002, batch_index  500/ 560 , validation accuracy 1.00000
# Epoch: 0002, batch_index  550/ 560 , validation accuracy 1.00000
# Epoch: 0003, batch_index    0/ 560 , validation accuracy 1.00000
# Epoch: 0003, batch_index   50/ 560 , validation accuracy 1.00000
# Epoch: 0003, batch_index  100/ 560 , validation accuracy 1.00000
# Epoch: 0003, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0003, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0003, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0003, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0003, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0003, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0003, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0003, batch_index  500/ 560 , validation accuracy 1.00000
# Epoch: 0003, batch_index  550/ 560 , validation accuracy 1.00000
# Epoch: 0004, batch_index    0/ 560 , validation accuracy 1.00000
# Epoch: 0004, batch_index   50/ 560 , validation accuracy 1.00000
# Epoch: 0004, batch_index  100/ 560 , validation accuracy 1.00000
# Epoch: 0004, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0004, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0004, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0004, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0004, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0004, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0004, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0004, batch_index  500/ 560 , validation accuracy 1.00000
# Epoch: 0004, batch_index  550/ 560 , validation accuracy 1.00000
# Epoch: 0005, batch_index    0/ 560 , validation accuracy 1.00000
# Epoch: 0005, batch_index   50/ 560 , validation accuracy 1.00000
# Epoch: 0005, batch_index  100/ 560 , validation accuracy 1.00000
# Epoch: 0005, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0005, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0005, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0005, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0005, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0005, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0005, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0005, batch_index  500/ 560 , validation accuracy 1.00000
# Epoch: 0005, batch_index  550/ 560 , validation accuracy 1.00000
# Epoch: 0006, batch_index    0/ 560 , validation accuracy 1.00000
# Epoch: 0006, batch_index   50/ 560 , validation accuracy 1.00000
# Epoch: 0006, batch_index  100/ 560 , validation accuracy 1.00000
# Epoch: 0006, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0006, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0006, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0006, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0006, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0006, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0006, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0006, batch_index  500/ 560 , validation accuracy 1.00000
# Epoch: 0006, batch_index  550/ 560 , validation accuracy 1.00000
# Epoch: 0007, batch_index    0/ 560 , validation accuracy 1.00000
# Epoch: 0007, batch_index   50/ 560 , validation accuracy 1.00000
# Epoch: 0007, batch_index  100/ 560 , validation accuracy 1.00000
# Epoch: 0007, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0007, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0007, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0007, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0007, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0007, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0007, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0007, batch_index  500/ 560 , validation accuracy 1.00000
# Epoch: 0007, batch_index  550/ 560 , validation accuracy 1.00000
# Epoch: 0008, batch_index    0/ 560 , validation accuracy 1.00000
# Epoch: 0008, batch_index   50/ 560 , validation accuracy 1.00000
# Epoch: 0008, batch_index  100/ 560 , validation accuracy 1.00000
# Epoch: 0008, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0008, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0008, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0008, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0008, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0008, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0008, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0008, batch_index  500/ 560 , validation accuracy 1.00000
# Epoch: 0008, batch_index  550/ 560 , validation accuracy 1.00000
# Epoch: 0009, batch_index    0/ 560 , validation accuracy 1.00000
# Epoch: 0009, batch_index   50/ 560 , validation accuracy 1.00000
# Epoch: 0009, batch_index  100/ 560 , validation accuracy 1.00000
# Epoch: 0009, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0009, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0009, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0009, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0009, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0009, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0009, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0009, batch_index  500/ 560 , validation accuracy 1.00000
# Epoch: 0009, batch_index  550/ 560 , validation accuracy 1.00000
# Epoch: 0010, batch_index    0/ 560 , validation accuracy 1.00000
# Epoch: 0010, batch_index   50/ 560 , validation accuracy 1.00000
# Epoch: 0010, batch_index  100/ 560 , validation accuracy 1.00000
# Epoch: 0010, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0010, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0010, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0010, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0010, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0010, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0010, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0010, batch_index  500/ 560 , validation accuracy 1.00000
# Epoch: 0010, batch_index  550/ 560 , validation accuracy 1.00000
# Epoch: 0011, batch_index    0/ 560 , validation accuracy 1.00000
# Epoch: 0011, batch_index   50/ 560 , validation accuracy 1.00000
# Epoch: 0011, batch_index  100/ 560 , validation accuracy 1.00000
# Epoch: 0011, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0011, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0011, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0011, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0011, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0011, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0011, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0011, batch_index  500/ 560 , validation accuracy 1.00000
# Epoch: 0011, batch_index  550/ 560 , validation accuracy 1.00000
# Epoch: 0012, batch_index    0/ 560 , validation accuracy 1.00000
# Epoch: 0012, batch_index   50/ 560 , validation accuracy 1.00000
# Epoch: 0012, batch_index  100/ 560 , validation accuracy 1.00000
# Epoch: 0012, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0012, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0012, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0012, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0012, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0012, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0012, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0012, batch_index  500/ 560 , validation accuracy 1.00000
# Epoch: 0012, batch_index  550/ 560 , validation accuracy 1.00000
# Epoch: 0013, batch_index    0/ 560 , validation accuracy 1.00000
# Epoch: 0013, batch_index   50/ 560 , validation accuracy 1.00000
# Epoch: 0013, batch_index  100/ 560 , validation accuracy 1.00000
# Epoch: 0013, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0013, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0013, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0013, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0013, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0013, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0013, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0013, batch_index  500/ 560 , validation accuracy 1.00000
# Epoch: 0013, batch_index  550/ 560 , validation accuracy 1.00000
# Epoch: 0014, batch_index    0/ 560 , validation accuracy 1.00000
# Epoch: 0014, batch_index   50/ 560 , validation accuracy 1.00000
# Epoch: 0014, batch_index  100/ 560 , validation accuracy 1.00000
# Epoch: 0014, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0014, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0014, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0014, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0014, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0014, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0014, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0014, batch_index  500/ 560 , validation accuracy 1.00000
# Epoch: 0014, batch_index  550/ 560 , validation accuracy 1.00000
# Epoch: 0015, batch_index    0/ 560 , validation accuracy 1.00000
# Epoch: 0015, batch_index   50/ 560 , validation accuracy 1.00000
# Epoch: 0015, batch_index  100/ 560 , validation accuracy 1.00000
# Epoch: 0015, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0015, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0015, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0015, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0015, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0015, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0015, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0015, batch_index  500/ 560 , validation accuracy 1.00000
# Epoch: 0015, batch_index  550/ 560 , validation accuracy 1.00000
# Epoch: 0016, batch_index    0/ 560 , validation accuracy 1.00000
# Epoch: 0016, batch_index   50/ 560 , validation accuracy 1.00000
# Epoch: 0016, batch_index  100/ 560 , validation accuracy 1.00000
# Epoch: 0016, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0016, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0016, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0016, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0016, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0016, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0016, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0016, batch_index  500/ 560 , validation accuracy 1.00000
# Epoch: 0016, batch_index  550/ 560 , validation accuracy 1.00000
# Epoch: 0017, batch_index    0/ 560 , validation accuracy 1.00000
# Epoch: 0017, batch_index   50/ 560 , validation accuracy 1.00000
# Epoch: 0017, batch_index  100/ 560 , validation accuracy 1.00000
# Epoch: 0017, batch_index  150/ 560 , validation accuracy 1.00000
# Epoch: 0017, batch_index  200/ 560 , validation accuracy 1.00000
# Epoch: 0017, batch_index  250/ 560 , validation accuracy 1.00000
# Epoch: 0017, batch_index  300/ 560 , validation accuracy 1.00000
# Epoch: 0017, batch_index  350/ 560 , validation accuracy 1.00000
# Epoch: 0017, batch_index  400/ 560 , validation accuracy 1.00000
# Epoch: 0017, batch_index  450/ 560 , validation accuracy 1.00000
# Epoch: 0017, batch_index  500/ 560 , validation accuracy 1.00000
# early_stop...........
# [0.99831688, 0.99879777, 0.99783599, 0.99927866, 0.99807644]
# [0.99046499, 0.99143797, 0.99046499, 0.99318933, 0.99143791]
# [0.99879724, 0.99879777, 0.99831611, 0.99879837, 0.99903733]
# 1. 5-Fold平均正確率 :  0.998461 2. 5-Fold平均精確率 :  0.998749 3. 5-Fold平均Recall :  0.991399
