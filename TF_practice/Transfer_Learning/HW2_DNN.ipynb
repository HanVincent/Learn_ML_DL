# %%
import numpy as np
import os
import tensorflow as tf
from sklearn.metrics import classification_report ## 印出可視覺化的表

###### Do not modify here ###### 

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

reset_graph()

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/")

# training on MNIST but only on digits 0 to 4
X_train1 = mnist.train.images[mnist.train.labels < 5]
y_train1 = mnist.train.labels[mnist.train.labels < 5]
X_valid1 = mnist.validation.images[mnist.validation.labels < 5]
y_valid1 = mnist.validation.labels[mnist.validation.labels < 5]
X_test1 = mnist.test.images[mnist.test.labels < 5]
y_test1 = mnist.test.labels[mnist.test.labels < 5]

###### Do not modify here ######
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
##############################################
#                                            #
#               基礎版本                      #
#                                            #
##############################################

# %%
### 先前設置 
in_units = 784 # 28 * 28 拉直後 = 784維 
h_units = [128, 128, 128, 128, 128] # 題目要求5層hidden layers，及每一層128neurons
n_class = 5 # 題目要求只要辨識 0 ,1 ,2 ,3 及4 ，共5個類別

n_train = len(X_train1) # train資料的長度
batch_size = 100
n_batch = n_train // batch_size

X = tf.placeholder(tf.float32,[None,in_units], name="X") # 初始化x資料型態為[None,784]
y = tf.placeholder(tf.int64, shape=(None), name="y") # 初始化y資料型態[None]

# %%
# [128, 128, 128, 128, 128]
def L_layers_model(X, h_units, n_class, dropout=None):
    # default he_init: factor=2.0, mode='FAN_IN', uniform=False, seed=None, dtype=tf.float32
    he_init = tf.contrib.layers.variance_scaling_initializer()
#     hidden = { "layer0": X }
    
    with tf.name_scope("DNN"):
        hidden = X
        for i in range(len(h_units)):
            hidden = (tf.layers.dense(hidden, h_units[i], 
                                      name="hidden" + str(i+1), 
                                      use_bias=True, kernel_initializer= he_init,
                                      bias_initializer=he_init, activation=tf.nn.elu))
            if dropout:
                hidden = tf.layers.dropout(hidden, rate=dropout)
            
        # 結合之後的 tf.nn.sparse_softmax_cross_entropy_with_logits [128 , 5]
        logits = tf.layers.dense(hidden, n_class, name="logits")
        Y_proba = tf.nn.softmax(logits, name="Y_proba")
    
    return Y_proba

def train_op(y, logits):
    with tf.name_scope("calc_loss"):
        entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
        loss = tf.reduce_mean(entropy, name="loss")
    
    ## 此區使用AdamOptimizer 的優化器進行梯度優化
    with tf.name_scope("train"):
        batch = tf.Variable(0)

        learning_rate = tf.train.exponential_decay(
                1e-4,  # Base learning rate.
                batch * batch_size,  # Current index into the dataset.
                n_train,  # Decay step.
                0.95,  # Decay rate.
                staircase=True)
        
        optimizer = tf.train.AdamOptimizer(learning_rate)
        training_op = optimizer.minimize(loss, global_step=batch, name="training_op")

    return (loss, training_op)

def acc_model(y, logits):
    #計算正確率   
    with tf.name_scope('calc_accuracy'):
        correct = tf.equal(tf.argmax(logits, 1), y)
        accuracy = tf.reduce_mean(tf.cast(correct, tf.float32), name="accuracy")

    #計算precision 因返回會有兩個值，只取後者
    with tf.name_scope('calc_precision'):
        _, precision = tf.metrics.precision(predictions=tf.argmax(logits,1), labels=y, name="precision")

    #計算recall 因返回會有兩個值，只取後者
    with tf.name_scope('calc_recall'):
        _, recall = tf.metrics.recall(predictions=tf.argmax(logits,1), labels=y, name="recall")

    return (accuracy, precision, recall)


def shuffle_data(data, labels):
    idx = np.random.permutation(len(data))
    data, label = data[idx], labels[idx]
    return (data, label)

# %%
logits = L_layers_model(X, h_units, n_class)
loss, train_op = train_op(y, logits)
accuracy, precision, recall = acc_model(y, logits)

checkpoint_dir = 'save/'  # model儲存位址
saver = tf.train.Saver()  # call save function

config = tf.ConfigProto(device_count = {'GPU': 1}) #指定gpu

# %%
# Params for Train
epochs = 1000 # 10 for augmented training data, 20 for training data
val_step = 50 # 當 50 步時去算一次驗證資料的正確率
early_stop = 20
# display_step = 100  # 你可以用這個去建一個規則去看train的正確率，但本專案先不用

init = tf.global_variables_initializer()
init_l = tf.local_variables_initializer()

# %%
def run(sess, X_train1, y_train1, X_valid1, y_valid1):
    max_acc = 0. # Save the maximum accuracy value for validation data
    early_stop_limit = 0 # 紀錄early_stop的值
        
    sess.run([init, init_l])
    summary_writer = tf.summary.FileWriter('tensorboard/', graph=tf.get_default_graph())
    
    # 可以自己選擇大概要幾個epoch，因為我們有early stop的方法，所以不怕一直train
    for epoch in range(epochs):
        if early_stop_limit >= early_stop: 
            print('early_stop...........')
            break

        # Random shuffling
        train_data, train_label = shuffle_data(X_train1, y_train1)

        # 用批次的方式去訓練 model
        for i in range(n_batch):
            # Compute the offset of the current minibatch in the data.
            offset = (i * batch_size) % (n_train)
            batch_xs = train_data[offset:(offset + batch_size), :]
            batch_ys = train_label[offset:(offset + batch_size)]
            sess.run([train_op, loss], feed_dict={X: batch_xs, y: batch_ys})

            # 每 n step時，model去看此時的驗證資料的正確率並印出來
            if i % val_step == 0:
                val_acc = sess.run(accuracy, feed_dict={X: X_valid1, y: y_valid1})
                print("Epoch:", '%04d,' % (epoch + 1), 
                      "batch_index %4d/%4d , validation accuracy %.5f" % (i, n_batch, val_acc))

                # 透過最大驗證正確率大於每一次的驗證正確率的條件來設定 early stop
                if max_acc >= val_acc:
                    early_stop_limit += 1
                    if early_stop_limit == early_stop: # 自己可以去限制最大驗證正確率不再變n次時，就停止訓練
                        break

                # 如果 val_acc 大於 max_acc，則取代它並儲存一次結果
                else: # validation_accuracy > max_acc
                    early_stop_limit = 0
                    max_acc = val_acc
                    saver.save(sess, checkpoint_dir + 'Team07_HW2.ckpt')                        
                    print('Team07_HW2.ckpt-' + 'complete-%04d-' % (epoch + 1) + 
                          "batch_index-%d" % i)

# %%
with tf.Session(config=config) as sess:
    run(sess, X_train1, y_train1, X_valid1, y_valid1)
    
    sess.run(init_l)
    saver.restore(sess, 'save/Team07_HW2.ckpt') # 開啟剛剛 early_stop 的 model

    print('Acc_test :' , sess.run(accuracy, feed_dict={X: X_test1, y: y_test1}))
    print('Prec_value :' , sess.run(precision, feed_dict={X: X_test1, y: y_test1}))
    print('Recall_value :' , sess.run(recall, feed_dict={X: X_test1, y: y_test1}))
    
    ## model去測試測試集並將label的結果記錄下來 
    pre = sess.run(tf.argmax(logits, 1), feed_dict={X: X_test1})

    ## 列印出測試資料的報表
    print(classification_report(y_test1.ravel(), pre))
# Out:
# Epoch: 0001, batch_index    0/ 280 , validation accuracy 0.27600
# Team07_HW2.ckpt-complete-0001-batch_index-0
# Epoch: 0001, batch_index   50/ 280 , validation accuracy 0.92377
# Team07_HW2.ckpt-complete-0001-batch_index-50
# Epoch: 0001, batch_index  100/ 280 , validation accuracy 0.94801
# Team07_HW2.ckpt-complete-0001-batch_index-100
# Epoch: 0001, batch_index  150/ 280 , validation accuracy 0.95622
# Team07_HW2.ckpt-complete-0001-batch_index-150
# Epoch: 0001, batch_index  200/ 280 , validation accuracy 0.96013
# Team07_HW2.ckpt-complete-0001-batch_index-200
# Epoch: 0001, batch_index  250/ 280 , validation accuracy 0.96325
# Team07_HW2.ckpt-complete-0001-batch_index-250
# Epoch: 0002, batch_index    0/ 280 , validation accuracy 0.96560
# Team07_HW2.ckpt-complete-0002-batch_index-0
# Epoch: 0002, batch_index   50/ 280 , validation accuracy 0.96716
# Team07_HW2.ckpt-complete-0002-batch_index-50
# Epoch: 0002, batch_index  100/ 280 , validation accuracy 0.96833
# Team07_HW2.ckpt-complete-0002-batch_index-100
# Epoch: 0002, batch_index  150/ 280 , validation accuracy 0.96873
# Team07_HW2.ckpt-complete-0002-batch_index-150
# Epoch: 0002, batch_index  200/ 280 , validation accuracy 0.97185
# Team07_HW2.ckpt-complete-0002-batch_index-200
# Epoch: 0002, batch_index  250/ 280 , validation accuracy 0.97459
# Team07_HW2.ckpt-complete-0002-batch_index-250
# Epoch: 0003, batch_index    0/ 280 , validation accuracy 0.97342
# Epoch: 0003, batch_index   50/ 280 , validation accuracy 0.97498
# Team07_HW2.ckpt-complete-0003-batch_index-50
# Epoch: 0003, batch_index  100/ 280 , validation accuracy 0.97615
# Team07_HW2.ckpt-complete-0003-batch_index-100
# Epoch: 0003, batch_index  150/ 280 , validation accuracy 0.97694
# Team07_HW2.ckpt-complete-0003-batch_index-150
# Epoch: 0003, batch_index  200/ 280 , validation accuracy 0.97694
# Epoch: 0003, batch_index  250/ 280 , validation accuracy 0.97694
# Epoch: 0004, batch_index    0/ 280 , validation accuracy 0.97850
# Team07_HW2.ckpt-complete-0004-batch_index-0
# Epoch: 0004, batch_index   50/ 280 , validation accuracy 0.97811
# Epoch: 0004, batch_index  100/ 280 , validation accuracy 0.97733
# Epoch: 0004, batch_index  150/ 280 , validation accuracy 0.98006
# Team07_HW2.ckpt-complete-0004-batch_index-150
# Epoch: 0004, batch_index  200/ 280 , validation accuracy 0.97928
# Epoch: 0004, batch_index  250/ 280 , validation accuracy 0.97889
# Epoch: 0005, batch_index    0/ 280 , validation accuracy 0.97889
# Epoch: 0005, batch_index   50/ 280 , validation accuracy 0.98006
# Epoch: 0005, batch_index  100/ 280 , validation accuracy 0.98163
# Team07_HW2.ckpt-complete-0005-batch_index-100
# Epoch: 0005, batch_index  150/ 280 , validation accuracy 0.98163
# Epoch: 0005, batch_index  200/ 280 , validation accuracy 0.98006
# Epoch: 0005, batch_index  250/ 280 , validation accuracy 0.98163
# Team07_HW2.ckpt-complete-0005-batch_index-250
# Epoch: 0006, batch_index    0/ 280 , validation accuracy 0.98006
# Epoch: 0006, batch_index   50/ 280 , validation accuracy 0.98124
# Epoch: 0006, batch_index  100/ 280 , validation accuracy 0.98084
# Epoch: 0006, batch_index  150/ 280 , validation accuracy 0.97967
# Epoch: 0006, batch_index  200/ 280 , validation accuracy 0.98124
# Epoch: 0006, batch_index  250/ 280 , validation accuracy 0.98124
# Epoch: 0007, batch_index    0/ 280 , validation accuracy 0.98241
# Team07_HW2.ckpt-complete-0007-batch_index-0
# Epoch: 0007, batch_index   50/ 280 , validation accuracy 0.98045
# Epoch: 0007, batch_index  100/ 280 , validation accuracy 0.98163
# Epoch: 0007, batch_index  150/ 280 , validation accuracy 0.98163
# Epoch: 0007, batch_index  200/ 280 , validation accuracy 0.98202
# Epoch: 0007, batch_index  250/ 280 , validation accuracy 0.98084
# Epoch: 0008, batch_index    0/ 280 , validation accuracy 0.98241
# Epoch: 0008, batch_index   50/ 280 , validation accuracy 0.98124
# Epoch: 0008, batch_index  100/ 280 , validation accuracy 0.98280
# Team07_HW2.ckpt-complete-0008-batch_index-100
# Epoch: 0008, batch_index  150/ 280 , validation accuracy 0.98280
# Epoch: 0008, batch_index  200/ 280 , validation accuracy 0.98319
# Team07_HW2.ckpt-complete-0008-batch_index-200
# Epoch: 0008, batch_index  250/ 280 , validation accuracy 0.98319
# Epoch: 0009, batch_index    0/ 280 , validation accuracy 0.98202
# Epoch: 0009, batch_index   50/ 280 , validation accuracy 0.98202
# Epoch: 0009, batch_index  100/ 280 , validation accuracy 0.98280
# Epoch: 0009, batch_index  150/ 280 , validation accuracy 0.98202
# Epoch: 0009, batch_index  200/ 280 , validation accuracy 0.98202
# Epoch: 0009, batch_index  250/ 280 , validation accuracy 0.98280
# Epoch: 0010, batch_index    0/ 280 , validation accuracy 0.98319
# Epoch: 0010, batch_index   50/ 280 , validation accuracy 0.98202
# Epoch: 0010, batch_index  100/ 280 , validation accuracy 0.98163
# Epoch: 0010, batch_index  150/ 280 , validation accuracy 0.98241
# Epoch: 0010, batch_index  200/ 280 , validation accuracy 0.98124
# Epoch: 0010, batch_index  250/ 280 , validation accuracy 0.98241
# Epoch: 0011, batch_index    0/ 280 , validation accuracy 0.98241
# Epoch: 0011, batch_index   50/ 280 , validation accuracy 0.98124
# Epoch: 0011, batch_index  100/ 280 , validation accuracy 0.98280
# Epoch: 0011, batch_index  150/ 280 , validation accuracy 0.98319
# Epoch: 0011, batch_index  200/ 280 , validation accuracy 0.98319
# Epoch: 0011, batch_index  250/ 280 , validation accuracy 0.98202
# Epoch: 0012, batch_index    0/ 280 , validation accuracy 0.98241
# early_stop...........
# INFO:tensorflow:Restoring parameters from save/Team07_HW2.ckpt
# Acc_test : 0.985211
# Prec_value : 0.999037
# Recall_value : 0.997836
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99       980
#           1       1.00      0.99      0.99      1135
#           2       0.98      0.96      0.97      1032
#           3       0.99      0.98      0.98      1010
#           4       0.97      0.99      0.98       982
#
# avg / total       0.99      0.99      0.99      5139

# %%
###################################
#                                 #
#     K-FOLD cross validation     #
#                                 #
###################################

# %%
### 額外程式，主要去打亂合併的資料，並做k-fold 的取資料
class CrossValidationFolds(object):
    
    def __init__(self, data, labels, num_folds, shuffle=True):
        self.data = data
        self.labels = labels
        self.num_folds = num_folds
        self.current_fold = 0
        
        # Shuffle Dataset
        if shuffle:
            perm = np.random.permutation(self.data.shape[0]) ##隨機打亂資料
            data = data[perm]
            labels = labels[perm]
    
    def split(self):
        current = self.current_fold
        size = int(self.data.shape[0]/self.num_folds) # 30596 / 5 一塊k的size大小
        
        index = np.arange(self.data.shape[0]) 

        # 利用 True/False 抓出 validation 區塊
        lower_bound = index >= current*size # validation 下界
        upper_bound = index < (current + 1)*size # 上界

        cv_region = lower_bound*upper_bound

        cv_data = self.data[cv_region] # 利用 True/False 抓出 True 的資料
        train_data = self.data[~cv_region]
        
        cv_labels = self.labels[cv_region]
        train_labels = self.labels[~cv_region]
        
        self.current_fold += 1 ## 丟回下一的fold
        return (train_data, train_labels), (cv_data, cv_labels)

# %%
FOLDS = 5 # k = 5

X_train = np.concatenate((X_train1,X_valid1), axis=0)
Y_label = np.concatenate((y_train1,y_valid1), axis=0)
data = CrossValidationFolds(X_train, Y_label, FOLDS)

recall_test = [] # 放每個第n-fold 時的recall值
prec_test = []   # 放每個第n-fold 時的精確值
acc_test = []    # 放每個第n-fold 時的正確率值

# %%
with tf.Session(config=config) as sess:
    for i in range(FOLDS):
        print("Fold: ", '%d,' % (i+1))
        (X_train1, y_train1), (X_valid1, y_valid1) = data.split()
        run(sess, X_train1, y_train1, X_valid1, y_valid1)
                        
        recall_test.append(sess.run(accuracy, feed_dict={X: X_test1, y: y_test1}))
        prec_test.append(sess.run(precision, feed_dict={X: X_test1, y: y_test1}))
        acc_test.append(sess.run(recall, feed_dict={X: X_test1, y: y_test1}))
    
    print(acc_test)
    print(recall_test)
    print(prec_test)
    print('1. 5-Fold平均正確率 : ',np.array(acc_test).mean() , 
          '2. 5-Fold平均精確率 : ',np.array(prec_test).mean() ,
          '3. 5-Fold平均Recall : ',np.array(recall_test).mean())
# Out:
# Fold:  1,
# Epoch: 0001, batch_index    0/ 280 , validation accuracy 0.27292
# Team07_HW2.ckpt-complete-0001-batch_index-0
# Epoch: 0001, batch_index   50/ 280 , validation accuracy 0.91404
# Team07_HW2.ckpt-complete-0001-batch_index-50
# Epoch: 0001, batch_index  100/ 280 , validation accuracy 0.94068
# Team07_HW2.ckpt-complete-0001-batch_index-100
# Epoch: 0001, batch_index  150/ 280 , validation accuracy 0.94917
# Team07_HW2.ckpt-complete-0001-batch_index-150
# Epoch: 0001, batch_index  200/ 280 , validation accuracy 0.95440
# Team07_HW2.ckpt-complete-0001-batch_index-200
# Epoch: 0001, batch_index  250/ 280 , validation accuracy 0.95620
# Team07_HW2.ckpt-complete-0001-batch_index-250
# Epoch: 0002, batch_index    0/ 280 , validation accuracy 0.95506
# Epoch: 0002, batch_index   50/ 280 , validation accuracy 0.95931
# Team07_HW2.ckpt-complete-0002-batch_index-50
# Epoch: 0002, batch_index  100/ 280 , validation accuracy 0.96225
# Team07_HW2.ckpt-complete-0002-batch_index-100
# Epoch: 0002, batch_index  150/ 280 , validation accuracy 0.96307
# Team07_HW2.ckpt-complete-0002-batch_index-150
# Epoch: 0002, batch_index  200/ 280 , validation accuracy 0.96437
# Team07_HW2.ckpt-complete-0002-batch_index-200
# Epoch: 0002, batch_index  250/ 280 , validation accuracy 0.96486
# Team07_HW2.ckpt-complete-0002-batch_index-250
# Epoch: 0003, batch_index    0/ 280 , validation accuracy 0.96470
# Epoch: 0003, batch_index   50/ 280 , validation accuracy 0.96454
# Epoch: 0003, batch_index  100/ 280 , validation accuracy 0.96584
# Team07_HW2.ckpt-complete-0003-batch_index-100
# Epoch: 0003, batch_index  150/ 280 , validation accuracy 0.96879
# Team07_HW2.ckpt-complete-0003-batch_index-150
# Epoch: 0003, batch_index  200/ 280 , validation accuracy 0.96911
# Team07_HW2.ckpt-complete-0003-batch_index-200
# Epoch: 0003, batch_index  250/ 280 , validation accuracy 0.96682
# Epoch: 0004, batch_index    0/ 280 , validation accuracy 0.96748
# Epoch: 0004, batch_index   50/ 280 , validation accuracy 0.97026
# Team07_HW2.ckpt-complete-0004-batch_index-50
# Epoch: 0004, batch_index  100/ 280 , validation accuracy 0.97009
# Epoch: 0004, batch_index  150/ 280 , validation accuracy 0.97254
# Team07_HW2.ckpt-complete-0004-batch_index-150
# Epoch: 0004, batch_index  200/ 280 , validation accuracy 0.97140
# Epoch: 0004, batch_index  250/ 280 , validation accuracy 0.97173
# Epoch: 0005, batch_index    0/ 280 , validation accuracy 0.96944
# Epoch: 0005, batch_index   50/ 280 , validation accuracy 0.97189
# Epoch: 0005, batch_index  100/ 280 , validation accuracy 0.97500
# Team07_HW2.ckpt-complete-0005-batch_index-100
# Epoch: 0005, batch_index  150/ 280 , validation accuracy 0.97336
# Epoch: 0005, batch_index  200/ 280 , validation accuracy 0.97336
# Epoch: 0005, batch_index  250/ 280 , validation accuracy 0.97532
# Team07_HW2.ckpt-complete-0005-batch_index-250
# Epoch: 0006, batch_index    0/ 280 , validation accuracy 0.97516
# Epoch: 0006, batch_index   50/ 280 , validation accuracy 0.97369
# Epoch: 0006, batch_index  100/ 280 , validation accuracy 0.97532
# Team07_HW2.ckpt-complete-0006-batch_index-100
# Epoch: 0006, batch_index  150/ 280 , validation accuracy 0.97483
# Epoch: 0006, batch_index  200/ 280 , validation accuracy 0.97287
# Epoch: 0006, batch_index  250/ 280 , validation accuracy 0.97516
# Epoch: 0007, batch_index    0/ 280 , validation accuracy 0.97434
# Epoch: 0007, batch_index   50/ 280 , validation accuracy 0.97500
# Epoch: 0007, batch_index  100/ 280 , validation accuracy 0.97581
# Team07_HW2.ckpt-complete-0007-batch_index-100
# Epoch: 0007, batch_index  150/ 280 , validation accuracy 0.97745
# Team07_HW2.ckpt-complete-0007-batch_index-150
# Epoch: 0007, batch_index  200/ 280 , validation accuracy 0.97614
# Epoch: 0007, batch_index  250/ 280 , validation accuracy 0.97728
# Epoch: 0008, batch_index    0/ 280 , validation accuracy 0.97745
# Epoch: 0008, batch_index   50/ 280 , validation accuracy 0.97663
# Epoch: 0008, batch_index  100/ 280 , validation accuracy 0.97810
# Team07_HW2.ckpt-complete-0008-batch_index-100
# Epoch: 0008, batch_index  150/ 280 , validation accuracy 0.97794
# Epoch: 0008, batch_index  200/ 280 , validation accuracy 0.97712
# Epoch: 0008, batch_index  250/ 280 , validation accuracy 0.97598
# Epoch: 0009, batch_index    0/ 280 , validation accuracy 0.97581
# Epoch: 0009, batch_index   50/ 280 , validation accuracy 0.97712
# Epoch: 0009, batch_index  100/ 280 , validation accuracy 0.97745
# Epoch: 0009, batch_index  150/ 280 , validation accuracy 0.97696
# Epoch: 0009, batch_index  200/ 280 , validation accuracy 0.97614
# Epoch: 0009, batch_index  250/ 280 , validation accuracy 0.97843
# Team07_HW2.ckpt-complete-0009-batch_index-250
# Epoch: 0010, batch_index    0/ 280 , validation accuracy 0.97598
# Epoch: 0010, batch_index   50/ 280 , validation accuracy 0.97990
# Team07_HW2.ckpt-complete-0010-batch_index-50
# Epoch: 0010, batch_index  100/ 280 , validation accuracy 0.97728
# Epoch: 0010, batch_index  150/ 280 , validation accuracy 0.97728
# Epoch: 0010, batch_index  200/ 280 , validation accuracy 0.97810
# Epoch: 0010, batch_index  250/ 280 , validation accuracy 0.97875
# Epoch: 0011, batch_index    0/ 280 , validation accuracy 0.97794
# Epoch: 0011, batch_index   50/ 280 , validation accuracy 0.97892
# Epoch: 0011, batch_index  100/ 280 , validation accuracy 0.97875
# Epoch: 0011, batch_index  150/ 280 , validation accuracy 0.97843
# Epoch: 0011, batch_index  200/ 280 , validation accuracy 0.97843
# Epoch: 0011, batch_index  250/ 280 , validation accuracy 0.97974
# Epoch: 0012, batch_index    0/ 280 , validation accuracy 0.97892
# Epoch: 0012, batch_index   50/ 280 , validation accuracy 0.97908
# Epoch: 0012, batch_index  100/ 280 , validation accuracy 0.97892
# Epoch: 0012, batch_index  150/ 280 , validation accuracy 0.97859
# Epoch: 0012, batch_index  200/ 280 , validation accuracy 0.97892
# Epoch: 0012, batch_index  250/ 280 , validation accuracy 0.97925
# Epoch: 0013, batch_index    0/ 280 , validation accuracy 0.97843
# Epoch: 0013, batch_index   50/ 280 , validation accuracy 0.97990
# Epoch: 0013, batch_index  100/ 280 , validation accuracy 0.97810
# Epoch: 0013, batch_index  150/ 280 , validation accuracy 0.97974
# early_stop...........
# Fold:  2,
# Epoch: 0001, batch_index    0/ 280 , validation accuracy 0.25053
# Team07_HW2.ckpt-complete-0001-batch_index-0
# Epoch: 0001, batch_index   50/ 280 , validation accuracy 0.92335
# Team07_HW2.ckpt-complete-0001-batch_index-50
# Epoch: 0001, batch_index  100/ 280 , validation accuracy 0.95146
# Team07_HW2.ckpt-complete-0001-batch_index-100
# Epoch: 0001, batch_index  150/ 280 , validation accuracy 0.95931
# Team07_HW2.ckpt-complete-0001-batch_index-150
# Epoch: 0001, batch_index  200/ 280 , validation accuracy 0.96290
# Team07_HW2.ckpt-complete-0001-batch_index-200
# Epoch: 0001, batch_index  250/ 280 , validation accuracy 0.96797
# Team07_HW2.ckpt-complete-0001-batch_index-250
# Epoch: 0002, batch_index    0/ 280 , validation accuracy 0.96699
# Epoch: 0002, batch_index   50/ 280 , validation accuracy 0.96862
# Team07_HW2.ckpt-complete-0002-batch_index-50
# Epoch: 0002, batch_index  100/ 280 , validation accuracy 0.97124
# Team07_HW2.ckpt-complete-0002-batch_index-100
# Epoch: 0002, batch_index  150/ 280 , validation accuracy 0.97026
# Epoch: 0002, batch_index  200/ 280 , validation accuracy 0.97254
# Team07_HW2.ckpt-complete-0002-batch_index-200
# Epoch: 0002, batch_index  250/ 280 , validation accuracy 0.97320
# Team07_HW2.ckpt-complete-0002-batch_index-250
# Epoch: 0003, batch_index    0/ 280 , validation accuracy 0.97353
# Team07_HW2.ckpt-complete-0003-batch_index-0
# Epoch: 0003, batch_index   50/ 280 , validation accuracy 0.97402
# Team07_HW2.ckpt-complete-0003-batch_index-50
# Epoch: 0003, batch_index  100/ 280 , validation accuracy 0.97451
# Team07_HW2.ckpt-complete-0003-batch_index-100
# Epoch: 0003, batch_index  150/ 280 , validation accuracy 0.97565
# Team07_HW2.ckpt-complete-0003-batch_index-150
# Epoch: 0003, batch_index  200/ 280 , validation accuracy 0.97598
# Team07_HW2.ckpt-complete-0003-batch_index-200
# Epoch: 0003, batch_index  250/ 280 , validation accuracy 0.97565
# Epoch: 0004, batch_index    0/ 280 , validation accuracy 0.97565
# Epoch: 0004, batch_index   50/ 280 , validation accuracy 0.97581
# Epoch: 0004, batch_index  100/ 280 , validation accuracy 0.97598
# Team07_HW2.ckpt-complete-0004-batch_index-100
# Epoch: 0004, batch_index  150/ 280 , validation accuracy 0.97810
# Team07_HW2.ckpt-complete-0004-batch_index-150
# Epoch: 0004, batch_index  200/ 280 , validation accuracy 0.97810
# Epoch: 0004, batch_index  250/ 280 , validation accuracy 0.97712
# Epoch: 0005, batch_index    0/ 280 , validation accuracy 0.97679
# Epoch: 0005, batch_index   50/ 280 , validation accuracy 0.97777
# Epoch: 0005, batch_index  100/ 280 , validation accuracy 0.97777
# Epoch: 0005, batch_index  150/ 280 , validation accuracy 0.97843
# Team07_HW2.ckpt-complete-0005-batch_index-150
# Epoch: 0005, batch_index  200/ 280 , validation accuracy 0.97810
# Epoch: 0005, batch_index  250/ 280 , validation accuracy 0.97875
# Team07_HW2.ckpt-complete-0005-batch_index-250
# Epoch: 0006, batch_index    0/ 280 , validation accuracy 0.97908
# Team07_HW2.ckpt-complete-0006-batch_index-0
# Epoch: 0006, batch_index   50/ 280 , validation accuracy 0.97908
# Epoch: 0006, batch_index  100/ 280 , validation accuracy 0.97843
# Epoch: 0006, batch_index  150/ 280 , validation accuracy 0.97859
# Epoch: 0006, batch_index  200/ 280 , validation accuracy 0.97908
# Epoch: 0006, batch_index  250/ 280 , validation accuracy 0.97974
# Team07_HW2.ckpt-complete-0006-batch_index-250
# Epoch: 0007, batch_index    0/ 280 , validation accuracy 0.97908
# Epoch: 0007, batch_index   50/ 280 , validation accuracy 0.97974
# Epoch: 0007, batch_index  100/ 280 , validation accuracy 0.97941
# Epoch: 0007, batch_index  150/ 280 , validation accuracy 0.97990
# Team07_HW2.ckpt-complete-0007-batch_index-150
# Epoch: 0007, batch_index  200/ 280 , validation accuracy 0.97974
# Epoch: 0007, batch_index  250/ 280 , validation accuracy 0.97990
# Epoch: 0008, batch_index    0/ 280 , validation accuracy 0.97925
# Epoch: 0008, batch_index   50/ 280 , validation accuracy 0.97957
# Epoch: 0008, batch_index  100/ 280 , validation accuracy 0.97990
# Epoch: 0008, batch_index  150/ 280 , validation accuracy 0.98055
# Team07_HW2.ckpt-complete-0008-batch_index-150
# Epoch: 0008, batch_index  200/ 280 , validation accuracy 0.98088
# Team07_HW2.ckpt-complete-0008-batch_index-200
# Epoch: 0008, batch_index  250/ 280 , validation accuracy 0.98006
# Epoch: 0009, batch_index    0/ 280 , validation accuracy 0.97957
# Epoch: 0009, batch_index   50/ 280 , validation accuracy 0.98219
# Team07_HW2.ckpt-complete-0009-batch_index-50
# Epoch: 0009, batch_index  100/ 280 , validation accuracy 0.98088
# Epoch: 0009, batch_index  150/ 280 , validation accuracy 0.98104
# Epoch: 0009, batch_index  200/ 280 , validation accuracy 0.98170
# Epoch: 0009, batch_index  250/ 280 , validation accuracy 0.98137
# Epoch: 0010, batch_index    0/ 280 , validation accuracy 0.98072
# Epoch: 0010, batch_index   50/ 280 , validation accuracy 0.98153
# Epoch: 0010, batch_index  100/ 280 , validation accuracy 0.98219
# Epoch: 0010, batch_index  150/ 280 , validation accuracy 0.98235
# Team07_HW2.ckpt-complete-0010-batch_index-150
# Epoch: 0010, batch_index  200/ 280 , validation accuracy 0.98039
# Epoch: 0010, batch_index  250/ 280 , validation accuracy 0.98268
# Team07_HW2.ckpt-complete-0010-batch_index-250
# Epoch: 0011, batch_index    0/ 280 , validation accuracy 0.98235
# Epoch: 0011, batch_index   50/ 280 , validation accuracy 0.98317
# Team07_HW2.ckpt-complete-0011-batch_index-50
# Epoch: 0011, batch_index  100/ 280 , validation accuracy 0.98317
# Epoch: 0011, batch_index  150/ 280 , validation accuracy 0.98202
# Epoch: 0011, batch_index  200/ 280 , validation accuracy 0.98300
# Epoch: 0011, batch_index  250/ 280 , validation accuracy 0.98202
# Epoch: 0012, batch_index    0/ 280 , validation accuracy 0.98170
# Epoch: 0012, batch_index   50/ 280 , validation accuracy 0.98186
# Epoch: 0012, batch_index  100/ 280 , validation accuracy 0.98219
# Epoch: 0012, batch_index  150/ 280 , validation accuracy 0.98251
# Epoch: 0012, batch_index  200/ 280 , validation accuracy 0.98300
# Epoch: 0012, batch_index  250/ 280 , validation accuracy 0.98268
# Epoch: 0013, batch_index    0/ 280 , validation accuracy 0.98317
# Team07_HW2.ckpt-complete-0013-batch_index-0
# Epoch: 0013, batch_index   50/ 280 , validation accuracy 0.98268
# Epoch: 0013, batch_index  100/ 280 , validation accuracy 0.98186
# Epoch: 0013, batch_index  150/ 280 , validation accuracy 0.98284
# Epoch: 0013, batch_index  200/ 280 , validation accuracy 0.98349
# Team07_HW2.ckpt-complete-0013-batch_index-200
# Epoch: 0013, batch_index  250/ 280 , validation accuracy 0.98333
# Epoch: 0014, batch_index    0/ 280 , validation accuracy 0.98366
# Team07_HW2.ckpt-complete-0014-batch_index-0
# Epoch: 0014, batch_index   50/ 280 , validation accuracy 0.98366
# Team07_HW2.ckpt-complete-0014-batch_index-50
# Epoch: 0014, batch_index  100/ 280 , validation accuracy 0.98333
# Epoch: 0014, batch_index  150/ 280 , validation accuracy 0.98513
# Team07_HW2.ckpt-complete-0014-batch_index-150
# Epoch: 0014, batch_index  200/ 280 , validation accuracy 0.98382
# Epoch: 0014, batch_index  250/ 280 , validation accuracy 0.98284
# Epoch: 0015, batch_index    0/ 280 , validation accuracy 0.98284
# Epoch: 0015, batch_index   50/ 280 , validation accuracy 0.98349
# Epoch: 0015, batch_index  100/ 280 , validation accuracy 0.98268
# Epoch: 0015, batch_index  150/ 280 , validation accuracy 0.98382
# Epoch: 0015, batch_index  200/ 280 , validation accuracy 0.98333
# Epoch: 0015, batch_index  250/ 280 , validation accuracy 0.98349
# Epoch: 0016, batch_index    0/ 280 , validation accuracy 0.98251
# Epoch: 0016, batch_index   50/ 280 , validation accuracy 0.98415
# Epoch: 0016, batch_index  100/ 280 , validation accuracy 0.98382
# Epoch: 0016, batch_index  150/ 280 , validation accuracy 0.98464
# Epoch: 0016, batch_index  200/ 280 , validation accuracy 0.98382
# Epoch: 0016, batch_index  250/ 280 , validation accuracy 0.98513
# Epoch: 0017, batch_index    0/ 280 , validation accuracy 0.98480
# Epoch: 0017, batch_index   50/ 280 , validation accuracy 0.98529
# Team07_HW2.ckpt-complete-0017-batch_index-50
# Epoch: 0017, batch_index  100/ 280 , validation accuracy 0.98431
# Epoch: 0017, batch_index  150/ 280 , validation accuracy 0.98415
# Epoch: 0017, batch_index  200/ 280 , validation accuracy 0.98464
# Epoch: 0017, batch_index  250/ 280 , validation accuracy 0.98480
# Epoch: 0018, batch_index    0/ 280 , validation accuracy 0.98447
# Epoch: 0018, batch_index   50/ 280 , validation accuracy 0.98513
# Epoch: 0018, batch_index  100/ 280 , validation accuracy 0.98480
# Epoch: 0018, batch_index  150/ 280 , validation accuracy 0.98447
# Epoch: 0018, batch_index  200/ 280 , validation accuracy 0.98546
# Team07_HW2.ckpt-complete-0018-batch_index-200
# Epoch: 0018, batch_index  250/ 280 , validation accuracy 0.98529
# Epoch: 0019, batch_index    0/ 280 , validation accuracy 0.98562
# Team07_HW2.ckpt-complete-0019-batch_index-0
# Epoch: 0019, batch_index   50/ 280 , validation accuracy 0.98562
# Epoch: 0019, batch_index  100/ 280 , validation accuracy 0.98464
# Epoch: 0019, batch_index  150/ 280 , validation accuracy 0.98513
# Epoch: 0019, batch_index  200/ 280 , validation accuracy 0.98513
# Epoch: 0019, batch_index  250/ 280 , validation accuracy 0.98513
# Epoch: 0020, batch_index    0/ 280 , validation accuracy 0.98464
# Epoch: 0020, batch_index   50/ 280 , validation accuracy 0.98562
# Team07_HW2.ckpt-complete-0020-batch_index-50
# Epoch: 0020, batch_index  100/ 280 , validation accuracy 0.98546
# Epoch: 0020, batch_index  150/ 280 , validation accuracy 0.98611
# Team07_HW2.ckpt-complete-0020-batch_index-150
# Epoch: 0020, batch_index  200/ 280 , validation accuracy 0.98447
# Epoch: 0020, batch_index  250/ 280 , validation accuracy 0.98562
# Epoch: 0021, batch_index    0/ 280 , validation accuracy 0.98578
# Epoch: 0021, batch_index   50/ 280 , validation accuracy 0.98660
# Team07_HW2.ckpt-complete-0021-batch_index-50
# Epoch: 0021, batch_index  100/ 280 , validation accuracy 0.98578
# Epoch: 0021, batch_index  150/ 280 , validation accuracy 0.98627
# Epoch: 0021, batch_index  200/ 280 , validation accuracy 0.98578
# Epoch: 0021, batch_index  250/ 280 , validation accuracy 0.98595
# Epoch: 0022, batch_index    0/ 280 , validation accuracy 0.98578
# Epoch: 0022, batch_index   50/ 280 , validation accuracy 0.98595
# Epoch: 0022, batch_index  100/ 280 , validation accuracy 0.98562
# Epoch: 0022, batch_index  150/ 280 , validation accuracy 0.98611
# Epoch: 0022, batch_index  200/ 280 , validation accuracy 0.98611
# Epoch: 0022, batch_index  250/ 280 , validation accuracy 0.98464
# Epoch: 0023, batch_index    0/ 280 , validation accuracy 0.98480
# Epoch: 0023, batch_index   50/ 280 , validation accuracy 0.98595
# Epoch: 0023, batch_index  100/ 280 , validation accuracy 0.98611
# Epoch: 0023, batch_index  150/ 280 , validation accuracy 0.98611
# Epoch: 0023, batch_index  200/ 280 , validation accuracy 0.98578
# Epoch: 0023, batch_index  250/ 280 , validation accuracy 0.98578
# Epoch: 0024, batch_index    0/ 280 , validation accuracy 0.98595
# Epoch: 0024, batch_index   50/ 280 , validation accuracy 0.98595
# Epoch: 0024, batch_index  100/ 280 , validation accuracy 0.98644
# Epoch: 0024, batch_index  150/ 280 , validation accuracy 0.98595
# early_stop...........
# Fold:  3,
# Epoch: 0001, batch_index    0/ 280 , validation accuracy 0.23239
# Team07_HW2.ckpt-complete-0001-batch_index-0
# Epoch: 0001, batch_index   50/ 280 , validation accuracy 0.89214
# Team07_HW2.ckpt-complete-0001-batch_index-50
# Epoch: 0001, batch_index  100/ 280 , validation accuracy 0.93675
# Team07_HW2.ckpt-complete-0001-batch_index-100
# Epoch: 0001, batch_index  150/ 280 , validation accuracy 0.94819
# Team07_HW2.ckpt-complete-0001-batch_index-150
# Epoch: 0001, batch_index  200/ 280 , validation accuracy 0.95522
# Team07_HW2.ckpt-complete-0001-batch_index-200
# Epoch: 0001, batch_index  250/ 280 , validation accuracy 0.96225
# Team07_HW2.ckpt-complete-0001-batch_index-250
# Epoch: 0002, batch_index    0/ 280 , validation accuracy 0.96160
# Epoch: 0002, batch_index   50/ 280 , validation accuracy 0.96307
# Team07_HW2.ckpt-complete-0002-batch_index-50
# Epoch: 0002, batch_index  100/ 280 , validation accuracy 0.96388
# Team07_HW2.ckpt-complete-0002-batch_index-100
# Epoch: 0002, batch_index  150/ 280 , validation accuracy 0.96617
# Team07_HW2.ckpt-complete-0002-batch_index-150
# Epoch: 0002, batch_index  200/ 280 , validation accuracy 0.96944
# Team07_HW2.ckpt-complete-0002-batch_index-200
# Epoch: 0002, batch_index  250/ 280 , validation accuracy 0.96846
# Epoch: 0003, batch_index    0/ 280 , validation accuracy 0.96748
# Epoch: 0003, batch_index   50/ 280 , validation accuracy 0.96846
# Epoch: 0003, batch_index  100/ 280 , validation accuracy 0.97026
# Team07_HW2.ckpt-complete-0003-batch_index-100
# Epoch: 0003, batch_index  150/ 280 , validation accuracy 0.97091
# Team07_HW2.ckpt-complete-0003-batch_index-150
# Epoch: 0003, batch_index  200/ 280 , validation accuracy 0.96977
# Epoch: 0003, batch_index  250/ 280 , validation accuracy 0.97124
# Team07_HW2.ckpt-complete-0003-batch_index-250
# Epoch: 0004, batch_index    0/ 280 , validation accuracy 0.97075
# Epoch: 0004, batch_index   50/ 280 , validation accuracy 0.97238
# Team07_HW2.ckpt-complete-0004-batch_index-50
# Epoch: 0004, batch_index  100/ 280 , validation accuracy 0.97320
# Team07_HW2.ckpt-complete-0004-batch_index-100
# Epoch: 0004, batch_index  150/ 280 , validation accuracy 0.97287
# Epoch: 0004, batch_index  200/ 280 , validation accuracy 0.97336
# Team07_HW2.ckpt-complete-0004-batch_index-200
# Epoch: 0004, batch_index  250/ 280 , validation accuracy 0.97385
# Team07_HW2.ckpt-complete-0004-batch_index-250
# Epoch: 0005, batch_index    0/ 280 , validation accuracy 0.97304
# Epoch: 0005, batch_index   50/ 280 , validation accuracy 0.97467
# Team07_HW2.ckpt-complete-0005-batch_index-50
# Epoch: 0005, batch_index  100/ 280 , validation accuracy 0.97500
# Team07_HW2.ckpt-complete-0005-batch_index-100
# Epoch: 0005, batch_index  150/ 280 , validation accuracy 0.97467
# Epoch: 0005, batch_index  200/ 280 , validation accuracy 0.97614
# Team07_HW2.ckpt-complete-0005-batch_index-200
# Epoch: 0005, batch_index  250/ 280 , validation accuracy 0.97516
# Epoch: 0006, batch_index    0/ 280 , validation accuracy 0.97467
# Epoch: 0006, batch_index   50/ 280 , validation accuracy 0.97581
# Epoch: 0006, batch_index  100/ 280 , validation accuracy 0.97696
# Team07_HW2.ckpt-complete-0006-batch_index-100
# Epoch: 0006, batch_index  150/ 280 , validation accuracy 0.97549
# Epoch: 0006, batch_index  200/ 280 , validation accuracy 0.97532
# Epoch: 0006, batch_index  250/ 280 , validation accuracy 0.97647
# Epoch: 0007, batch_index    0/ 280 , validation accuracy 0.97663
# Epoch: 0007, batch_index   50/ 280 , validation accuracy 0.97565
# Epoch: 0007, batch_index  100/ 280 , validation accuracy 0.97663
# Epoch: 0007, batch_index  150/ 280 , validation accuracy 0.97728
# Team07_HW2.ckpt-complete-0007-batch_index-150
# Epoch: 0007, batch_index  200/ 280 , validation accuracy 0.97630
# Epoch: 0007, batch_index  250/ 280 , validation accuracy 0.97728
# Epoch: 0008, batch_index    0/ 280 , validation accuracy 0.97745
# Team07_HW2.ckpt-complete-0008-batch_index-0
# Epoch: 0008, batch_index   50/ 280 , validation accuracy 0.97761
# Team07_HW2.ckpt-complete-0008-batch_index-50
# Epoch: 0008, batch_index  100/ 280 , validation accuracy 0.97761
# Team07_HW2.ckpt-complete-0008-batch_index-100
# Epoch: 0008, batch_index  150/ 280 , validation accuracy 0.97859
# Team07_HW2.ckpt-complete-0008-batch_index-150
# Epoch: 0008, batch_index  200/ 280 , validation accuracy 0.97761
# Epoch: 0008, batch_index  250/ 280 , validation accuracy 0.97794
# Epoch: 0009, batch_index    0/ 280 , validation accuracy 0.97826
# Epoch: 0009, batch_index   50/ 280 , validation accuracy 0.97826
# Epoch: 0009, batch_index  100/ 280 , validation accuracy 0.97826
# Epoch: 0009, batch_index  150/ 280 , validation accuracy 0.97925
# Team07_HW2.ckpt-complete-0009-batch_index-150
# Epoch: 0009, batch_index  200/ 280 , validation accuracy 0.97925
# Team07_HW2.ckpt-complete-0009-batch_index-200
# Epoch: 0009, batch_index  250/ 280 , validation accuracy 0.97974
# Team07_HW2.ckpt-complete-0009-batch_index-250
# Epoch: 0010, batch_index    0/ 280 , validation accuracy 0.97941
# Epoch: 0010, batch_index   50/ 280 , validation accuracy 0.98023
# Team07_HW2.ckpt-complete-0010-batch_index-50
# Epoch: 0010, batch_index  100/ 280 , validation accuracy 0.97859
# Epoch: 0010, batch_index  150/ 280 , validation accuracy 0.98006
# Epoch: 0010, batch_index  200/ 280 , validation accuracy 0.98006
# Epoch: 0010, batch_index  250/ 280 , validation accuracy 0.97925
# Epoch: 0011, batch_index    0/ 280 , validation accuracy 0.97777
# Epoch: 0011, batch_index   50/ 280 , validation accuracy 0.97974
# Epoch: 0011, batch_index  100/ 280 , validation accuracy 0.97875
# Epoch: 0011, batch_index  150/ 280 , validation accuracy 0.98006
# Epoch: 0011, batch_index  200/ 280 , validation accuracy 0.98039
# Team07_HW2.ckpt-complete-0011-batch_index-200
# Epoch: 0011, batch_index  250/ 280 , validation accuracy 0.97843
# Epoch: 0012, batch_index    0/ 280 , validation accuracy 0.97875
# Epoch: 0012, batch_index   50/ 280 , validation accuracy 0.98055
# Team07_HW2.ckpt-complete-0012-batch_index-50
# Epoch: 0012, batch_index  100/ 280 , validation accuracy 0.98023
# Epoch: 0012, batch_index  150/ 280 , validation accuracy 0.97990
# Epoch: 0012, batch_index  200/ 280 , validation accuracy 0.98088
# Team07_HW2.ckpt-complete-0012-batch_index-200
# Epoch: 0012, batch_index  250/ 280 , validation accuracy 0.98088
# Epoch: 0013, batch_index    0/ 280 , validation accuracy 0.98055
# Epoch: 0013, batch_index   50/ 280 , validation accuracy 0.98186
# Team07_HW2.ckpt-complete-0013-batch_index-50
# Epoch: 0013, batch_index  100/ 280 , validation accuracy 0.98039
# Epoch: 0013, batch_index  150/ 280 , validation accuracy 0.98088
# Epoch: 0013, batch_index  200/ 280 , validation accuracy 0.98072
# Epoch: 0013, batch_index  250/ 280 , validation accuracy 0.98137
# Epoch: 0014, batch_index    0/ 280 , validation accuracy 0.98170
# Epoch: 0014, batch_index   50/ 280 , validation accuracy 0.98104
# Epoch: 0014, batch_index  100/ 280 , validation accuracy 0.98088
# Epoch: 0014, batch_index  150/ 280 , validation accuracy 0.98170
# Epoch: 0014, batch_index  200/ 280 , validation accuracy 0.98186
# Team07_HW2.ckpt-complete-0014-batch_index-200
# Epoch: 0014, batch_index  250/ 280 , validation accuracy 0.98202
# Team07_HW2.ckpt-complete-0014-batch_index-250
# Epoch: 0015, batch_index    0/ 280 , validation accuracy 0.98251
# Team07_HW2.ckpt-complete-0015-batch_index-0
# Epoch: 0015, batch_index   50/ 280 , validation accuracy 0.98121
# Epoch: 0015, batch_index  100/ 280 , validation accuracy 0.98137
# Epoch: 0015, batch_index  150/ 280 , validation accuracy 0.98170
# Epoch: 0015, batch_index  200/ 280 , validation accuracy 0.98153
# Epoch: 0015, batch_index  250/ 280 , validation accuracy 0.98235
# Epoch: 0016, batch_index    0/ 280 , validation accuracy 0.98235
# Epoch: 0016, batch_index   50/ 280 , validation accuracy 0.98202
# Epoch: 0016, batch_index  100/ 280 , validation accuracy 0.98219
# Epoch: 0016, batch_index  150/ 280 , validation accuracy 0.98219
# Epoch: 0016, batch_index  200/ 280 , validation accuracy 0.98219
# Epoch: 0016, batch_index  250/ 280 , validation accuracy 0.98153
# Epoch: 0017, batch_index    0/ 280 , validation accuracy 0.98039
# Epoch: 0017, batch_index   50/ 280 , validation accuracy 0.98235
# Epoch: 0017, batch_index  100/ 280 , validation accuracy 0.98202
# Epoch: 0017, batch_index  150/ 280 , validation accuracy 0.98268
# Team07_HW2.ckpt-complete-0017-batch_index-150
# Epoch: 0017, batch_index  200/ 280 , validation accuracy 0.98219
# Epoch: 0017, batch_index  250/ 280 , validation accuracy 0.98251
# Epoch: 0018, batch_index    0/ 280 , validation accuracy 0.98235
# Epoch: 0018, batch_index   50/ 280 , validation accuracy 0.98284
# Team07_HW2.ckpt-complete-0018-batch_index-50
# Epoch: 0018, batch_index  100/ 280 , validation accuracy 0.98268
# Epoch: 0018, batch_index  150/ 280 , validation accuracy 0.98219
# Epoch: 0018, batch_index  200/ 280 , validation accuracy 0.98251
# Epoch: 0018, batch_index  250/ 280 , validation accuracy 0.98284
# Team07_HW2.ckpt-complete-0018-batch_index-250
# Epoch: 0019, batch_index    0/ 280 , validation accuracy 0.98300
# Team07_HW2.ckpt-complete-0019-batch_index-0
# Epoch: 0019, batch_index   50/ 280 , validation accuracy 0.98251
# Epoch: 0019, batch_index  100/ 280 , validation accuracy 0.98251
# Epoch: 0019, batch_index  150/ 280 , validation accuracy 0.98186
# Epoch: 0019, batch_index  200/ 280 , validation accuracy 0.98251
# Epoch: 0019, batch_index  250/ 280 , validation accuracy 0.98235
# Epoch: 0020, batch_index    0/ 280 , validation accuracy 0.98268
# Epoch: 0020, batch_index   50/ 280 , validation accuracy 0.98284
# Epoch: 0020, batch_index  100/ 280 , validation accuracy 0.98235
# Epoch: 0020, batch_index  150/ 280 , validation accuracy 0.98235
# Epoch: 0020, batch_index  200/ 280 , validation accuracy 0.98284
# Epoch: 0020, batch_index  250/ 280 , validation accuracy 0.98251
# Epoch: 0021, batch_index    0/ 280 , validation accuracy 0.98251
# Epoch: 0021, batch_index   50/ 280 , validation accuracy 0.98251
# Epoch: 0021, batch_index  100/ 280 , validation accuracy 0.98251
# Epoch: 0021, batch_index  150/ 280 , validation accuracy 0.98219
# Epoch: 0021, batch_index  200/ 280 , validation accuracy 0.98235
# Epoch: 0021, batch_index  250/ 280 , validation accuracy 0.98300
# Epoch: 0022, batch_index    0/ 280 , validation accuracy 0.98317
# Team07_HW2.ckpt-complete-0022-batch_index-0
# Epoch: 0022, batch_index   50/ 280 , validation accuracy 0.98268
# Epoch: 0022, batch_index  100/ 280 , validation accuracy 0.98284
# Epoch: 0022, batch_index  150/ 280 , validation accuracy 0.98300
# Epoch: 0022, batch_index  200/ 280 , validation accuracy 0.98284
# Epoch: 0022, batch_index  250/ 280 , validation accuracy 0.98284
# Epoch: 0023, batch_index    0/ 280 , validation accuracy 0.98235
# Epoch: 0023, batch_index   50/ 280 , validation accuracy 0.98284
# Epoch: 0023, batch_index  100/ 280 , validation accuracy 0.98317
# Epoch: 0023, batch_index  150/ 280 , validation accuracy 0.98251
# Epoch: 0023, batch_index  200/ 280 , validation accuracy 0.98284
# Epoch: 0023, batch_index  250/ 280 , validation accuracy 0.98268
# Epoch: 0024, batch_index    0/ 280 , validation accuracy 0.98284
# Epoch: 0024, batch_index   50/ 280 , validation accuracy 0.98284
# Epoch: 0024, batch_index  100/ 280 , validation accuracy 0.98333
# Team07_HW2.ckpt-complete-0024-batch_index-100
# Epoch: 0024, batch_index  150/ 280 , validation accuracy 0.98317
# Epoch: 0024, batch_index  200/ 280 , validation accuracy 0.98317
# Epoch: 0024, batch_index  250/ 280 , validation accuracy 0.98268
# Epoch: 0025, batch_index    0/ 280 , validation accuracy 0.98268
# Epoch: 0025, batch_index   50/ 280 , validation accuracy 0.98317
# Epoch: 0025, batch_index  100/ 280 , validation accuracy 0.98300
# Epoch: 0025, batch_index  150/ 280 , validation accuracy 0.98333
# Epoch: 0025, batch_index  200/ 280 , validation accuracy 0.98333
# Team07_HW2.ckpt-complete-0025-batch_index-200
# Epoch: 0025, batch_index  250/ 280 , validation accuracy 0.98366
# Team07_HW2.ckpt-complete-0025-batch_index-250
# Epoch: 0026, batch_index    0/ 280 , validation accuracy 0.98317
# Epoch: 0026, batch_index   50/ 280 , validation accuracy 0.98300
# Epoch: 0026, batch_index  100/ 280 , validation accuracy 0.98317
# Epoch: 0026, batch_index  150/ 280 , validation accuracy 0.98284
# Epoch: 0026, batch_index  200/ 280 , validation accuracy 0.98317
# Epoch: 0026, batch_index  250/ 280 , validation accuracy 0.98268
# Epoch: 0027, batch_index    0/ 280 , validation accuracy 0.98251
# Epoch: 0027, batch_index   50/ 280 , validation accuracy 0.98333
# Epoch: 0027, batch_index  100/ 280 , validation accuracy 0.98333
# Epoch: 0027, batch_index  150/ 280 , validation accuracy 0.98317
# Epoch: 0027, batch_index  200/ 280 , validation accuracy 0.98317
# Epoch: 0027, batch_index  250/ 280 , validation accuracy 0.98333
# Epoch: 0028, batch_index    0/ 280 , validation accuracy 0.98300
# Epoch: 0028, batch_index   50/ 280 , validation accuracy 0.98349
# Epoch: 0028, batch_index  100/ 280 , validation accuracy 0.98284
# Epoch: 0028, batch_index  150/ 280 , validation accuracy 0.98349
# Epoch: 0028, batch_index  200/ 280 , validation accuracy 0.98349
# Epoch: 0028, batch_index  250/ 280 , validation accuracy 0.98317
# Epoch: 0029, batch_index    0/ 280 , validation accuracy 0.98300
# Epoch: 0029, batch_index   50/ 280 , validation accuracy 0.98284
# early_stop...........
# Fold:  4,
# Epoch: 0001, batch_index    0/ 280 , validation accuracy 0.35905
# Team07_HW2.ckpt-complete-0001-batch_index-0
# Epoch: 0001, batch_index   50/ 280 , validation accuracy 0.91224
# Team07_HW2.ckpt-complete-0001-batch_index-50
# Epoch: 0001, batch_index  100/ 280 , validation accuracy 0.94296
# Team07_HW2.ckpt-complete-0001-batch_index-100
# Epoch: 0001, batch_index  150/ 280 , validation accuracy 0.95179
# Team07_HW2.ckpt-complete-0001-batch_index-150
# Epoch: 0001, batch_index  200/ 280 , validation accuracy 0.95571
# Team07_HW2.ckpt-complete-0001-batch_index-200
# Epoch: 0001, batch_index  250/ 280 , validation accuracy 0.95865
# Team07_HW2.ckpt-complete-0001-batch_index-250
# Epoch: 0002, batch_index    0/ 280 , validation accuracy 0.95816
# Epoch: 0002, batch_index   50/ 280 , validation accuracy 0.96127
# Team07_HW2.ckpt-complete-0002-batch_index-50
# Epoch: 0002, batch_index  100/ 280 , validation accuracy 0.96372
# Team07_HW2.ckpt-complete-0002-batch_index-100
# Epoch: 0002, batch_index  150/ 280 , validation accuracy 0.96405
# Team07_HW2.ckpt-complete-0002-batch_index-150
# Epoch: 0002, batch_index  200/ 280 , validation accuracy 0.96568
# Team07_HW2.ckpt-complete-0002-batch_index-200
# Epoch: 0002, batch_index  250/ 280 , validation accuracy 0.96568
# Epoch: 0003, batch_index    0/ 280 , validation accuracy 0.96486
# Epoch: 0003, batch_index   50/ 280 , validation accuracy 0.96699
# Team07_HW2.ckpt-complete-0003-batch_index-50
# Epoch: 0003, batch_index  100/ 280 , validation accuracy 0.96813
# Team07_HW2.ckpt-complete-0003-batch_index-100
# Epoch: 0003, batch_index  150/ 280 , validation accuracy 0.96797
# Epoch: 0003, batch_index  200/ 280 , validation accuracy 0.96846
# Team07_HW2.ckpt-complete-0003-batch_index-200
# Epoch: 0003, batch_index  250/ 280 , validation accuracy 0.97042
# Team07_HW2.ckpt-complete-0003-batch_index-250
# Epoch: 0004, batch_index    0/ 280 , validation accuracy 0.96993
# Epoch: 0004, batch_index   50/ 280 , validation accuracy 0.96993
# Epoch: 0004, batch_index  100/ 280 , validation accuracy 0.96977
# Epoch: 0004, batch_index  150/ 280 , validation accuracy 0.97156
# Team07_HW2.ckpt-complete-0004-batch_index-150
# Epoch: 0004, batch_index  200/ 280 , validation accuracy 0.97042
# Epoch: 0004, batch_index  250/ 280 , validation accuracy 0.96993
# Epoch: 0005, batch_index    0/ 280 , validation accuracy 0.96813
# Epoch: 0005, batch_index   50/ 280 , validation accuracy 0.97075
# Epoch: 0005, batch_index  100/ 280 , validation accuracy 0.97042
# Epoch: 0005, batch_index  150/ 280 , validation accuracy 0.97336
# Team07_HW2.ckpt-complete-0005-batch_index-150
# Epoch: 0005, batch_index  200/ 280 , validation accuracy 0.97271
# Epoch: 0005, batch_index  250/ 280 , validation accuracy 0.97124
# Epoch: 0006, batch_index    0/ 280 , validation accuracy 0.96993
# Epoch: 0006, batch_index   50/ 280 , validation accuracy 0.97320
# Epoch: 0006, batch_index  100/ 280 , validation accuracy 0.97467
# Team07_HW2.ckpt-complete-0006-batch_index-100
# Epoch: 0006, batch_index  150/ 280 , validation accuracy 0.97418
# Epoch: 0006, batch_index  200/ 280 , validation accuracy 0.97189
# Epoch: 0006, batch_index  250/ 280 , validation accuracy 0.97205
# Epoch: 0007, batch_index    0/ 280 , validation accuracy 0.97075
# Epoch: 0007, batch_index   50/ 280 , validation accuracy 0.97418
# Epoch: 0007, batch_index  100/ 280 , validation accuracy 0.97353
# Epoch: 0007, batch_index  150/ 280 , validation accuracy 0.97516
# Team07_HW2.ckpt-complete-0007-batch_index-150
# Epoch: 0007, batch_index  200/ 280 , validation accuracy 0.97418
# Epoch: 0007, batch_index  250/ 280 , validation accuracy 0.97581
# Team07_HW2.ckpt-complete-0007-batch_index-250
# Epoch: 0008, batch_index    0/ 280 , validation accuracy 0.97598
# Team07_HW2.ckpt-complete-0008-batch_index-0
# Epoch: 0008, batch_index   50/ 280 , validation accuracy 0.97696
# Team07_HW2.ckpt-complete-0008-batch_index-50
# Epoch: 0008, batch_index  100/ 280 , validation accuracy 0.97712
# Team07_HW2.ckpt-complete-0008-batch_index-100
# Epoch: 0008, batch_index  150/ 280 , validation accuracy 0.97712
# Epoch: 0008, batch_index  200/ 280 , validation accuracy 0.97614
# Epoch: 0008, batch_index  250/ 280 , validation accuracy 0.97761
# Team07_HW2.ckpt-complete-0008-batch_index-250
# Epoch: 0009, batch_index    0/ 280 , validation accuracy 0.97696
# Epoch: 0009, batch_index   50/ 280 , validation accuracy 0.97565
# Epoch: 0009, batch_index  100/ 280 , validation accuracy 0.97794
# Team07_HW2.ckpt-complete-0009-batch_index-100
# Epoch: 0009, batch_index  150/ 280 , validation accuracy 0.97532
# Epoch: 0009, batch_index  200/ 280 , validation accuracy 0.97532
# Epoch: 0009, batch_index  250/ 280 , validation accuracy 0.97777
# Epoch: 0010, batch_index    0/ 280 , validation accuracy 0.97696
# Epoch: 0010, batch_index   50/ 280 , validation accuracy 0.97696
# Epoch: 0010, batch_index  100/ 280 , validation accuracy 0.97794
# Epoch: 0010, batch_index  150/ 280 , validation accuracy 0.97745
# Epoch: 0010, batch_index  200/ 280 , validation accuracy 0.97745
# Epoch: 0010, batch_index  250/ 280 , validation accuracy 0.97663
# Epoch: 0011, batch_index    0/ 280 , validation accuracy 0.97630
# Epoch: 0011, batch_index   50/ 280 , validation accuracy 0.97859
# Team07_HW2.ckpt-complete-0011-batch_index-50
# Epoch: 0011, batch_index  100/ 280 , validation accuracy 0.97728
# Epoch: 0011, batch_index  150/ 280 , validation accuracy 0.97908
# Team07_HW2.ckpt-complete-0011-batch_index-150
# Epoch: 0011, batch_index  200/ 280 , validation accuracy 0.97810
# Epoch: 0011, batch_index  250/ 280 , validation accuracy 0.97843
# Epoch: 0012, batch_index    0/ 280 , validation accuracy 0.97794
# Epoch: 0012, batch_index   50/ 280 , validation accuracy 0.97810
# Epoch: 0012, batch_index  100/ 280 , validation accuracy 0.97745
# Epoch: 0012, batch_index  150/ 280 , validation accuracy 0.97810
# Epoch: 0012, batch_index  200/ 280 , validation accuracy 0.97810
# Epoch: 0012, batch_index  250/ 280 , validation accuracy 0.97728
# Epoch: 0013, batch_index    0/ 280 , validation accuracy 0.97696
# Epoch: 0013, batch_index   50/ 280 , validation accuracy 0.97794
# Epoch: 0013, batch_index  100/ 280 , validation accuracy 0.97826
# Epoch: 0013, batch_index  150/ 280 , validation accuracy 0.97761
# Epoch: 0013, batch_index  200/ 280 , validation accuracy 0.97794
# Epoch: 0013, batch_index  250/ 280 , validation accuracy 0.97908
# Epoch: 0014, batch_index    0/ 280 , validation accuracy 0.97908
# Epoch: 0014, batch_index   50/ 280 , validation accuracy 0.97908
# Team07_HW2.ckpt-complete-0014-batch_index-50
# Epoch: 0014, batch_index  100/ 280 , validation accuracy 0.97974
# Team07_HW2.ckpt-complete-0014-batch_index-100
# Epoch: 0014, batch_index  150/ 280 , validation accuracy 0.97875
# Epoch: 0014, batch_index  200/ 280 , validation accuracy 0.97728
# Epoch: 0014, batch_index  250/ 280 , validation accuracy 0.97990
# Team07_HW2.ckpt-complete-0014-batch_index-250
# Epoch: 0015, batch_index    0/ 280 , validation accuracy 0.97925
# Epoch: 0015, batch_index   50/ 280 , validation accuracy 0.97957
# Epoch: 0015, batch_index  100/ 280 , validation accuracy 0.97957
# Epoch: 0015, batch_index  150/ 280 , validation accuracy 0.98055
# Team07_HW2.ckpt-complete-0015-batch_index-150
# Epoch: 0015, batch_index  200/ 280 , validation accuracy 0.98023
# Epoch: 0015, batch_index  250/ 280 , validation accuracy 0.97908
# Epoch: 0016, batch_index    0/ 280 , validation accuracy 0.97892
# Epoch: 0016, batch_index   50/ 280 , validation accuracy 0.98006
# Epoch: 0016, batch_index  100/ 280 , validation accuracy 0.98039
# Epoch: 0016, batch_index  150/ 280 , validation accuracy 0.97957
# Epoch: 0016, batch_index  200/ 280 , validation accuracy 0.97990
# Epoch: 0016, batch_index  250/ 280 , validation accuracy 0.97974
# Epoch: 0017, batch_index    0/ 280 , validation accuracy 0.97990
# Epoch: 0017, batch_index   50/ 280 , validation accuracy 0.97957
# Epoch: 0017, batch_index  100/ 280 , validation accuracy 0.98023
# Epoch: 0017, batch_index  150/ 280 , validation accuracy 0.98006
# Epoch: 0017, batch_index  200/ 280 , validation accuracy 0.97974
# Epoch: 0017, batch_index  250/ 280 , validation accuracy 0.97990
# Epoch: 0018, batch_index    0/ 280 , validation accuracy 0.98023
# Epoch: 0018, batch_index   50/ 280 , validation accuracy 0.98039
# Epoch: 0018, batch_index  100/ 280 , validation accuracy 0.98006
# Epoch: 0018, batch_index  150/ 280 , validation accuracy 0.98023
# Epoch: 0018, batch_index  200/ 280 , validation accuracy 0.98055
# Team07_HW2.ckpt-complete-0018-batch_index-200
# Epoch: 0018, batch_index  250/ 280 , validation accuracy 0.98055
# Epoch: 0019, batch_index    0/ 280 , validation accuracy 0.98088
# Team07_HW2.ckpt-complete-0019-batch_index-0
# Epoch: 0019, batch_index   50/ 280 , validation accuracy 0.98006
# Epoch: 0019, batch_index  100/ 280 , validation accuracy 0.98006
# Epoch: 0019, batch_index  150/ 280 , validation accuracy 0.97974
# Epoch: 0019, batch_index  200/ 280 , validation accuracy 0.98006
# Epoch: 0019, batch_index  250/ 280 , validation accuracy 0.97990
# Epoch: 0020, batch_index    0/ 280 , validation accuracy 0.97974
# Epoch: 0020, batch_index   50/ 280 , validation accuracy 0.97974
# Epoch: 0020, batch_index  100/ 280 , validation accuracy 0.98039
# Epoch: 0020, batch_index  150/ 280 , validation accuracy 0.97990
# Epoch: 0020, batch_index  200/ 280 , validation accuracy 0.98039
# Epoch: 0020, batch_index  250/ 280 , validation accuracy 0.98072
# Epoch: 0021, batch_index    0/ 280 , validation accuracy 0.98088
# Epoch: 0021, batch_index   50/ 280 , validation accuracy 0.97990
# Epoch: 0021, batch_index  100/ 280 , validation accuracy 0.98121
# Team07_HW2.ckpt-complete-0021-batch_index-100
# Epoch: 0021, batch_index  150/ 280 , validation accuracy 0.98006
# Epoch: 0021, batch_index  200/ 280 , validation accuracy 0.98104
# Epoch: 0021, batch_index  250/ 280 , validation accuracy 0.98072
# Epoch: 0022, batch_index    0/ 280 , validation accuracy 0.98072
# Epoch: 0022, batch_index   50/ 280 , validation accuracy 0.98121
# Epoch: 0022, batch_index  100/ 280 , validation accuracy 0.98055
# Epoch: 0022, batch_index  150/ 280 , validation accuracy 0.98039
# Epoch: 0022, batch_index  200/ 280 , validation accuracy 0.98023
# Epoch: 0022, batch_index  250/ 280 , validation accuracy 0.98055
# Epoch: 0023, batch_index    0/ 280 , validation accuracy 0.98055
# Epoch: 0023, batch_index   50/ 280 , validation accuracy 0.98186
# Team07_HW2.ckpt-complete-0023-batch_index-50
# Epoch: 0023, batch_index  100/ 280 , validation accuracy 0.98072
# Epoch: 0023, batch_index  150/ 280 , validation accuracy 0.98072
# Epoch: 0023, batch_index  200/ 280 , validation accuracy 0.98039
# Epoch: 0023, batch_index  250/ 280 , validation accuracy 0.98072
# Epoch: 0024, batch_index    0/ 280 , validation accuracy 0.98088
# Epoch: 0024, batch_index   50/ 280 , validation accuracy 0.98072
# Epoch: 0024, batch_index  100/ 280 , validation accuracy 0.98023
# Epoch: 0024, batch_index  150/ 280 , validation accuracy 0.98137
# Epoch: 0024, batch_index  200/ 280 , validation accuracy 0.98153
# Epoch: 0024, batch_index  250/ 280 , validation accuracy 0.98023
# Epoch: 0025, batch_index    0/ 280 , validation accuracy 0.98039
# Epoch: 0025, batch_index   50/ 280 , validation accuracy 0.98039
# Epoch: 0025, batch_index  100/ 280 , validation accuracy 0.98153
# Epoch: 0025, batch_index  150/ 280 , validation accuracy 0.98088
# Epoch: 0025, batch_index  200/ 280 , validation accuracy 0.98072
# Epoch: 0025, batch_index  250/ 280 , validation accuracy 0.97925
# Epoch: 0026, batch_index    0/ 280 , validation accuracy 0.97925
# Epoch: 0026, batch_index   50/ 280 , validation accuracy 0.98186
# Epoch: 0026, batch_index  100/ 280 , validation accuracy 0.98039
# Epoch: 0026, batch_index  150/ 280 , validation accuracy 0.98023
# early_stop...........
# Fold:  5,
# Epoch: 0001, batch_index    0/ 280 , validation accuracy 0.30773
# Team07_HW2.ckpt-complete-0001-batch_index-0
# Epoch: 0001, batch_index   50/ 280 , validation accuracy 0.93005
# Team07_HW2.ckpt-complete-0001-batch_index-50
# Epoch: 0001, batch_index  100/ 280 , validation accuracy 0.95375
# Team07_HW2.ckpt-complete-0001-batch_index-100
# Epoch: 0001, batch_index  150/ 280 , validation accuracy 0.96323
# Team07_HW2.ckpt-complete-0001-batch_index-150
# Epoch: 0001, batch_index  200/ 280 , validation accuracy 0.96781
# Team07_HW2.ckpt-complete-0001-batch_index-200
# Epoch: 0001, batch_index  250/ 280 , validation accuracy 0.96993
# Team07_HW2.ckpt-complete-0001-batch_index-250
# Epoch: 0002, batch_index    0/ 280 , validation accuracy 0.96911
# Epoch: 0002, batch_index   50/ 280 , validation accuracy 0.97124
# Team07_HW2.ckpt-complete-0002-batch_index-50
# Epoch: 0002, batch_index  100/ 280 , validation accuracy 0.97254
# Team07_HW2.ckpt-complete-0002-batch_index-100
# Epoch: 0002, batch_index  150/ 280 , validation accuracy 0.97516
# Team07_HW2.ckpt-complete-0002-batch_index-150
# Epoch: 0002, batch_index  200/ 280 , validation accuracy 0.97418
# Epoch: 0002, batch_index  250/ 280 , validation accuracy 0.97532
# Team07_HW2.ckpt-complete-0002-batch_index-250
# Epoch: 0003, batch_index    0/ 280 , validation accuracy 0.97565
# Team07_HW2.ckpt-complete-0003-batch_index-0
# Epoch: 0003, batch_index   50/ 280 , validation accuracy 0.97696
# Team07_HW2.ckpt-complete-0003-batch_index-50
# Epoch: 0003, batch_index  100/ 280 , validation accuracy 0.97761
# Team07_HW2.ckpt-complete-0003-batch_index-100
# Epoch: 0003, batch_index  150/ 280 , validation accuracy 0.97630
# Epoch: 0003, batch_index  200/ 280 , validation accuracy 0.97810
# Team07_HW2.ckpt-complete-0003-batch_index-200
# Epoch: 0003, batch_index  250/ 280 , validation accuracy 0.97892
# Team07_HW2.ckpt-complete-0003-batch_index-250
# Epoch: 0004, batch_index    0/ 280 , validation accuracy 0.97859
# Epoch: 0004, batch_index   50/ 280 , validation accuracy 0.98006
# Team07_HW2.ckpt-complete-0004-batch_index-50
# Epoch: 0004, batch_index  100/ 280 , validation accuracy 0.97875
# Epoch: 0004, batch_index  150/ 280 , validation accuracy 0.98023
# Team07_HW2.ckpt-complete-0004-batch_index-150
# Epoch: 0004, batch_index  200/ 280 , validation accuracy 0.98072
# Team07_HW2.ckpt-complete-0004-batch_index-200
# Epoch: 0004, batch_index  250/ 280 , validation accuracy 0.98023
# Epoch: 0005, batch_index    0/ 280 , validation accuracy 0.97908
# Epoch: 0005, batch_index   50/ 280 , validation accuracy 0.97925
# Epoch: 0005, batch_index  100/ 280 , validation accuracy 0.98006
# Epoch: 0005, batch_index  150/ 280 , validation accuracy 0.98235
# Team07_HW2.ckpt-complete-0005-batch_index-150
# Epoch: 0005, batch_index  200/ 280 , validation accuracy 0.98235
# Epoch: 0005, batch_index  250/ 280 , validation accuracy 0.98284
# Team07_HW2.ckpt-complete-0005-batch_index-250
# Epoch: 0006, batch_index    0/ 280 , validation accuracy 0.98186
# Epoch: 0006, batch_index   50/ 280 , validation accuracy 0.98219
# Epoch: 0006, batch_index  100/ 280 , validation accuracy 0.98284
# Epoch: 0006, batch_index  150/ 280 , validation accuracy 0.98268
# Epoch: 0006, batch_index  200/ 280 , validation accuracy 0.98366
# Team07_HW2.ckpt-complete-0006-batch_index-200
# Epoch: 0006, batch_index  250/ 280 , validation accuracy 0.98431
# Team07_HW2.ckpt-complete-0006-batch_index-250
# Epoch: 0007, batch_index    0/ 280 , validation accuracy 0.98398
# Epoch: 0007, batch_index   50/ 280 , validation accuracy 0.98464
# Team07_HW2.ckpt-complete-0007-batch_index-50
# Epoch: 0007, batch_index  100/ 280 , validation accuracy 0.98415
# Epoch: 0007, batch_index  150/ 280 , validation accuracy 0.98480
# Team07_HW2.ckpt-complete-0007-batch_index-150
# Epoch: 0007, batch_index  200/ 280 , validation accuracy 0.98529
# Team07_HW2.ckpt-complete-0007-batch_index-200
# Epoch: 0007, batch_index  250/ 280 , validation accuracy 0.98366
# Epoch: 0008, batch_index    0/ 280 , validation accuracy 0.98431
# Epoch: 0008, batch_index   50/ 280 , validation accuracy 0.98497
# Epoch: 0008, batch_index  100/ 280 , validation accuracy 0.98546
# Team07_HW2.ckpt-complete-0008-batch_index-100
# Epoch: 0008, batch_index  150/ 280 , validation accuracy 0.98333
# Epoch: 0008, batch_index  200/ 280 , validation accuracy 0.98578
# Team07_HW2.ckpt-complete-0008-batch_index-200
# Epoch: 0008, batch_index  250/ 280 , validation accuracy 0.98447
# Epoch: 0009, batch_index    0/ 280 , validation accuracy 0.98464
# Epoch: 0009, batch_index   50/ 280 , validation accuracy 0.98513
# Epoch: 0009, batch_index  100/ 280 , validation accuracy 0.98546
# Epoch: 0009, batch_index  150/ 280 , validation accuracy 0.98464
# Epoch: 0009, batch_index  200/ 280 , validation accuracy 0.98595
# Team07_HW2.ckpt-complete-0009-batch_index-200
# Epoch: 0009, batch_index  250/ 280 , validation accuracy 0.98480
# Epoch: 0010, batch_index    0/ 280 , validation accuracy 0.98464
# Epoch: 0010, batch_index   50/ 280 , validation accuracy 0.98562
# Epoch: 0010, batch_index  100/ 280 , validation accuracy 0.98529
# Epoch: 0010, batch_index  150/ 280 , validation accuracy 0.98611
# Team07_HW2.ckpt-complete-0010-batch_index-150
# Epoch: 0010, batch_index  200/ 280 , validation accuracy 0.98627
# Team07_HW2.ckpt-complete-0010-batch_index-200
# Epoch: 0010, batch_index  250/ 280 , validation accuracy 0.98595
# Epoch: 0011, batch_index    0/ 280 , validation accuracy 0.98660
# Team07_HW2.ckpt-complete-0011-batch_index-0
# Epoch: 0011, batch_index   50/ 280 , validation accuracy 0.98611
# Epoch: 0011, batch_index  100/ 280 , validation accuracy 0.98595
# Epoch: 0011, batch_index  150/ 280 , validation accuracy 0.98611
# Epoch: 0011, batch_index  200/ 280 , validation accuracy 0.98562
# Epoch: 0011, batch_index  250/ 280 , validation accuracy 0.98529
# Epoch: 0012, batch_index    0/ 280 , validation accuracy 0.98595
# Epoch: 0012, batch_index   50/ 280 , validation accuracy 0.98676
# Team07_HW2.ckpt-complete-0012-batch_index-50
# Epoch: 0012, batch_index  100/ 280 , validation accuracy 0.98676
# Epoch: 0012, batch_index  150/ 280 , validation accuracy 0.98709
# Team07_HW2.ckpt-complete-0012-batch_index-150
# Epoch: 0012, batch_index  200/ 280 , validation accuracy 0.98562
# Epoch: 0012, batch_index  250/ 280 , validation accuracy 0.98627
# Epoch: 0013, batch_index    0/ 280 , validation accuracy 0.98578
# Epoch: 0013, batch_index   50/ 280 , validation accuracy 0.98627
# Epoch: 0013, batch_index  100/ 280 , validation accuracy 0.98595
# Epoch: 0013, batch_index  150/ 280 , validation accuracy 0.98693
# Epoch: 0013, batch_index  200/ 280 , validation accuracy 0.98676
# Epoch: 0013, batch_index  250/ 280 , validation accuracy 0.98595
# Epoch: 0014, batch_index    0/ 280 , validation accuracy 0.98562
# Epoch: 0014, batch_index   50/ 280 , validation accuracy 0.98611
# Epoch: 0014, batch_index  100/ 280 , validation accuracy 0.98742
# Team07_HW2.ckpt-complete-0014-batch_index-100
# Epoch: 0014, batch_index  150/ 280 , validation accuracy 0.98611
# Epoch: 0014, batch_index  200/ 280 , validation accuracy 0.98676
# Epoch: 0014, batch_index  250/ 280 , validation accuracy 0.98676
# Epoch: 0015, batch_index    0/ 280 , validation accuracy 0.98676
# Epoch: 0015, batch_index   50/ 280 , validation accuracy 0.98676
# Epoch: 0015, batch_index  100/ 280 , validation accuracy 0.98676
# Epoch: 0015, batch_index  150/ 280 , validation accuracy 0.98660
# Epoch: 0015, batch_index  200/ 280 , validation accuracy 0.98725
# Epoch: 0015, batch_index  250/ 280 , validation accuracy 0.98578
# Epoch: 0016, batch_index    0/ 280 , validation accuracy 0.98529
# Epoch: 0016, batch_index   50/ 280 , validation accuracy 0.98742
# Epoch: 0016, batch_index  100/ 280 , validation accuracy 0.98725
# Epoch: 0016, batch_index  150/ 280 , validation accuracy 0.98725
# Epoch: 0016, batch_index  200/ 280 , validation accuracy 0.98693
# Epoch: 0016, batch_index  250/ 280 , validation accuracy 0.98725
# Epoch: 0017, batch_index    0/ 280 , validation accuracy 0.98742
# Epoch: 0017, batch_index   50/ 280 , validation accuracy 0.98774
# Team07_HW2.ckpt-complete-0017-batch_index-50
# Epoch: 0017, batch_index  100/ 280 , validation accuracy 0.98693
# Epoch: 0017, batch_index  150/ 280 , validation accuracy 0.98758
# Epoch: 0017, batch_index  200/ 280 , validation accuracy 0.98725
# Epoch: 0017, batch_index  250/ 280 , validation accuracy 0.98709
# Epoch: 0018, batch_index    0/ 280 , validation accuracy 0.98693
# Epoch: 0018, batch_index   50/ 280 , validation accuracy 0.98693
# Epoch: 0018, batch_index  100/ 280 , validation accuracy 0.98693
# Epoch: 0018, batch_index  150/ 280 , validation accuracy 0.98693
# Epoch: 0018, batch_index  200/ 280 , validation accuracy 0.98791
# Team07_HW2.ckpt-complete-0018-batch_index-200
# Epoch: 0018, batch_index  250/ 280 , validation accuracy 0.98742
# Epoch: 0019, batch_index    0/ 280 , validation accuracy 0.98807
# Team07_HW2.ckpt-complete-0019-batch_index-0
# Epoch: 0019, batch_index   50/ 280 , validation accuracy 0.98840
# Team07_HW2.ckpt-complete-0019-batch_index-50
# Epoch: 0019, batch_index  100/ 280 , validation accuracy 0.98676
# Epoch: 0019, batch_index  150/ 280 , validation accuracy 0.98709
# Epoch: 0019, batch_index  200/ 280 , validation accuracy 0.98725
# Epoch: 0019, batch_index  250/ 280 , validation accuracy 0.98644
# Epoch: 0020, batch_index    0/ 280 , validation accuracy 0.98627
# Epoch: 0020, batch_index   50/ 280 , validation accuracy 0.98742
# Epoch: 0020, batch_index  100/ 280 , validation accuracy 0.98725
# Epoch: 0020, batch_index  150/ 280 , validation accuracy 0.98791
# Epoch: 0020, batch_index  200/ 280 , validation accuracy 0.98807
# Epoch: 0020, batch_index  250/ 280 , validation accuracy 0.98774
# Epoch: 0021, batch_index    0/ 280 , validation accuracy 0.98807
# Epoch: 0021, batch_index   50/ 280 , validation accuracy 0.98807
# Epoch: 0021, batch_index  100/ 280 , validation accuracy 0.98823
# Epoch: 0021, batch_index  150/ 280 , validation accuracy 0.98774
# Epoch: 0021, batch_index  200/ 280 , validation accuracy 0.98791
# Epoch: 0021, batch_index  250/ 280 , validation accuracy 0.98758
# Epoch: 0022, batch_index    0/ 280 , validation accuracy 0.98758
# Epoch: 0022, batch_index   50/ 280 , validation accuracy 0.98758
# Epoch: 0022, batch_index  100/ 280 , validation accuracy 0.98840
# Epoch: 0022, batch_index  150/ 280 , validation accuracy 0.98742
# early_stop...........
# [0.99735516, 0.99783599, 0.99735516, 0.99639338, 0.99855733]
# [0.98637867, 0.98696232, 0.98637861, 0.9879353, 0.98812991]
# [0.99927729, 0.99879664, 0.99879605, 0.99903566, 0.99879748]
# 1. 5-Fold平均正確率 :  0.997499 2. 5-Fold平均精確率 :  0.998941 3. 5-Fold平均Recall :  0.987157
